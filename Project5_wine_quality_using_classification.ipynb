# %%
#Lets import the red wine dataset
import pandas as pd
df_wines=pd.read_csv('C:/Users/vishwaraj/Desktop/winequality-red.csv',sep=',')
df_wines
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
#lets chcek the presence of null values
df_wines.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#Lets chcek the datatypes of each column
df_wines.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
#correlation matrix
df_wines.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
#Lets describe the dataset
df_wines.describe()
#From correlation matrix total sulfur dioxide seems to have some outliers as there is significant difference between mean and median
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
#Lets do some graphical EDA
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x="quality",y="alcohol",data=df_wines)
plt.show()
#from below barplot it can be seen there is increasing trend in average alcohol content from 5 to 8

# %%
#Lets check the count of each type of quality
sns.countplot(x="quality",data=df_wines)
plt.show()
#here we can see that most of the wines of quality 5 and 6 in the datset 
#Other 3 and 8 are very very less so barplot may not give clear picture about average alcohol content as instances are very less

# %%
#Keeping in mind the above points lets check average ph content in each type of wines
sns.barplot(x="quality",y="pH",data=df_wines)
plt.show()
#it is alomost same in each type of wine and hardly shows any variance

# %%
#Lets chcek as seen from correlation matrix above total sulfur dioxide seem to have outliers
#Lets verify this using boxplot
sns.boxplot(x="quality",y="total sulfur dioxide",data=df_wines)
plt.show()
#we see presence of outliers graphically here as we could see in correlation matrix

# %%
#Let's chcek the change in average residual sugar with quality
sns.barplot(x="quality",y="residual sugar",data=df_wines)
plt.show()

# %%
#Lets remove the outliers if present using z scores
from scipy.stats import zscore
z_scr=zscore(df_wines)
print(df_wines.shape)
df_wines_new=df_wines.loc[(abs(z_scr)<3).all(axis=1)]
print(df_wines_new.shape)
# Out:
# (1599, 12)
# (1451, 12)

# %%
#lets again chcek presence of each type of quality in the df_wines_new since outliers have been removed
sns.countplot(x="quality",data=df_wines_new)
plt.show()
#here we see we have removed one type of quality from the dataset

# %%
#Lets convert target variable into binary classification problem 
bins = (2, 6.5, 8)
classs = ['bad', 'good']
df_wines_new['quality'] = pd.cut(df_wines_new['quality'], bins = bins, labels = classs)
# Out:
# C:\Users\vishwaraj\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df_wines_new
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# 11              7.5             0.500         0.36             6.1      0.071
# 12              5.6             0.615         0.00             1.6      0.089
# 16              8.5             0.280         0.56             1.8      0.092
# 18              7.4             0.590         0.08             4.4      0.086
# 20              8.9             0.220         0.48             1.8      0.077
# 21              7.6             0.390         0.31             2.3      0.082
# 22              7.9             0.430         0.21             1.6      0.106
# 23              8.5             0.490         0.11             2.3      0.084
# 24              6.9             0.400         0.14             2.4      0.085
# 25              6.3             0.390         0.16             1.4      0.080
# 26              7.6             0.410         0.24             1.8      0.080
# 27              7.9             0.430         0.21             1.6      0.106
# 28              7.1             0.710         0.00             1.9      0.080
# 29              7.8             0.645         0.00             2.0      0.082
# 30              6.7             0.675         0.07             2.4      0.089
# 31              6.9             0.685         0.00             2.5      0.105
# 32              8.3             0.655         0.12             2.3      0.083
# 34              5.2             0.320         0.25             1.8      0.103
# 35              7.8             0.645         0.00             5.5      0.086
# ...             ...               ...          ...             ...        ...
# 1566            6.7             0.160         0.64             2.1      0.059
# 1567            7.2             0.695         0.13             2.0      0.076
# 1568            7.0             0.560         0.13             1.6      0.077
# 1569            6.2             0.510         0.14             1.9      0.056
# 1571            6.4             0.380         0.14             2.2      0.038
# 1572            7.3             0.690         0.32             2.2      0.069
# 1573            6.0             0.580         0.20             2.4      0.075
# 1575            7.5             0.520         0.40             2.2      0.060
# 1576            8.0             0.300         0.63             1.6      0.081
# 1577            6.2             0.700         0.15             5.1      0.076
# 1578            6.8             0.670         0.15             1.8      0.118
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 5                    13.0                  40.0  0.99780  3.51       0.56
# 6                    15.0                  59.0  0.99640  3.30       0.46
# 7                    15.0                  21.0  0.99460  3.39       0.47
# 8                     9.0                  18.0  0.99680  3.36       0.57
# 9                    17.0                 102.0  0.99780  3.35       0.80
# 10                   15.0                  65.0  0.99590  3.28       0.54
# 11                   17.0                 102.0  0.99780  3.35       0.80
# 12                   16.0                  59.0  0.99430  3.58       0.52
# 16                   35.0                 103.0  0.99690  3.30       0.75
# 18                    6.0                  29.0  0.99740  3.38       0.50
# 20                   29.0                  60.0  0.99680  3.39       0.53
# 21                   23.0                  71.0  0.99820  3.52       0.65
# 22                   10.0                  37.0  0.99660  3.17       0.91
# 23                    9.0                  67.0  0.99680  3.17       0.53
# 24                   21.0                  40.0  0.99680  3.43       0.63
# 25                   11.0                  23.0  0.99550  3.34       0.56
# 26                    4.0                  11.0  0.99620  3.28       0.59
# 27                   10.0                  37.0  0.99660  3.17       0.91
# 28                   14.0                  35.0  0.99720  3.47       0.55
# 29                    8.0                  16.0  0.99640  3.38       0.59
# 30                   17.0                  82.0  0.99580  3.35       0.54
# 31                   22.0                  37.0  0.99660  3.46       0.57
# 32                   15.0                 113.0  0.99660  3.17       0.66
# 34                   13.0                  50.0  0.99570  3.38       0.55
# 35                    5.0                  18.0  0.99860  3.40       0.55
# ...                   ...                   ...      ...   ...        ...
# 1566                 24.0                  52.0  0.99494  3.34       0.71
# 1567                 12.0                  20.0  0.99546  3.29       0.54
# 1568                 25.0                  42.0  0.99629  3.34       0.59
# 1569                 15.0                  34.0  0.99396  3.48       0.57
# 1571                 15.0                  25.0  0.99514  3.44       0.65
# 1572                 35.0                 104.0  0.99632  3.33       0.51
# 1573                 15.0                  50.0  0.99467  3.58       0.67
# 1575                 12.0                  20.0  0.99474  3.26       0.64
# 1576                 16.0                  29.0  0.99588  3.30       0.78
# 1577                 13.0                  27.0  0.99622  3.54       0.60
# 1578                 13.0                  20.0  0.99540  3.42       0.67
# 1579                 24.0                  32.0  0.99402  3.54       0.60
# 1580                  9.0                  26.0  0.99470  3.36       0.60
# 1581                 24.0                  32.0  0.99402  3.54       0.60
# 1582                 13.0                  27.0  0.99362  3.57       0.50
# 1583                 32.0                  98.0  0.99578  3.33       0.62
# 1584                 24.0                  34.0  0.99484  3.29       0.80
# 1585                 22.0                  48.0  0.99494  3.30       0.84
# 1586                 34.0                  60.0  0.99492  3.34       0.85
# 1587                 18.0                  28.0  0.99483  3.55       0.66
# 1588                 34.0                 102.0  0.99414  3.27       0.78
# 1590                 26.0                  35.0  0.99314  3.32       0.82
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1592                 29.0                  40.0  0.99574  3.42       0.75
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol quality
# 0         9.4     bad
# 1         9.8     bad
# 2         9.8     bad
# 3         9.8     bad
# 4         9.4     bad
# 5         9.4     bad
# 6         9.4     bad
# 7        10.0    good
# 8         9.5    good
# 9        10.5     bad
# 10        9.2     bad
# 11       10.5     bad
# 12        9.9     bad
# 16       10.5    good
# 18        9.0     bad
# 20        9.4     bad
# 21        9.7     bad
# 22        9.5     bad
# 23        9.4     bad
# 24        9.7     bad
# 25        9.3     bad
# 26        9.5     bad
# 27        9.5     bad
# 28        9.4     bad
# 29        9.8     bad
# 30       10.1     bad
# 31       10.6     bad
# 32        9.8     bad
# 34        9.2     bad
# 35        9.6     bad
# ...       ...     ...
# 1566     11.2     bad
# 1567     10.1     bad
# 1568      9.2     bad
# 1569     11.5     bad
# 1571     11.1     bad
# 1572      9.5     bad
# 1573     12.5     bad
# 1575     11.8     bad
# 1576     10.8     bad
# 1577     11.9     bad
# 1578     11.3     bad
# 1579     11.3     bad
# 1580     11.9     bad
# 1581     11.3     bad
# 1582     11.9     bad
# 1583      9.8     bad
# 1584     11.6    good
# 1585     11.5     bad
# 1586     11.4     bad
# 1587     10.9     bad
# 1588     12.8     bad
# 1590     11.6     bad
# 1591     11.6     bad
# 1592     11.0     bad
# 1593      9.5     bad
# 1594     10.5     bad
# 1595     11.2     bad
# 1596     11.0     bad
# 1597     10.2     bad
# 1598     11.0     bad
#
# [1451 rows x 12 columns]

# %%
#lets chcek the count of good and bad instances in the datase
sns.countplot(x="quality",data=df_wines_new)
plt.show()
#this the case of highly imbalance data

# %%
#Lets divide dataset into input and output
df_x=df_wines_new.drop(columns=["quality"])
y=df_wines_new[["quality"]]

# %%
#Lets chcek the skewness of the input dataset
print(df_x.skew())
print()
print(len(df_x.skew().loc[df_x.skew()>0.55]))# Number of features having skewness more than 0.55
# Out:
# fixed acidity           0.823934
# volatile acidity        0.380659
# citric acid             0.291297
# residual sugar          2.456107
# chlorides               2.275162
# free sulfur dioxide     0.869250
# total sulfur dioxide    1.183161
# density                 0.055738
# pH                      0.114705
# sulphates               0.891492
# alcohol                 0.758958
# dtype: float64
#
# 7

# %%
#Lets treat above skewness
import numpy as np
for index in df_x.skew().index:
    if df_x.skew().loc[index] >0.55:
        df_x[index]=np.cbrt(df_x[index])

# %%
#lets again check the skewness
print(df_x.skew())
print()
print(len(df_x.skew().loc[df_x.skew()>0.55]))# Number of features having skewness more than 0.55
# Out:
# fixed acidity           0.529105
# volatile acidity        0.380659
# citric acid             0.291297
# residual sugar          1.629524
# chlorides               1.020246
# free sulfur dioxide     0.125799
# total sulfur dioxide    0.342621
# density                 0.055738
# pH                      0.114705
# sulphates               0.523901
# alcohol                 0.646678
# dtype: float64
#
# 3

# %%
#Lets do the preprocessing bring features to common scale
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(df_x)
x=sc.transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
#Lets convert the target variable into integers
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit(y)
y=le.transform(y)
y
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#since it is imbalanced dataset so we will focus on auc-roc score
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
def max_aucroc_score(clf,df_x,y):
    max_aucroc_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = r_state,test_size=0.20,stratify=y)
        clf.fit(x_train,y_train)
        y_pred = clf.predict(x_test)
        aucroc_scr=roc_auc_score(y_test,y_pred)
        print("auc roc score corresponding to ",r_state," is ",aucroc_scr)
        if aucroc_scr>max_aucroc_score:
            max_aucroc_score=aucroc_scr
            final_r_state=r_state
    print("max auc roc score corresponding to ",final_r_state," is ",max_aucroc_score)
    return final_r_state

# %%
from sklearn.tree import DecisionTreeClassifier
dc=DecisionTreeClassifier()
max_aucroc_score(dc,df_x,y)
# Out:
# auc roc score corresponding to  42  is  0.7996513944223107
# auc roc score corresponding to  43  is  0.7201195219123506
# auc roc score corresponding to  44  is  0.7291832669322709
# auc roc score corresponding to  45  is  0.6741035856573705
# auc roc score corresponding to  46  is  0.7416832669322709
# auc roc score corresponding to  47  is  0.7741035856573706
# auc roc score corresponding to  48  is  0.7226593625498007
# auc roc score corresponding to  49  is  0.7510956175298805
# auc roc score corresponding to  50  is  0.6786354581673307
# auc roc score corresponding to  51  is  0.750199203187251
# auc roc score corresponding to  52  is  0.677191235059761
# auc roc score corresponding to  53  is  0.8215637450199204
# auc roc score corresponding to  54  is  0.6846115537848606
# auc roc score corresponding to  55  is  0.7641434262948208
# auc roc score corresponding to  56  is  0.7891434262948207
# auc roc score corresponding to  57  is  0.7831673306772907
# auc roc score corresponding to  58  is  0.7556274900398408
# auc roc score corresponding to  59  is  0.7311752988047808
# auc roc score corresponding to  60  is  0.7911354581673307
# auc roc score corresponding to  61  is  0.7596115537848606
# auc roc score corresponding to  62  is  0.7021912350597609
# auc roc score corresponding to  63  is  0.8141434262948206
# auc roc score corresponding to  64  is  0.6851593625498007
# auc roc score corresponding to  65  is  0.7306274900398406
# auc roc score corresponding to  66  is  0.7496513944223107
# auc roc score corresponding to  67  is  0.8161354581673307
# auc roc score corresponding to  68  is  0.8181274900398408
# auc roc score corresponding to  69  is  0.7982071713147411
# auc roc score corresponding to  70  is  0.7766434262948206
# auc roc score corresponding to  71  is  0.750199203187251
# auc roc score corresponding to  72  is  0.7186752988047809
# auc roc score corresponding to  73  is  0.7971115537848605
# auc roc score corresponding to  74  is  0.8331673306772908
# auc roc score corresponding to  75  is  0.7596115537848606
# auc roc score corresponding to  76  is  0.6811752988047808
# auc roc score corresponding to  77  is  0.7146912350597608
# auc roc score corresponding to  78  is  0.7371513944223108
# auc roc score corresponding to  79  is  0.7291832669322709
# auc roc score corresponding to  80  is  0.7226593625498007
# auc roc score corresponding to  81  is  0.7351593625498007
# auc roc score corresponding to  82  is  0.7476593625498007
# auc roc score corresponding to  83  is  0.7371513944223108
# auc roc score corresponding to  84  is  0.7556274900398408
# auc roc score corresponding to  85  is  0.7277390438247011
# auc roc score corresponding to  86  is  0.756175298804781
# auc roc score corresponding to  87  is  0.7471115537848607
# auc roc score corresponding to  88  is  0.7161354581673307
# auc roc score corresponding to  89  is  0.8096115537848607
# auc roc score corresponding to  90  is  0.7181274900398407
# auc roc score corresponding to  91  is  0.7041832669322708
# auc roc score corresponding to  92  is  0.8172310756972111
# auc roc score corresponding to  93  is  0.6951195219123506
# auc roc score corresponding to  94  is  0.8246513944223108
# auc roc score corresponding to  95  is  0.7382470119521913
# auc roc score corresponding to  96  is  0.7931274900398406
# auc roc score corresponding to  97  is  0.7201195219123506
# auc roc score corresponding to  98  is  0.7451195219123506
# auc roc score corresponding to  99  is  0.748207171314741
# max auc roc score corresponding to  74  is  0.8331673306772908
# 74

# %%
from sklearn.model_selection import cross_val_score
print("Mean roc auc score for decision tree classifier: ",cross_val_score(dc,df_x,y,cv=5,scoring="roc_auc").mean())
print("standard deviation in roc auc score for decision tree classifier: ",cross_val_score(dc,df_x,y,cv=5,scoring="roc_auc").std())
print(cross_val_score(dc,df_x,y,cv=5,scoring="roc_auc"))
# Out:
# Mean roc auc score for decision tree classifier:  0.6535341463414635
# standard deviation in roc auc score for decision tree classifier:  0.05762346618217537
# [0.56117073 0.6995     0.7225     0.745      0.655     ]

# %%
#Lets use KNN
#For KNN we need to know the best value of k using grid search
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
import warnings
warnings.filterwarnings("ignore")
kc=KNeighborsClassifier()
neighbors={"n_neighbors":range(1,30)}
clf = GridSearchCV(kc, neighbors, cv=5,scoring="roc_auc")
clf.fit(x,y)
clf.best_params_
# Out:
# {'n_neighbors': 29}

# %%
kc=KNeighborsClassifier(n_neighbors=29)
max_aucroc_score(kc,x,y)
# Out:
# auc roc score corresponding to  42  is  0.6150398406374502
# auc roc score corresponding to  43  is  0.6195717131474103
# auc roc score corresponding to  44  is  0.6340637450199204
# auc roc score corresponding to  45  is  0.6295318725099601
# auc roc score corresponding to  46  is  0.6275398406374503
# auc roc score corresponding to  47  is  0.6380478087649403
# auc roc score corresponding to  48  is  0.5900398406374502
# auc roc score corresponding to  49  is  0.6485557768924303
# auc roc score corresponding to  50  is  0.6070717131474104
# auc roc score corresponding to  51  is  0.5300796812749005
# auc roc score corresponding to  52  is  0.6485557768924303
# auc roc score corresponding to  53  is  0.62300796812749
# auc roc score corresponding to  54  is  0.5655876494023905
# auc roc score corresponding to  55  is  0.5965637450199204
# auc roc score corresponding to  56  is  0.6010956175298805
# auc roc score corresponding to  57  is  0.6525398406374503
# auc roc score corresponding to  58  is  0.6235557768924302
# auc roc score corresponding to  59  is  0.5860557768924303
# auc roc score corresponding to  60  is  0.6545318725099601
# auc roc score corresponding to  61  is  0.5775398406374502
# auc roc score corresponding to  62  is  0.5860557768924303
# auc roc score corresponding to  63  is  0.6130478087649402
# auc roc score corresponding to  64  is  0.6485557768924303
# auc roc score corresponding to  65  is  0.6420318725099602
# auc roc score corresponding to  66  is  0.6280876494023905
# auc roc score corresponding to  67  is  0.5945717131474104
# auc roc score corresponding to  68  is  0.6420318725099602
# auc roc score corresponding to  69  is  0.6255478087649402
# auc roc score corresponding to  70  is  0.6195717131474103
# auc roc score corresponding to  71  is  0.6090637450199203
# auc roc score corresponding to  72  is  0.6275398406374503
# auc roc score corresponding to  73  is  0.6380478087649403
# auc roc score corresponding to  74  is  0.6360557768924303
# auc roc score corresponding to  75  is  0.6485557768924303
# auc roc score corresponding to  76  is  0.6300796812749004
# auc roc score corresponding to  77  is  0.6175796812749004
# auc roc score corresponding to  78  is  0.6505478087649402
# auc roc score corresponding to  79  is  0.6755478087649402
# auc roc score corresponding to  80  is  0.5871513944223107
# auc roc score corresponding to  81  is  0.6795318725099602
# auc roc score corresponding to  82  is  0.5715637450199204
# auc roc score corresponding to  83  is  0.6525398406374503
# auc roc score corresponding to  84  is  0.6670318725099602
# auc roc score corresponding to  85  is  0.5925796812749005
# auc roc score corresponding to  86  is  0.6320717131474104
# auc roc score corresponding to  87  is  0.6110557768924303
# auc roc score corresponding to  88  is  0.5985557768924303
# auc roc score corresponding to  89  is  0.6780876494023904
# auc roc score corresponding to  90  is  0.6445717131474104
# auc roc score corresponding to  91  is  0.6190239043824701
# auc roc score corresponding to  92  is  0.6425796812749004
# auc roc score corresponding to  93  is  0.5735557768924303
# auc roc score corresponding to  94  is  0.5840637450199203
# auc roc score corresponding to  95  is  0.6460159362549801
# auc roc score corresponding to  96  is  0.5985557768924303
# auc roc score corresponding to  97  is  0.63351593625498
# auc roc score corresponding to  98  is  0.5920318725099601
# auc roc score corresponding to  99  is  0.6590637450199204
# max auc roc score corresponding to  81  is  0.6795318725099602
# 81

# %%
from sklearn.model_selection import cross_val_score
print("Mean roc auc score for  KNN classifier: ",cross_val_score(kc,x,y,cv=5,scoring="roc_auc").mean())
print("standard deviation in roc auc score for KNN classifier: ",cross_val_score(kc,x,y,cv=5,scoring="roc_auc").std())
print(cross_val_score(kc,x,y,cv=5,scoring="roc_auc"))
# Out:
# Mean roc auc score for  KNN classifier:  0.8346517073170732
# standard deviation in roc auc score for KNN classifier:  0.020694453998447812
# [0.83565854 0.85065    0.8628     0.8181     0.80605   ]

# %%
#Lets chcek random forest classifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
parameters={"n_estimators":[10,100,500]}
rf_clf=RandomForestClassifier()
clf = GridSearchCV(rf_clf, parameters, cv=5,scoring="roc_auc")
clf.fit(df_x,y)
clf.best_params_
# Out:
# {'n_estimators': 500}

# %%
rf_clf=RandomForestClassifier(n_estimators=500)
max_aucroc_score(rf_clf,df_x,y)
# Out:
# auc roc score corresponding to  42  is  0.7650398406374502
# auc roc score corresponding to  43  is  0.7670318725099602
# auc roc score corresponding to  44  is  0.7025398406374502
# auc roc score corresponding to  45  is  0.7045318725099602
# auc roc score corresponding to  46  is  0.7610557768924303
# auc roc score corresponding to  47  is  0.7405876494023904
# auc roc score corresponding to  48  is  0.7130478087649402
# auc roc score corresponding to  49  is  0.7815239043824701
# auc roc score corresponding to  50  is  0.6610557768924303
# auc roc score corresponding to  51  is  0.7525398406374503
# auc roc score corresponding to  52  is  0.7425796812749004
# auc roc score corresponding to  53  is  0.7335159362549801
# auc roc score corresponding to  54  is  0.6755478087649402
# auc roc score corresponding to  55  is  0.7570717131474105
# auc roc score corresponding to  56  is  0.8130478087649402
# auc roc score corresponding to  57  is  0.7735557768924303
# auc roc score corresponding to  58  is  0.7130478087649402
# auc roc score corresponding to  59  is  0.6900398406374502
# auc roc score corresponding to  60  is  0.7210159362549801
# auc roc score corresponding to  61  is  0.7070717131474104
# auc roc score corresponding to  62  is  0.7255478087649403
# auc roc score corresponding to  63  is  0.7630478087649403
# auc roc score corresponding to  64  is  0.7360557768924303
# auc roc score corresponding to  65  is  0.7255478087649403
# auc roc score corresponding to  66  is  0.7400398406374502
# auc roc score corresponding to  67  is  0.7945717131474105
# auc roc score corresponding to  68  is  0.8065239043824701
# auc roc score corresponding to  69  is  0.7880478087649403
# auc roc score corresponding to  70  is  0.7675796812749004
# auc roc score corresponding to  71  is  0.7735557768924303
# auc roc score corresponding to  72  is  0.7525398406374503
# auc roc score corresponding to  73  is  0.8065239043824701
# auc roc score corresponding to  74  is  0.7275398406374503
# auc roc score corresponding to  75  is  0.7900398406374503
# auc roc score corresponding to  76  is  0.7235557768924303
# auc roc score corresponding to  77  is  0.7655876494023904
# auc roc score corresponding to  78  is  0.7260956175298805
# auc roc score corresponding to  79  is  0.7610557768924303
# auc roc score corresponding to  80  is  0.7116035856573706
# auc roc score corresponding to  81  is  0.7440239043824701
# auc roc score corresponding to  82  is  0.7275398406374503
# auc roc score corresponding to  83  is  0.7610557768924303
# auc roc score corresponding to  84  is  0.7565239043824701
# auc roc score corresponding to  85  is  0.7380478087649402
# auc roc score corresponding to  86  is  0.7945717131474105
# auc roc score corresponding to  87  is  0.6900398406374502
# auc roc score corresponding to  88  is  0.7465637450199203
# auc roc score corresponding to  89  is  0.8175796812749004
# auc roc score corresponding to  90  is  0.7195717131474104
# auc roc score corresponding to  91  is  0.7440239043824701
# auc roc score corresponding to  92  is  0.8530876494023905
# auc roc score corresponding to  93  is  0.6965637450199204
# auc roc score corresponding to  94  is  0.8090637450199203
# auc roc score corresponding to  95  is  0.7840637450199204
# auc roc score corresponding to  96  is  0.7775398406374503
# auc roc score corresponding to  97  is  0.7315239043824702
# auc roc score corresponding to  98  is  0.6835159362549801
# auc roc score corresponding to  99  is  0.7110557768924303
# max auc roc score corresponding to  92  is  0.8530876494023905
# 92

# %%
print("Mean roc auc score for random forest classifier: ",cross_val_score(rf_clf,df_x,y,cv=5,scoring="roc_auc").mean())
print("standard deviation in roc auc score for random forest classifier: ",cross_val_score(rf_clf,df_x,y,cv=5,scoring="roc_auc").std())
print(cross_val_score(rf_clf,df_x,y,cv=5,scoring="roc_auc"))
# Out:
# Mean roc auc score for random forest classifier:  0.869660243902439
# standard deviation in roc auc score for random forest classifier:  0.02332384704391669
# [0.87931707 0.8761     0.87895    0.8471     0.8475    ]

# %%
#Lets use Gradient boosting classifier
from sklearn.ensemble import GradientBoostingClassifier
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
gb_clf=GradientBoostingClassifier()
clf = GridSearchCV(gb_clf, parameters, cv=5,scoring="roc_auc")
clf.fit(df_x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 100}

# %%
gb_clf=GradientBoostingClassifier(learning_rate=0.1,n_estimators=100)
max_aucroc_score(gb_clf,df_x,y)
# Out:
# auc roc score corresponding to  42  is  0.7675796812749004
# auc roc score corresponding to  43  is  0.7650398406374502
# auc roc score corresponding to  44  is  0.7241035856573705
# auc roc score corresponding to  45  is  0.6670318725099602
# auc roc score corresponding to  46  is  0.7590637450199204
# auc roc score corresponding to  47  is  0.7635956175298805
# auc roc score corresponding to  48  is  0.7005478087649403
# auc roc score corresponding to  49  is  0.7900398406374503
# auc roc score corresponding to  50  is  0.6280876494023905
# auc roc score corresponding to  51  is  0.7195717131474104
# auc roc score corresponding to  52  is  0.7260956175298805
# auc roc score corresponding to  53  is  0.7045318725099602
# auc roc score corresponding to  54  is  0.6755478087649402
# auc roc score corresponding to  55  is  0.7741035856573706
# auc roc score corresponding to  56  is  0.8070717131474103
# auc roc score corresponding to  57  is  0.7695717131474104
# auc roc score corresponding to  58  is  0.7320717131474104
# auc roc score corresponding to  59  is  0.7110557768924303
# auc roc score corresponding to  60  is  0.7525398406374503
# auc roc score corresponding to  61  is  0.6715637450199203
# auc roc score corresponding to  62  is  0.6840637450199203
# auc roc score corresponding to  63  is  0.7050796812749004
# auc roc score corresponding to  64  is  0.7380478087649402
# auc roc score corresponding to  65  is  0.7175796812749005
# auc roc score corresponding to  66  is  0.7275398406374503
# auc roc score corresponding to  67  is  0.7155876494023905
# auc roc score corresponding to  68  is  0.8090637450199203
# auc roc score corresponding to  69  is  0.7425796812749004
# auc roc score corresponding to  70  is  0.7715637450199203
# auc roc score corresponding to  71  is  0.7425796812749004
# auc roc score corresponding to  72  is  0.7340637450199203
# auc roc score corresponding to  73  is  0.8025398406374503
# auc roc score corresponding to  74  is  0.7505478087649402
# auc roc score corresponding to  75  is  0.7795318725099601
# auc roc score corresponding to  76  is  0.7320717131474104
# auc roc score corresponding to  77  is  0.7491035856573706
# auc roc score corresponding to  78  is  0.7155876494023905
# auc roc score corresponding to  79  is  0.7326195219123507
# auc roc score corresponding to  80  is  0.6721115537848605
# auc roc score corresponding to  81  is  0.7590637450199204
# auc roc score corresponding to  82  is  0.6971115537848606
# auc roc score corresponding to  83  is  0.7425796812749004
# auc roc score corresponding to  84  is  0.7110557768924303
# auc roc score corresponding to  85  is  0.7735557768924303
# auc roc score corresponding to  86  is  0.7530876494023905
# auc roc score corresponding to  87  is  0.6650398406374503
# auc roc score corresponding to  88  is  0.7340637450199203
# auc roc score corresponding to  89  is  0.7741035856573706
# auc roc score corresponding to  90  is  0.7030876494023904
# auc roc score corresponding to  91  is  0.7235557768924303
# auc roc score corresponding to  92  is  0.7925796812749004
# auc roc score corresponding to  93  is  0.6860557768924302
# auc roc score corresponding to  94  is  0.7510956175298805
# auc roc score corresponding to  95  is  0.7550796812749004
# auc roc score corresponding to  96  is  0.7275398406374503
# auc roc score corresponding to  97  is  0.7545318725099601
# auc roc score corresponding to  98  is  0.6445717131474104
# auc roc score corresponding to  99  is  0.7175796812749005
# max auc roc score corresponding to  68  is  0.8090637450199203
# 68

# %%
print("Mean roc auc score for gradient boosting classifier: ",cross_val_score(gb_clf,df_x,y,cv=5,scoring="roc_auc").mean())
print("standard deviation in roc auc score for gradient boosting classifier: ",cross_val_score(gb_clf,df_x,y,cv=5,scoring="roc_auc").std())
print(cross_val_score(gb_clf,df_x,y,cv=5,scoring="roc_auc"))
# Out:
# Mean roc auc score for gradient boosting classifier:  0.8738682926829269
# standard deviation in roc auc score for gradient boosting classifier:  0.03751791337684295
# [0.92243902 0.8709     0.9095     0.8324     0.8334    ]

# %%
#Lets use SVM
from sklearn.svm import SVC
svc=SVC()
parameters={"kernel":["linear", "poly", "rbf"],"C":[0.001,0.01,0.1,1,10]}
clf = GridSearchCV(svc, parameters, cv=5,scoring="roc_auc")
clf.fit(x,y)
clf.best_params_
# Out:
# {'C': 0.1, 'kernel': 'linear'}

# %%
svc=SVC(kernel="linear",C=0.1)
max_aucroc_score(svc,x,y)
# Out:
# auc roc score corresponding to  42  is  0.6045318725099602
# auc roc score corresponding to  43  is  0.5605079681274902
# auc roc score corresponding to  44  is  0.6420318725099602
# auc roc score corresponding to  45  is  0.5815239043824701
# auc roc score corresponding to  46  is  0.5
# auc roc score corresponding to  47  is  0.6235557768924302
# auc roc score corresponding to  48  is  0.5630478087649402
# auc roc score corresponding to  49  is  0.5
# auc roc score corresponding to  50  is  0.5940239043824701
# auc roc score corresponding to  51  is  0.5650398406374502
# auc roc score corresponding to  52  is  0.6090637450199203
# auc roc score corresponding to  53  is  0.5125
# auc roc score corresponding to  54  is  0.5420318725099602
# auc roc score corresponding to  55  is  0.5985557768924303
# auc roc score corresponding to  56  is  0.6505478087649402
# auc roc score corresponding to  57  is  0.525
# auc roc score corresponding to  58  is  0.5650398406374502
# auc roc score corresponding to  59  is  0.5900398406374502
# auc roc score corresponding to  60  is  0.5
# auc roc score corresponding to  61  is  0.5815239043824701
# auc roc score corresponding to  62  is  0.5940239043824701
# auc roc score corresponding to  63  is  0.5690239043824701
# auc roc score corresponding to  64  is  0.6400398406374502
# auc roc score corresponding to  65  is  0.5
# auc roc score corresponding to  66  is  0.6005478087649403
# auc roc score corresponding to  67  is  0.6235557768924302
# auc roc score corresponding to  68  is  0.5
# auc roc score corresponding to  69  is  0.5375
# auc roc score corresponding to  70  is  0.6275398406374503
# auc roc score corresponding to  71  is  0.6190239043824701
# auc roc score corresponding to  72  is  0.5
# auc roc score corresponding to  73  is  0.5
# auc roc score corresponding to  74  is  0.53550796812749
# auc roc score corresponding to  75  is  0.5
# auc roc score corresponding to  76  is  0.5565239043824701
# auc roc score corresponding to  77  is  0.5925796812749005
# auc roc score corresponding to  78  is  0.6215637450199203
# auc roc score corresponding to  79  is  0.5
# auc roc score corresponding to  80  is  0.6010956175298805
# auc roc score corresponding to  81  is  0.5835159362549801
# auc roc score corresponding to  82  is  0.5880478087649402
# auc roc score corresponding to  83  is  0.5940239043824701
# auc roc score corresponding to  84  is  0.5125
# auc roc score corresponding to  85  is  0.5625
# auc roc score corresponding to  86  is  0.5
# auc roc score corresponding to  87  is  0.5920318725099601
# auc roc score corresponding to  88  is  0.5795318725099602
# auc roc score corresponding to  89  is  0.5960159362549801
# auc roc score corresponding to  90  is  0.5650398406374502
# auc roc score corresponding to  91  is  0.6295318725099601
# auc roc score corresponding to  92  is  0.5940239043824701
# auc roc score corresponding to  93  is  0.5485557768924303
# auc roc score corresponding to  94  is  0.525
# auc roc score corresponding to  95  is  0.5
# auc roc score corresponding to  96  is  0.5
# auc roc score corresponding to  97  is  0.5605079681274902
# auc roc score corresponding to  98  is  0.5690239043824701
# auc roc score corresponding to  99  is  0.6315239043824701
# max auc roc score corresponding to  56  is  0.6505478087649402
# 56

# %%
print("Mean roc auc score for SVM classifier: ",cross_val_score(svc,x,y,cv=5,scoring="roc_auc").mean())
print("standard deviation in roc auc score for SVM classifier: ",cross_val_score(svc,x,y,cv=5,scoring="roc_auc").std())
print(cross_val_score(svc,x,y,cv=5,scoring="roc_auc"))
# Out:
# Mean roc auc score for SVM classifier:  0.8849175609756097
# standard deviation in roc auc score for SVM classifier:  0.019191290310850893
# [0.9004878 0.8782    0.912     0.8576    0.8763   ]

# %% [markdown]
# Based on above scores we can choose random forest as there  we are achieving highest auc_roc score with random state 92

# %%
#lets make our final model
x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = 92,test_size=0.20,stratify=y)
rf_clf=RandomForestClassifier(n_estimators=500)
rf_clf.fit(x_train,y_train)
y_pred=rf_clf.predict(x_test)

# %%
#Lets print auc roc score and confusion matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
print("Confusion matrix \n",confusion_matrix(y_test,y_pred))
print("f1 score is : ",f1_score(y_test,y_pred))
print("classification report \n",classification_report(y_test,y_pred))
print("AUC ROC Score: ",roc_auc_score(y_test,y_pred))
# Out:
# Confusion matrix
#  [[241  10]
#  [ 11  29]]
# f1 score is :  0.7341772151898733
# classification report
#                precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       251
#            1       0.74      0.72      0.73        40
#
#    micro avg       0.93      0.93      0.93       291
#    macro avg       0.85      0.84      0.85       291
# weighted avg       0.93      0.93      0.93       291
#
# AUC ROC Score:  0.8425796812749005

# %%
#Lets save this model using joblib
#Lets save the above model
from sklearn.externals import joblib 
  
# Save the model as a pickle in a file 
joblib.dump(rf_clf, 'wine_datset_random_forest.pkl')
# Out:
# ['wine_datset_random_forest.pkl']
