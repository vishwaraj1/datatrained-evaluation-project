# %%
import pandas as pd
df_train=pd.read_excel("C:/Users/vishwaraj/Desktop/food restaurant/Data_Train.xlsx")
df_train["source"]="train"
df_test=pd.read_excel("C:/Users/vishwaraj/Desktop/food restaurant/Data_Test.xlsx")
df_test["source"]="test"
df_food=pd.concat([df_train,df_test])
df_food
# Out:
# C:\Users\vishwaraj\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#              CITY    COST                                       CUISINES  \
# 0           Thane  1200.0                    Malwani, Goan, North Indian
# 1         Chennai  1500.0                 Asian, Modern Indian, Japanese
# 2         Chennai   800.0     North Indian, Chinese, Biryani, Hyderabadi
# 3          Mumbai   800.0                               Tibetan, Chinese
# 4          Mumbai   300.0                                       Desserts
# ...           ...     ...                                            ...
# 4226    New Delhi     NaN                 North Indian, Mughlai, Chinese
# 4227    Bangalore     NaN  Biryani, North Indian, Sandwich, Salad, Wraps
# 4228    Faridabad     NaN                      Continental, North Indian
# 4229        Kochi     NaN                               Rolls, Beverages
# 4230  Bandra West     NaN                                        Mughlai
#
#               LOCALITY RATING  RESTAURANT_ID  \
# 0       Dombivali East    3.6           9438
# 1            Ramapuram    4.2          13198
# 2           Saligramam    3.8          10915
# 3          Bandra West    4.1           6346
# 4          Lower Parel    3.8          15387
# ...                ...    ...            ...
# 4226      Punjabi Bagh    3.9           9057
# 4227        HSR Layout    4.3           1247
# 4228         Sector 86    3.7           8617
# 4229             Kochi      -           6485
# 4230  Perry Cross Road    3.7           2421
#
#                                                    TIME              TITLE  \
# 0                11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)      CASUAL DINING
# 1                                  6pm – 11pm (Mon-Sun)  CASUAL DINING,BAR
# 2                   11am – 3:30pm, 7pm – 11pm (Mon-Sun)      CASUAL DINING
# 3                               11:30am – 1am (Mon-Sun)        QUICK BITES
# 4                                  11am – 1am (Mon-Sun)     DESSERT PARLOR
# ...                                                 ...                ...
# 4226                        11:30am – 11:30pm (Mon-Sun)      CASUAL DINING
# 4227                               11am – 1am (Mon-Sun)               None
# 4228                         9:30am – 10:30pm (Mon-Sun)        QUICK BITES
# 4229  11am – 11:30pm (Mon, Tue, Wed, Thu, Sat, Sun),...        QUICK BITES
# 4230                                5pm – 1am (Mon-Sun)        QUICK BITES
#
#           VOTES source
# 0      49 votes  train
# 1      30 votes  train
# 2     221 votes  train
# 3      24 votes  train
# 4     165 votes  train
# ...         ...    ...
# 4226  287 votes   test
# 4227  469 votes   test
# 4228   53 votes   test
# 4229        NaN   test
# 4230   63 votes   test
#
# [16921 rows x 10 columns]

# %%
#lets reset the index
df_food.reset_index(drop=True,inplace=True)

# %%
#displaying data
df_food
# Out:
#                       CITY    COST  \
# 0                    Thane  1200.0
# 1                  Chennai  1500.0
# 2                  Chennai   800.0
# 3                   Mumbai   800.0
# 4                   Mumbai   300.0
# 5                   Mumbai   800.0
# 6                Bangalore   600.0
# 7                  Gurgaon  1600.0
# 8                Bangalore   300.0
# 9                Hyderabad   200.0
# 10               Bangalore   900.0
# 11               Bangalore   800.0
# 12                   Kochi   600.0
# 13                   Kochi   400.0
# 14              Thane West   300.0
# 15               Hyderabad  1400.0
# 16                  Mumbai   900.0
# 17               Hyderabad   600.0
# 18     Andheri Lokhandwala   600.0
# 19               New Delhi   200.0
# 20               Hyderabad   350.0
# 21               New Delhi   500.0
# 22               New Delhi   450.0
# 23               Bangalore   600.0
# 24               New Delhi   700.0
# 25                   Kochi   400.0
# 26               Bangalore   700.0
# 27                 Chennai  1400.0
# 28                 Chennai  1000.0
# 29               Bangalore  1400.0
# ...                    ...     ...
# 16891              Gurgaon     NaN
# 16892              Chennai     NaN
# 16893              Chennai     NaN
# 16894              Chennai     NaN
# 16895            Bangalore     NaN
# 16896            New Delhi     NaN
# 16897              Chennai     NaN
# 16898               Mumbai     NaN
# 16899            Hyderabad     NaN
# 16900               Mumbai     NaN
# 16901            Hyderabad     NaN
# 16902               Mumbai     NaN
# 16903            Hyderabad     NaN
# 16904            Bangalore     NaN
# 16905               Mumbai     NaN
# 16906              Chennai     NaN
# 16907               Mumbai     NaN
# 16908            Bangalore     NaN
# 16909            Bangalore     NaN
# 16910               Mumbai     NaN
# 16911               Mumbai     NaN
# 16912            Bangalore     NaN
# 16913               Mumbai     NaN
# 16914            Bangalore     NaN
# 16915               Mumbai     NaN
# 16916            New Delhi     NaN
# 16917            Bangalore     NaN
# 16918            Faridabad     NaN
# 16919                Kochi     NaN
# 16920          Bandra West     NaN
#
#                                                 CUISINES  \
# 0                            Malwani, Goan, North Indian
# 1                         Asian, Modern Indian, Japanese
# 2             North Indian, Chinese, Biryani, Hyderabadi
# 3                                       Tibetan, Chinese
# 4                                               Desserts
# 5                North Indian, Chinese, Seafood, Biryani
# 6             Cafe, Chinese, Pizza, North Indian, Burger
# 7                                               Bar Food
# 8                             South Indian, North Indian
# 9                                           North Indian
# 10             North Indian, Chinese, Fast Food, Biryani
# 11                          Fast Food, Burger, Beverages
# 12                                      Arabian, Mughlai
# 13                                          South Indian
# 14                                         Maharashtrian
# 15                                     Parsi, Hyderabadi
# 16                               North Indian, Fast Food
# 17                     North Indian, Hyderabadi, Chinese
# 18                                         Chinese, Thai
# 19                              Bakery, Fast Food, Momos
# 20                                 Continental, European
# 21                            North Indian, Rolls, Momos
# 22               North Indian, Fast Food, Mughlai, Rolls
# 23                Andhra, Chinese, North Indian, Biryani
# 24                                Cafe, Italian, Chinese
# 25                                 Biryani, North Indian
# 26                            North Indian, Chinese, BBQ
# 27                                               Italian
# 28       Finger Food, North Indian, Continental, Italian
# 29         Finger Food, Continental, Asian, North Indian
# ...                                                  ...
# 16891                              Biryani, South Indian
# 16892                                 Biryani, Fast Food
# 16893                South Indian, Biryani, North Indian
# 16894                                             Bakery
# 16895                                   Bakery, Desserts
# 16896                European, Continental, North Indian
# 16897                South Indian, North Indian, Chinese
# 16898                              Chinese, North Indian
# 16899  Biryani, Chinese, Mughlai, North Indian, Hyder...
# 16900                     Chinese, North Indian, Mughlai
# 16901                         Fast Food, Bakery, Chinese
# 16902                                       North Indian
# 16903                North Indian, South Indian, Chinese
# 16904              Fast Food, North Indian, South Indian
# 16905                                Ice Cream, Desserts
# 16906                     Chinese, North Indian, Arabian
# 16907            European, Mediterranean, Italian, Sushi
# 16908                              North Indian, Biryani
# 16909                       Biryani, Hyderabadi, Chinese
# 16910  South Indian, North Indian, Fast Food, Chinese...
# 16911                     North Indian, Mughlai, Chinese
# 16912               North Indian, Chinese, Kebab, Juices
# 16913                                Sindhi, Street Food
# 16914                               Kerala, South Indian
# 16915                     North Indian, Mughlai, Chinese
# 16916                     North Indian, Mughlai, Chinese
# 16917      Biryani, North Indian, Sandwich, Salad, Wraps
# 16918                          Continental, North Indian
# 16919                                   Rolls, Beverages
# 16920                                            Mughlai
#
#                     LOCALITY RATING  RESTAURANT_ID  \
# 0             Dombivali East    3.6           9438
# 1                  Ramapuram    4.2          13198
# 2                 Saligramam    3.8          10915
# 3                Bandra West    4.1           6346
# 4                Lower Parel    3.8          15387
# 5            Vile Parle West    4.0           5618
# 6      Koramangala 6th Block    4.1           4383
# 7                  Sector 29    4.3           1249
# 8          Bannerghatta Road    3.9           7062
# 9               Dilsukhnagar    3.3          10109
# 10     Koramangala 5th Block    4.1             38
# 11               Indiranagar    4.0            844
# 12                Chullickal    3.4            938
# 13                 Edappally      -           4319
# 14                  Majiwada    4.0          15024
# 15             Jubilee Hills    4.5          12401
# 16             Borivali West    3.6           5254
# 17                    Nagole    3.5           8259
# 18       Andheri Lokhandwala    3.6           4009
# 19             Krishna Nagar    4.1          11841
# 20               Hitech City    4.2           6465
# 21                Karol Bagh    4.0           1048
# 22                       SDA    4.0          12499
# 23              Thippasandra    3.9          10412
# 24                    Dwarka    4.2           2389
# 25                  Kakkanad    3.8           6551
# 26                       HSR    3.4          13446
# 27                Vadapalani    4.1          10277
# 28               Neelangarai    4.3           4222
# 29     Koramangala 5th Block    4.2           6577
# ...                      ...    ...            ...
# 16891              Sector 37    3.5          13547
# 16892        Thousand Lights    4.2           9386
# 16893           Thuraipakkam    4.1          12971
# 16894              Perungudi    3.2          15219
# 16895           New BEL Road    3.8            141
# 16896         Rajendra Place    4.2           4325
# 16897             K.K. Nagar    3.4           6158
# 16898                  Worli    3.6          11799
# 16899               Kondapur    4.0           4992
# 16900         Santacruz East    3.3          11680
# 16901               Ameerpet    3.2           2943
# 16902              Kalbadevi    4.0           6204
# 16903              Manikonda    2.6          14205
# 16904               JP Nagar    3.7          10521
# 16905                  Powai    4.3           6448
# 16906               Tambaram    3.6            499
# 16907                   Juhu    4.1          14508
# 16908              Jalahalli    3.3          11667
# 16909           Malleshwaram    4.1           6412
# 16910            Mulund West    3.9           6199
# 16911          Goregaon East    3.6           3265
# 16912               JP Nagar    3.8           6973
# 16913            Lower Parel    NEW           6887
# 16914            Indiranagar    3.8            331
# 16915             Grant Road    4.0           1670
# 16916           Punjabi Bagh    3.9           9057
# 16917             HSR Layout    4.3           1247
# 16918              Sector 86    3.7           8617
# 16919                  Kochi      -           6485
# 16920       Perry Cross Road    3.7           2421
#
#                                                     TIME  \
# 0                 11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)
# 1                                   6pm – 11pm (Mon-Sun)
# 2                    11am – 3:30pm, 7pm – 11pm (Mon-Sun)
# 3                                11:30am – 1am (Mon-Sun)
# 4                                   11am – 1am (Mon-Sun)
# 5                             12noon – 12:30AM (Mon-Sun)
# 6      12noon – 11:30pm (Mon, Tue, Thu, Fri, Sat, Sun...
# 7                                    1pm – 1am (Mon-Sun)
# 8                                7am – 10:30pm (Mon-Sun)
# 9                    11am – 2pm, 4pm – 10:30pm (Mon-Sun)
# 10                           12:30pm – 12:30AM (Mon-Sun)
# 11      11am – 12:15AM (Mon, Tue, Wed, Thu, Fri, Sun)...
# 12                                 11am – 11pm (Mon-Sun)
# 13                              11am – 11:30pm (Mon-Sun)
# 14                    Closed (Mon),11am – 11pm (Tue-Sun)
# 15        11:30am – 11:30pm (Mon, Tue, Wed, Thu, Sun)...
# 16                         7:30am – 12midnight (Mon-Sun)
# 17                           11am – 12midnight (Mon-Sun)
# 18                              11am – 11:45pm (Mon-Sun)
# 19                     Closed (Mon),9am – 10pm (Tue-Sun)
# 20                               9:30am – 10pm (Mon-Sun)
# 21                           10:30am – 11:30pm (Mon-Sun)
# 22                                  11am – 3am (Mon-Sun)
# 23                   11am – 3:30pm, 7pm – 11pm (Mon-Sun)
# 24                                 11am – 11pm (Mon-Sun)
# 25                               12noon – 11pm (Mon-Sun)
# 26         12:30pm – 11pm (Mon-Thu),12:30pm – 11:30pm...
# 27       Closed (Mon),12noon – 3pm, 6pm – 11pm (Tue-Sun)
# 28                                 11am – 11pm (Mon-Sun)
# 29                               12:30pm – 1am (Mon-Sun)
# ...                                                  ...
# 16891                               7am – 11pm (Mon-Sun)
# 16892                              11am – 11pm (Mon-Sun)
# 16893  12noon – 3:30pm, 7:30pm – 11pm (Mon-Fri),12noo...
# 16894                              10am – 10pm (Mon-Sun)
# 16895                              11am – 11pm (Mon-Sun)
# 16896                                 24 Hours (Mon-Sun)
# 16897                               7am – 11pm (Mon-Sun)
# 16898                     11:30am – 12midnight (Mon-Sun)
# 16899                               10am – 2am (Mon-Sun)
# 16900             11am – 4pm, 7pm – 12midnight (Mon-Sun)
# 16901                                8am – 4am (Mon-Sun)
# 16902              Closed (Mon),10am – 11:45pm (Tue-Sun)
# 16903                              11am – 11pm (Mon-Sun)
# 16904                               8am – 10pm (Mon-Sun)
# 16905                           11am – 12:30AM (Mon-Sun)
# 16906                           11:30am – 11pm (Mon-Sun)
# 16907   7pm – 1:30am (Mon-Tue),12noon – 1:30am (Wed-Sun)
# 16908                        12:30pm – 10:15pm (Mon-Sun)
# 16909                        11:30am – 11:30pm (Mon-Sun)
# 16910                               7am – 10pm (Mon-Sun)
# 16911                                9am – 1am (Mon-Sun)
# 16912                 12noon – 4pm, 7pm – 11pm (Mon-Sun)
# 16913             11:30am – 4pm, 7pm – 11:30pm (Mon-Sun)
# 16914  12noon – 4pm, 7pm – 10:30pm (Mon-Sat),12noon –...
# 16915  6am – 12:30AM (Mon, Tue, Wed, Thu, Sat, Sun), ...
# 16916                        11:30am – 11:30pm (Mon-Sun)
# 16917                               11am – 1am (Mon-Sun)
# 16918                         9:30am – 10:30pm (Mon-Sun)
# 16919  11am – 11:30pm (Mon, Tue, Wed, Thu, Sat, Sun),...
# 16920                                5pm – 1am (Mon-Sun)
#
#                            TITLE       VOTES source
# 0                  CASUAL DINING    49 votes  train
# 1              CASUAL DINING,BAR    30 votes  train
# 2                  CASUAL DINING   221 votes  train
# 3                    QUICK BITES    24 votes  train
# 4                 DESSERT PARLOR   165 votes  train
# 5                  CASUAL DINING   550 votes  train
# 6                           CAFÉ   509 votes  train
# 7                   MICROBREWERY  1612 votes  train
# 8                    QUICK BITES   101 votes  train
# 9                    QUICK BITES   219 votes  train
# 10                 CASUAL DINING   244 votes  train
# 11     QUICK BITES,BEVERAGE SHOP   274 votes  train
# 12                 CASUAL DINING    15 votes  train
# 13                 CASUAL DINING         NaN  train
# 14                   QUICK BITES   160 votes  train
# 15      CASUAL DINING,IRANI CAFE  2499 votes  train
# 16                 CASUAL DINING   319 votes  train
# 17                 CASUAL DINING   121 votes  train
# 18                 CASUAL DINING   535 votes  train
# 19            BAKERY,QUICK BITES   350 votes  train
# 20                 CASUAL DINING   400 votes  train
# 21                   QUICK BITES  1327 votes  train
# 22                          None  1191 votes  train
# 23                 CASUAL DINING   533 votes  train
# 24                          CAFÉ   493 votes  train
# 25                   QUICK BITES   372 votes  train
# 26                 CASUAL DINING   105 votes  train
# 27             BAR,CASUAL DINING   178 votes  train
# 28                           BAR   150 votes  train
# 29                           PUB  2456 votes  train
# ...                          ...         ...    ...
# 16891                QUICK BITES    22 votes   test
# 16892                QUICK BITES   232 votes   test
# 16893                QUICK BITES  1697 votes   test
# 16894                     BAKERY    31 votes   test
# 16895                     BAKERY    26 votes   test
# 16896                FINE DINING   749 votes   test
# 16897                QUICK BITES    26 votes   test
# 16898              CASUAL DINING   251 votes   test
# 16899              CASUAL DINING   125 votes   test
# 16900              CASUAL DINING   312 votes   test
# 16901         QUICK BITES,BAKERY  1246 votes   test
# 16902              CASUAL DINING   371 votes   test
# 16903              CASUAL DINING    62 votes   test
# 16904                QUICK BITES   174 votes   test
# 16905             DESSERT PARLOR  1265 votes   test
# 16906                QUICK BITES   171 votes   test
# 16907          BAR,CASUAL DINING  1239 votes   test
# 16908                       None     6 votes   test
# 16909              CASUAL DINING   226 votes   test
# 16910              CASUAL DINING   197 votes   test
# 16911              CASUAL DINING   441 votes   test
# 16912                QUICK BITES   245 votes   test
# 16913              CASUAL DINING         NaN   test
# 16914                QUICK BITES   410 votes   test
# 16915                QUICK BITES   197 votes   test
# 16916              CASUAL DINING   287 votes   test
# 16917                       None   469 votes   test
# 16918                QUICK BITES    53 votes   test
# 16919                QUICK BITES         NaN   test
# 16920                QUICK BITES    63 votes   test
#
# [16921 rows x 10 columns]

# %%
#chceking the datatypes
df_food.dtypes
# Out:
# CITY              object
# COST             float64
# CUISINES          object
# LOCALITY          object
# RATING            object
# RESTAURANT_ID      int64
# TIME              object
# TITLE             object
# VOTES             object
# source            object
# dtype: object

# %%
for col in df_food.columns:
    if df_food[col].dtype=="object":
        print(df_food[col].value_counts())
        print()
# Out:
# Chennai           2855
# Bangalore         2835
# Hyderabad         2458
# Mumbai            2311
# New Delhi         1754
#                   ...
# Mira raod east       1
# Chennai-600008       1
# Maharashtra.         1
# Vasai Mumbai         1
# Mumbai 400015        1
# Name: CITY, Length: 450, dtype: int64
#
# North Indian                                                                716
# North Indian, Chinese                                                       714
# South Indian                                                                706
# Fast Food                                                                   364
# Chinese                                                                     226
#                                                                            ...
# Seafood, Chinese, North Indian, Mangalorean                                   1
# Singaporean, Malaysian, Chinese, Asian, Thai, Momos                           1
# Chinese, Fast Food, Bakery                                                    1
# Italian, Pizza, Desserts, Beverages                                           1
# Continental, South Indian, North Indian, Italian, Mediterranean, Chinese      1
# Name: CUISINES, Length: 5183, dtype: int64
#
# Gachibowli                                        216
# Indiranagar                                       187
# Kakkanad                                          175
# Kukatpally                                        171
# Madhapur                                          169
#                                                  ...
# Sector 82                                           1
# Mogappair West                                      1
# Mettuguda                                           1
# Goregaon                                            1
# Opposite State Bank of India Gachibowli branch      1
# Name: LOCALITY, Length: 1636, dtype: int64
#
# 3.9    1643
# 3.8    1604
# 4.0    1498
# 3.7    1437
# 3.6    1261
# 4.1    1217
# 3.5     988
# 4.2     968
# NEW     930
# 3.4     777
# 4.3     740
# -       672
# 3.3     485
# 4.4     484
# 3.2     349
# 4.5     274
# 3.1     263
# 2.9     242
# 3.0     229
# 2.8     191
# 4.6     184
# 2.7     129
# 4.7      90
# 2.6      85
# 2.5      51
# 4.8      49
# 4.9      28
# 2.4      24
# 2.3      15
# 2.1       4
# 2.2       4
# 2.0       2
# Name: RATING, dtype: int64
#
# 11am – 11pm (Mon-Sun)                                    1862
# 12noon – 12midnight (Mon-Sun)                             615
# 12noon – 11pm (Mon-Sun)                                   541
# 11am – 12midnight (Mon-Sun)                               419
# 10am – 10pm (Mon-Sun)                                     288
#                                                          ...
# 5:30pm – 11:45pm (Mon, Tue, Wed, Thu, Sun), 5:30pm...       1
# 11:30am – 3:30pm, 7:30pm – 10:45pm (Mon-Sun)                1
# 12noon – 3:30pm, 7pm – 11pm (Mon, Tue, Wed, Thu...          1
# 11:30am – 4pm (Mon-Fri),11:30am – 10:30pm...                1
# 12midnight – 4am, 11am – 12midnight (Mon-Sun)               1
# Name: TIME, Length: 3295, dtype: int64
#
# QUICK BITES                 5634
# CASUAL DINING               4910
# None                        1287
# CAFÉ                         830
# DESSERT PARLOR               508
#                             ...
# MICROBREWERY,LOUNGE            1
# QUICK BITES,MEAT SHOP          1
# BEVERAGE SHOP,FOOD COURT       1
# FINE DINING,MICROBREWERY       1
# IRANI CAFE,BAKERY              1
# Name: TITLE, Length: 123, dtype: int64
#
# 44 votes      92
# 22 votes      88
# 6 votes       87
# 29 votes      83
# 24 votes      81
#               ..
# 2171 votes     1
# 2457 votes     1
# 1108 votes     1
# 2030 votes     1
# 7346 votes     1
# Name: VOTES, Length: 2075, dtype: int64
#
# train    12690
# test      4231
# Name: source, dtype: int64

# %%
#Lets chcek null values
df_food.isnull().sum()
# Out:
# CITY              147
# COST             4231
# CUISINES            0
# LOCALITY          128
# RATING              4
# RESTAURANT_ID       0
# TIME                0
# TITLE               0
# VOTES            1606
# source              0
# dtype: int64

# %%
#lets chcek all the rows where votes are null
df_food.loc[df_food["VOTES"].isnull()]
#So we can say there is a pattern where ever resturant is new and rating is missing there are no votes
#We can impute votes by 0 as for new resurants or missing rating its logical to have no votes
# Out:
#             CITY   COST                            CUISINES       LOCALITY  \
# 13         Kochi  400.0                        South Indian      Edappally
# 62         Kochi  200.0             North Indian, Beverages    Kalamassery
# 69     New Delhi  200.0                    Pizza, Fast Food        Kalkaji
# 85     Bangalore  300.0          North Indian, South Indian    Vijay Nagar
# 111       Mumbai  800.0  Gujarati, Rajasthani, North Indian  Borivali West
# ...          ...    ...                                 ...            ...
# 16873      Noida    NaN                  Cafe, North Indian      Sector 63
# 16875  New Delhi    NaN                           Fast Food  Shalimar Bagh
# 16888  Bangalore    NaN                         Continental    Indiranagar
# 16913     Mumbai    NaN                 Sindhi, Street Food    Lower Parel
# 16919      Kochi    NaN                    Rolls, Beverages          Kochi
#
#       RATING  RESTAURANT_ID  \
# 13         -           4319
# 62       NEW           7841
# 69       NEW          11096
# 85         -          12657
# 111      NEW           7095
# ...      ...            ...
# 16873    NEW           7007
# 16875    NEW           6387
# 16888    NEW          13381
# 16913    NEW           6887
# 16919      -           6485
#
#                                                     TIME          TITLE VOTES  \
# 13                              11am – 11:30pm (Mon-Sun)  CASUAL DINING   NaN
# 62                                 11am – 11pm (Mon-Sun)    QUICK BITES   NaN
# 69                                 11am – 11pm (Mon-Sun)           None   NaN
# 85               Closed (Mon),7:30am – 10:30pm (Tue-Sun)    QUICK BITES   NaN
# 111               11:30am – 3:30pm, 7pm – 11pm (Mon-Sun)  CASUAL DINING   NaN
# ...                                                  ...            ...   ...
# 16873                              11am – 11pm (Mon-Sun)           CAFÉ   NaN
# 16875                        12:30pm – 10:30pm (Mon-Sun)    QUICK BITES   NaN
# 16888                        11am – 12midnight (Mon-Sun)    QUICK BITES   NaN
# 16913             11:30am – 4pm, 7pm – 11:30pm (Mon-Sun)  CASUAL DINING   NaN
# 16919  11am – 11:30pm (Mon, Tue, Wed, Thu, Sat, Sun),...    QUICK BITES   NaN
#
#       source
# 13     train
# 62     train
# 69     train
# 85     train
# 111    train
# ...      ...
# 16873   test
# 16875   test
# 16888   test
# 16913   test
# 16919   test
#
# [1606 rows x 10 columns]

# %%
#Imputing missing cells in votes column
df_food["VOTES"].fillna(0,inplace=True)

# %%
#Lets again chcek the null values
df_food.isnull().sum()
# Out:
# CITY              147
# COST             4231
# CUISINES            0
# LOCALITY          128
# RATING              4
# RESTAURANT_ID       0
# TIME                0
# TITLE               0
# VOTES               0
# source              0
# dtype: int64

# %%
#chceking value counts for "RATING"
df_food["RATING"].value_counts()
# Out:
# 3.9    1643
# 3.8    1604
# 4.0    1498
# 3.7    1437
# 3.6    1261
# 4.1    1217
# 3.5     988
# 4.2     968
# NEW     930
# 3.4     777
# 4.3     740
# -       672
# 3.3     485
# 4.4     484
# 3.2     349
# 4.5     274
# 3.1     263
# 2.9     242
# 3.0     229
# 2.8     191
# 4.6     184
# 2.7     129
# 4.7      90
# 2.6      85
# 2.5      51
# 4.8      49
# 4.9      28
# 2.4      24
# 2.3      15
# 2.2       4
# 2.1       4
# 2.0       2
# Name: RATING, dtype: int64

# %%
#where resurant are NEW and - we will replace by 0 and  and also null values by 0
#By doing this column can be interpretted as numeric
df_food["RATING"].replace("NEW",0,inplace=True)
df_food["RATING"].replace("-",0,inplace=True)
df_food["RATING"].fillna(0,inplace=True)

# %%
#So rating column has been imputed
df_food["RATING"].isnull().sum()
# Out:
# 0

# %%
#Lets change the datatypes of"RATING" to float
df_food["RATING"]=df_food["RATING"].astype(float)

# %%
#If we closely look at the"VOTES" column it can be conveted to int by stripping off "votes" string wherever present
df_food["VOTES"].loc[df_food["VOTES"].str[-5:]=="votes"]=df_food["VOTES"].loc[df_food["VOTES"]
                                                                              .str[-5:]=="votes"].str.rstrip("votes")
# Out:
# C:\Users\vishwaraj\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#lets now convert the "VOTES" column to int
df_food["VOTES"]=df_food["VOTES"].astype(int)

# %%
#Lets chcek the datatypes
df_food.dtypes
#We have converted "RATING" and "VOTES" float and int respectively
# Out:
# CITY              object
# COST             float64
# CUISINES          object
# LOCALITY          object
# RATING           float64
# RESTAURANT_ID      int64
# TIME              object
# TITLE             object
# VOTES              int32
# source            object
# dtype: object

# %%
#Lets chcek null values
df_food.isnull().sum()
#From below we have still "CITY" and "LOCALITY" to be imputed
# Out:
# CITY              147
# COST             4231
# CUISINES            0
# LOCALITY          128
# RATING              0
# RESTAURANT_ID       0
# TIME                0
# TITLE               0
# VOTES               0
# source              0
# dtype: int64

# %%
#lets chcek where city is null
df_food.loc[df_food["CITY"].isnull()]
#By seeing the data we come to know in most of the rows when city is NAN LOCALITY is also NAN
#So we will impute both columns with "missing" when ever both we will encounter as NaN
# Out:
#       CITY    COST                                           CUISINES  \
# 129    NaN   500.0   North Indian, South Indian, Chinese, Continental
# 246    NaN   300.0                                            Biryani
# 411    NaN   600.0    North Indian, Chinese, Pizza, Burger, Fast Food
# 466    NaN   200.0                                       North Indian
# 481    NaN   250.0                                        Street Food
# 534    NaN   600.0                        Healthy Food, Salad, Juices
# 668    NaN   400.0                     North Indian, Mughlai, Chinese
# 788    NaN   500.0                  North Indian, BBQ, Biryani, Kebab
# 817    NaN  1200.0  Thai, Chinese, Continental, North Indian, Italian
# 826    NaN   500.0                  Burger, Pizza, Fast Food, Italian
# 827    NaN   400.0                                    Fast Food, Cafe
# 997    NaN   400.0  North Indian, Mughlai, Biryani, Kebab, Rajasthani
# 1012   NaN   400.0                              North Indian, Chinese
# 1135   NaN   800.0         Biryani, North Indian, Mughlai, Rajasthani
# 1219   NaN   450.0                                            Chinese
# 1314   NaN   700.0                                              Pizza
# 1386   NaN   600.0                              North Indian, Chinese
# 1613   NaN   200.0                                   Bakery, Desserts
# 1615   NaN   500.0                 North Indian, Bengali, Continental
# 1692   NaN   500.0                                               Cafe
# 1759   NaN  3000.0        Continental, North Indian, Italian, Chinese
# 1791   NaN   400.0                                   Bakery, Desserts
# 1795   NaN   200.0                                       North Indian
# 1945   NaN   200.0                                           Sandwich
# 1951   NaN   150.0                       Juices, Beverages, Fast Food
# 2313   NaN   150.0                                   Bakery, Desserts
# 2524   NaN   450.0             Pizza, Burger, Fast Food, North Indian
# 2568   NaN   600.0                 North Indian, Chinese, Continental
# 2571   NaN   700.0                                   Pizza, Fast Food
# 2844   NaN   600.0                   Fast Food, North Indian, Chinese
# ...    ...     ...                                                ...
# 13031  NaN     NaN                                 Fast Food, Mexican
# 13183  NaN     NaN                 North Indian, Chinese, Continental
# 13383  NaN     NaN                     Beverages, Desserts, Fast Food
# 13400  NaN     NaN                     Arabian, North Indian, Chinese
# 13534  NaN     NaN                   Andhra, Hyderabadi, North Indian
# 13591  NaN     NaN                                   Biryani, Mughlai
# 13728  NaN     NaN         Fast Food, Pizza, Burger, Beverages, Rolls
# 14044  NaN     NaN                     North Indian, Chinese, Mughlai
# 14096  NaN     NaN            North Indian, Chinese, Fast Food, Momos
# 14147  NaN     NaN                                       North Indian
# 14411  NaN     NaN              North Indian, Mughlai, Biryani, Kebab
# 14447  NaN     NaN                                     Italian, Pizza
# 14591  NaN     NaN                                       Healthy Food
# 14747  NaN     NaN  Continental, Asian, Healthy Food, Burger, Biry...
# 14794  NaN     NaN                                    Awadhi, Chinese
# 14874  NaN     NaN                                Desserts, Ice Cream
# 15191  NaN     NaN                     North Indian, Mughlai, Biryani
# 15434  NaN     NaN          North Indian, Mughlai, Chinese, Fast Food
# 15632  NaN     NaN                     Mughlai, North Indian, Biryani
# 15678  NaN     NaN                                               Cafe
# 16059  NaN     NaN  Cafe, Arabian, Continental, Turkish, Fast Food...
# 16134  NaN     NaN                            Biryani, Kebab, Mughlai
# 16218  NaN     NaN                       Bengali, Fast Food, Desserts
# 16246  NaN     NaN                 Street Food, North Indian, Chinese
# 16250  NaN     NaN                                   Biryani, Mughlai
# 16311  NaN     NaN                     Continental, Mexican, American
# 16313  NaN     NaN       North Indian, South Indian, Chinese, Biryani
# 16803  NaN     NaN                Fast Food, Italian, Pizza, Sandwich
# 16815  NaN     NaN                              Chinese, North Indian
# 16857  NaN     NaN                                           Lebanese
#
#                      LOCALITY  RATING  RESTAURANT_ID  \
# 129                       NaN     3.6           9101
# 246        Palarivattom Kochi     3.4          14502
# 411                       NaN     4.0           6313
# 466                       NaN     4.2           1133
# 481                       NaN     3.7           4788
# 534                       NaN     3.6           3233
# 668                       NaN     4.1           1707
# 788                       NaN     0.0          14685
# 817    shop 7 shikrupa socity     4.1           1042
# 826                       NaN     4.6            102
# 827                       NaN     4.0          11204
# 997                       NaN     4.0          14615
# 1012                      NaN     3.5          13730
# 1135                      NaN     4.4          11208
# 1219                      NaN     0.0           5415
# 1314                      NaN     4.2          10376
# 1386                      NaN     4.2             59
# 1613                      NaN     3.6          12906
# 1615                      NaN     3.5           8883
# 1692                      NaN     3.7           3371
# 1759                      NaN     4.2           2397
# 1791                      NaN     0.0          14902
# 1795                      NaN     3.3          14890
# 1945                      NaN     3.7          11627
# 1951                      NaN     3.5          11704
# 2313                      NaN     0.0           2764
# 2524                      NaN     4.1           9109
# 2568                      NaN     4.0           7704
# 2571                      NaN     4.2           9121
# 2844                      NaN     3.6          11756
# ...                       ...     ...            ...
# 13031                     NaN     4.6           7993
# 13183                     NaN     4.5          14472
# 13383                     NaN     3.5          14033
# 13400                 Chennai     3.4            451
# 13534                     NaN     3.3          12667
# 13591                     NaN     0.0          11123
# 13728                     NaN     3.5           1227
# 14044  Jaipuria Sunrise Plaza     3.9          14152
# 14096                     NaN     4.8           4780
# 14147                     NaN     3.6           9122
# 14411                     NaN     4.2           6974
# 14447                     NaN     4.6          11035
# 14591                     NaN     3.8           3594
# 14747                     NaN     3.8           4898
# 14794                     NaN     4.5           8915
# 14874                     NaN     3.8           4869
# 15191                     NaN     4.8          14839
# 15434                     NaN     3.7          10864
# 15632                     NaN     4.3          13562
# 15678                     NaN     4.0           2141
# 16059                     NaN     4.1           5400
# 16134                     NaN     3.9          15436
# 16218                     NaN     0.0          10944
# 16246                     NaN     3.5           5102
# 16250                     NaN     2.8           7282
# 16311      Maharashtra 400013     4.0           9779
# 16313                     NaN     3.5           5922
# 16803                     NaN     3.7           4748
# 16815                     NaN     3.5           8587
# 16857                 Chennai     3.7          12015
#
#                                                     TIME              TITLE  \
# 129                    12noon – 3pm, 7pm – 2am (Mon-Sun)               None
# 246                              12noon – 11pm (Mon-Sun)        QUICK BITES
# 411                                  7pm – 4am (Mon-Sun)               None
# 466                                  4pm – 9pm (Mon-Sun)               None
# 481      11am – 11pm (Mon),9:30am – 12midnight (Tue-Sun)               None
# 534                                11am – 10pm (Mon-Sun)               None
# 668                               12noon – 1am (Mon-Sun)               None
# 788                12noon – 4pm, 7pm – 11:30pm (Mon-Sun)               None
# 817                        12noon – 12midnight (Mon-Sun)      CASUAL DINING
# 826           6pm – 4am (Mon-Fri),12noon – 4am (Sat-Sun)               None
# 827                                  9am – 4am (Mon-Sun)               None
# 997    11am – 3:30pm, 6:30pm – 10:30pm (Mon-Fri),11am...      CASUAL DINING
# 1012                   12noon – 4pm, 7pm – 2am (Mon-Sun)               None
# 1135                                11am – 1am (Mon-Sun)               None
# 1219                               11am – 11pm (Mon-Sun)               None
# 1314                             12noon – 10pm (Mon-Sun)               None
# 1386                              12noon – 4am (Mon-Sun)               None
# 1613                               10am – 10pm (Mon-Sun)     DESSERT PARLOR
# 1615                              12noon – 2am (Mon-Sun)        QUICK BITES
# 1692                                  24 Hours (Mon-Sun)               CAFÉ
# 1759                             6:30am – 11pm (Mon-Sun)  CASUAL DINING,BAR
# 1791                                 9am – 8pm (Mon-Sun)               None
# 1795                               10am – 10pm (Mon-Sun)               None
# 1945                                8am – 11pm (Mon-Sun)               None
# 1951                               11am – 11pm (Mon-Sun)      BEVERAGE SHOP
# 2313                                       Not Available             BAKERY
# 2524                                 7pm – 5am (Mon-Sun)               None
# 2568    12midnight – 8am, 11:45am – 12midnight (Mon-Sun)               None
# 2571                                 6pm – 2am (Mon-Sun)               None
# 2844                               11am – 11pm (Mon-Sun)        QUICK BITES
# ...                                                  ...                ...
# 13031           12noon – 3pm, 7pm – 12midnight (Mon-Sun)               None
# 13183       12midnight – 4am, 7pm – 12midnight (Mon-Sun)               None
# 13383                              11am – 11pm (Mon-Sun)               None
# 13400              12noon – 3pm, 5:30pm – 11pm (Mon-Sun)        QUICK BITES
# 13534             11am – 3:30pm, 7pm – 10:30pm (Mon-Sun)        QUICK BITES
# 13591                             12noon – 1am (Mon-Sun)               None
# 13728                                 24 Hours (Mon-Sun)        QUICK BITES
# 14044                11:30am – 4pm, 5pm – 11pm (Mon-Sun)        QUICK BITES
# 14096                              11am – 11pm (Mon-Sun)               None
# 14147                         8am – 12midnight (Mon-Sun)        QUICK BITES
# 14411                      12noon – 12midnight (Mon-Sun)               None
# 14447         6pm – 4am (Mon-Fri),12noon – 4am (Sat-Sun)               None
# 14591     8am – 12midnight (Mon-Fri),8am – 1am (Sat-Sun)               None
# 14747                            8:45am – 11pm (Mon-Sun)               None
# 14794                     11:30am – 12midnight (Mon-Sun)               None
# 14874    12midnight – 1am, 1pm – 12midnight (Mon, Wed...     DESSERT PARLOR
# 15191          11:30am – 3:30pm, 6pm – 11:30pm (Mon-Sun)               None
# 15434                             12noon – 1am (Mon-Sun)      CASUAL DINING
# 15632                              11am – 11pm (Mon-Sun)      CASUAL DINING
# 15678                              11am – 10pm (Mon-Sun)               CAFÉ
# 16059  12noon – 12midnight (Mon-Fri),8:30am – 11:58pm...               CAFÉ
# 16134                      12noon – 12midnight (Mon-Sun)               None
# 16218   11am – 3:30pm, 7pm – 11:30pm (Mon-Thu),11am –...               None
# 16246                              11am – 11pm (Mon-Sun)               None
# 16250                              11am – 11pm (Mon-Sun)               None
# 16311                             5pm – 1:30am (Mon-Sun)  PUB,CASUAL DINING
# 16313                            6am – 11:30pm (Mon-Sun)      CASUAL DINING
# 16803                                1pm – 8am (Mon-Sun)               None
# 16815   11:45am – 3:30pm, 7:30pm – 11:40pm (Mon, Sat)...        QUICK BITES
# 16857                               4pm – 11pm (Mon-Sun)        QUICK BITES
#
#        VOTES source
# 129      728  train
# 246       82  train
# 411       29  train
# 466       55  train
# 481      616  train
# 534       30  train
# 668      152  train
# 788        0  train
# 817      486  train
# 826      230  train
# 827      254  train
# 997      420  train
# 1012      23  train
# 1135    1074  train
# 1219       0  train
# 1314     106  train
# 1386      61  train
# 1613      15  train
# 1615     115  train
# 1692     135  train
# 1759     213  train
# 1791       0  train
# 1795      81  train
# 1945      90  train
# 1951      57  train
# 2313       0  train
# 2524     601  train
# 2568     284  train
# 2571     283  train
# 2844     199  train
# ...      ...    ...
# 13031    115   test
# 13183    177   test
# 13383     13   test
# 13400     69   test
# 13534    430   test
# 13591      0   test
# 13728     43   test
# 14044    362   test
# 14096    109   test
# 14147     27   test
# 14411    306   test
# 14447    225   test
# 14591     42   test
# 14747    753   test
# 14794    224   test
# 14874    139   test
# 15191    128   test
# 15434    680   test
# 15632   1119   test
# 15678    119   test
# 16059    575   test
# 16134     65   test
# 16218      0   test
# 16246     30   test
# 16250     26   test
# 16311   1142   test
# 16313    102   test
# 16803     27   test
# 16815     25   test
# 16857    124   test
#
# [147 rows x 10 columns]

# %%
#imputing both "LOCALITY" and "CITY" columns with "missing" when ever both are nan
import numpy as np
import math
#math.isnan(df_food["CITY"].iloc[129])
null_city_indexes=df_food.loc[df_food["CITY"].isnull()].index
for index in null_city_indexes :
    try:
        if math.isnan(df_food["CITY"].iloc[index]) and math.isnan(df_food["LOCALITY"].iloc[index]):
            df_food["CITY"].iloc[index]="missing"
            df_food["LOCALITY"].iloc[index]="missing"
    except:
        pass

# %%
#lets again chcek the null values
df_food.isnull().sum()
#So we see number null values in the column "CITY" AND "LOCALITY" reduced significantly
# Out:
# CITY               20
# COST             4231
# CUISINES            0
# LOCALITY            1
# RATING              0
# RESTAURANT_ID       0
# TIME                0
# TITLE               0
# VOTES               0
# source              0
# dtype: int64

# %%
#lets chcek where city is null
df_food.loc[df_food["CITY"].isnull()]
#We see in most of the rows in LOCALITY city name is mentioned
# Out:
#       CITY    COST                                           CUISINES  \
# 246    NaN   300.0                                            Biryani
# 817    NaN  1200.0  Thai, Chinese, Continental, North Indian, Italian
# 5149   NaN   400.0                     Beverages, Ice Cream, Desserts
# 5297   NaN  1000.0                                        Continental
# 6397   NaN   950.0  Cafe, American, Asian, Bakery, Biryani, Chines...
# 6451   NaN   400.0                                             Bakery
# 8456   NaN   150.0                               Fast Food, Beverages
# 8735   NaN   400.0                                    Chinese, Burger
# 9121   NaN  1500.0  Finger Food, American, Continental, Burger, Pizza
# 9268   NaN   200.0                                           Lebanese
# 10200  NaN   300.0  North Indian, Chinese, Sandwich, Street Food, ...
# 10704  NaN   650.0                             Continental, Fast Food
# 11491  NaN   500.0                     Arabian, North Indian, Chinese
# 12314  NaN   650.0                              North Indian, Bengali
# 12447  NaN   350.0            North Indian, Chinese, Mughlai, Seafood
# 12859  NaN     NaN                              North Indian, Chinese
# 13400  NaN     NaN                     Arabian, North Indian, Chinese
# 14044  NaN     NaN                     North Indian, Chinese, Mughlai
# 16311  NaN     NaN                     Continental, Mexican, American
# 16857  NaN     NaN                                           Lebanese
#
#                                                 LOCALITY  RATING  \
# 246                                   Palarivattom Kochi     3.4
# 817                               shop 7 shikrupa socity     4.1
# 5149                                         Navi Mumbai     3.8
# 5297                                               Kochi     3.4
# 6397                                             Alibaug     4.2
# 6451                                             Chennai     3.5
# 8456                                           Mathikere     3.7
# 8735                                             Chennai     3.8
# 9121                                           Bangalore     3.9
# 9268                                               Kochi     3.4
# 10200                                             Kalyan     3.5
# 10704                                            Chennai     4.0
# 11491                                            Chennai     3.0
# 12314  Opposite to corporation bank and LIC office ba...     4.3
# 12447                                          Hyderabad     3.1
# 12859                                            Chennai     3.5
# 13400                                            Chennai     3.4
# 14044                             Jaipuria Sunrise Plaza     3.9
# 16311                                 Maharashtra 400013     4.0
# 16857                                            Chennai     3.7
#
#        RESTAURANT_ID                                             TIME  \
# 246            14502                          12noon – 11pm (Mon-Sun)
# 817             1042                    12noon – 12midnight (Mon-Sun)
# 5149            7264                            11am – 11pm (Mon-Sun)
# 5297            1030                               24 Hours (Mon-Sun)
# 6397            7334                           9am – 9:30pm (Mon-Sun)
# 6451            2595                            10am – 10pm (Mon-Sun)
# 8456           12367                          9:30am – 11pm (Mon-Sun)
# 8735           15526                            11am – 11pm (Mon-Sun)
# 9121            9800                             11am – 1am (Mon-Sun)
# 9268           12021                            11am – 11pm (Mon-Sun)
# 10200           1433  7:30am – 12midnight (Mon, Tue, Wed, Thu, Sat...
# 10704           5552                    12noon – 12midnight (Mon-Sun)
# 11491            954                            11am – 11pm (Mon-Sun)
# 12314          11724              11am – 3:30pm, 7pm – 11pm (Mon-Sun)
# 12447           7314                   12:30pm – 12midnight (Mon-Sun)
# 12859          10663                            11am – 11pm (Mon-Sun)
# 13400            451            12noon – 3pm, 5:30pm – 11pm (Mon-Sun)
# 14044          14152              11:30am – 4pm, 5pm – 11pm (Mon-Sun)
# 16311           9779                           5pm – 1:30am (Mon-Sun)
# 16857          12015                             4pm – 11pm (Mon-Sun)
#
#                               TITLE  VOTES source
# 246                     QUICK BITES     82  train
# 817                   CASUAL DINING    486  train
# 5149   BEVERAGE SHOP,DESSERT PARLOR    163  train
# 5297                  CASUAL DINING     19  train
# 6397                           CAFÉ    253  train
# 6451                         BAKERY     10  train
# 8456                    QUICK BITES     28  train
# 8735                  CASUAL DINING    284  train
# 9121              PUB,CASUAL DINING    557  train
# 9268                    QUICK BITES     14  train
# 10200                   QUICK BITES     40  train
# 10704                 CASUAL DINING     68  train
# 11491                   QUICK BITES    109  train
# 12314                 CASUAL DINING    775  train
# 12447                   QUICK BITES     44  train
# 12859                   QUICK BITES    161   test
# 13400                   QUICK BITES     69   test
# 14044                   QUICK BITES    362   test
# 16311             PUB,CASUAL DINING   1142   test
# 16857                   QUICK BITES    124   test

# %%
#lets collect city names after removing dupliactes
city_list=df_food["CITY"].drop_duplicates().to_list()

# %%
null_city_indexes=df_food.loc[df_food["CITY"].isnull()].index

# %%
#df_food.loc[df_food["CITY"].isnull(),["LOCALITY"]].str.split()
for index in null_city_indexes:
    for city in city_list:
        if city in df_food["LOCALITY"].iloc[index].split():
            df_food["CITY"].iloc[index]=city

# %%
#lets chcek number of rows left where city is null
df_food.loc[df_food["CITY"].isnull()]
# Out:
#       CITY    COST                                           CUISINES  \
# 817    NaN  1200.0  Thai, Chinese, Continental, North Indian, Italian
# 6397   NaN   950.0  Cafe, American, Asian, Bakery, Biryani, Chines...
# 8456   NaN   150.0                               Fast Food, Beverages
# 12314  NaN   650.0                              North Indian, Bengali
# 14044  NaN     NaN                     North Indian, Chinese, Mughlai
#
#                                                 LOCALITY  RATING  \
# 817                               shop 7 shikrupa socity     4.1
# 6397                                             Alibaug     4.2
# 8456                                           Mathikere     3.7
# 12314  Opposite to corporation bank and LIC office ba...     4.3
# 14044                             Jaipuria Sunrise Plaza     3.9
#
#        RESTAURANT_ID                                 TIME          TITLE  \
# 817             1042        12noon – 12midnight (Mon-Sun)  CASUAL DINING
# 6397            7334               9am – 9:30pm (Mon-Sun)           CAFÉ
# 8456           12367              9:30am – 11pm (Mon-Sun)    QUICK BITES
# 12314          11724  11am – 3:30pm, 7pm – 11pm (Mon-Sun)  CASUAL DINING
# 14044          14152  11:30am – 4pm, 5pm – 11pm (Mon-Sun)    QUICK BITES
#
#        VOTES source
# 817      486  train
# 6397     253  train
# 8456      28  train
# 12314    775  train
# 14044    362   test

# %%
#Now we will impute "CITY" and "LOCALITY" as missing
df_food["CITY"].fillna("missing",inplace=True)
df_food["LOCALITY"].fillna("missing",inplace=True)

# %%
#Lets chcek the null values again
df_food.isnull().sum()
#4231 is the cost which need to predicted in test dataset
# Out:
# CITY                0
# COST             4231
# CUISINES            0
# LOCALITY            0
# RATING              0
# RESTAURANT_ID       0
# TIME                0
# TITLE               0
# VOTES               0
# source              0
# dtype: int64

# %%
#displaying data
df_food
# Out:
#                       CITY    COST  \
# 0                    Thane  1200.0
# 1                  Chennai  1500.0
# 2                  Chennai   800.0
# 3                   Mumbai   800.0
# 4                   Mumbai   300.0
# 5                   Mumbai   800.0
# 6                Bangalore   600.0
# 7                  Gurgaon  1600.0
# 8                Bangalore   300.0
# 9                Hyderabad   200.0
# 10               Bangalore   900.0
# 11               Bangalore   800.0
# 12                   Kochi   600.0
# 13                   Kochi   400.0
# 14              Thane West   300.0
# 15               Hyderabad  1400.0
# 16                  Mumbai   900.0
# 17               Hyderabad   600.0
# 18     Andheri Lokhandwala   600.0
# 19               New Delhi   200.0
# 20               Hyderabad   350.0
# 21               New Delhi   500.0
# 22               New Delhi   450.0
# 23               Bangalore   600.0
# 24               New Delhi   700.0
# 25                   Kochi   400.0
# 26               Bangalore   700.0
# 27                 Chennai  1400.0
# 28                 Chennai  1000.0
# 29               Bangalore  1400.0
# ...                    ...     ...
# 16891              Gurgaon     NaN
# 16892              Chennai     NaN
# 16893              Chennai     NaN
# 16894              Chennai     NaN
# 16895            Bangalore     NaN
# 16896            New Delhi     NaN
# 16897              Chennai     NaN
# 16898               Mumbai     NaN
# 16899            Hyderabad     NaN
# 16900               Mumbai     NaN
# 16901            Hyderabad     NaN
# 16902               Mumbai     NaN
# 16903            Hyderabad     NaN
# 16904            Bangalore     NaN
# 16905               Mumbai     NaN
# 16906              Chennai     NaN
# 16907               Mumbai     NaN
# 16908            Bangalore     NaN
# 16909            Bangalore     NaN
# 16910               Mumbai     NaN
# 16911               Mumbai     NaN
# 16912            Bangalore     NaN
# 16913               Mumbai     NaN
# 16914            Bangalore     NaN
# 16915               Mumbai     NaN
# 16916            New Delhi     NaN
# 16917            Bangalore     NaN
# 16918            Faridabad     NaN
# 16919                Kochi     NaN
# 16920          Bandra West     NaN
#
#                                                 CUISINES  \
# 0                            Malwani, Goan, North Indian
# 1                         Asian, Modern Indian, Japanese
# 2             North Indian, Chinese, Biryani, Hyderabadi
# 3                                       Tibetan, Chinese
# 4                                               Desserts
# 5                North Indian, Chinese, Seafood, Biryani
# 6             Cafe, Chinese, Pizza, North Indian, Burger
# 7                                               Bar Food
# 8                             South Indian, North Indian
# 9                                           North Indian
# 10             North Indian, Chinese, Fast Food, Biryani
# 11                          Fast Food, Burger, Beverages
# 12                                      Arabian, Mughlai
# 13                                          South Indian
# 14                                         Maharashtrian
# 15                                     Parsi, Hyderabadi
# 16                               North Indian, Fast Food
# 17                     North Indian, Hyderabadi, Chinese
# 18                                         Chinese, Thai
# 19                              Bakery, Fast Food, Momos
# 20                                 Continental, European
# 21                            North Indian, Rolls, Momos
# 22               North Indian, Fast Food, Mughlai, Rolls
# 23                Andhra, Chinese, North Indian, Biryani
# 24                                Cafe, Italian, Chinese
# 25                                 Biryani, North Indian
# 26                            North Indian, Chinese, BBQ
# 27                                               Italian
# 28       Finger Food, North Indian, Continental, Italian
# 29         Finger Food, Continental, Asian, North Indian
# ...                                                  ...
# 16891                              Biryani, South Indian
# 16892                                 Biryani, Fast Food
# 16893                South Indian, Biryani, North Indian
# 16894                                             Bakery
# 16895                                   Bakery, Desserts
# 16896                European, Continental, North Indian
# 16897                South Indian, North Indian, Chinese
# 16898                              Chinese, North Indian
# 16899  Biryani, Chinese, Mughlai, North Indian, Hyder...
# 16900                     Chinese, North Indian, Mughlai
# 16901                         Fast Food, Bakery, Chinese
# 16902                                       North Indian
# 16903                North Indian, South Indian, Chinese
# 16904              Fast Food, North Indian, South Indian
# 16905                                Ice Cream, Desserts
# 16906                     Chinese, North Indian, Arabian
# 16907            European, Mediterranean, Italian, Sushi
# 16908                              North Indian, Biryani
# 16909                       Biryani, Hyderabadi, Chinese
# 16910  South Indian, North Indian, Fast Food, Chinese...
# 16911                     North Indian, Mughlai, Chinese
# 16912               North Indian, Chinese, Kebab, Juices
# 16913                                Sindhi, Street Food
# 16914                               Kerala, South Indian
# 16915                     North Indian, Mughlai, Chinese
# 16916                     North Indian, Mughlai, Chinese
# 16917      Biryani, North Indian, Sandwich, Salad, Wraps
# 16918                          Continental, North Indian
# 16919                                   Rolls, Beverages
# 16920                                            Mughlai
#
#                     LOCALITY  RATING  RESTAURANT_ID  \
# 0             Dombivali East     3.6           9438
# 1                  Ramapuram     4.2          13198
# 2                 Saligramam     3.8          10915
# 3                Bandra West     4.1           6346
# 4                Lower Parel     3.8          15387
# 5            Vile Parle West     4.0           5618
# 6      Koramangala 6th Block     4.1           4383
# 7                  Sector 29     4.3           1249
# 8          Bannerghatta Road     3.9           7062
# 9               Dilsukhnagar     3.3          10109
# 10     Koramangala 5th Block     4.1             38
# 11               Indiranagar     4.0            844
# 12                Chullickal     3.4            938
# 13                 Edappally     0.0           4319
# 14                  Majiwada     4.0          15024
# 15             Jubilee Hills     4.5          12401
# 16             Borivali West     3.6           5254
# 17                    Nagole     3.5           8259
# 18       Andheri Lokhandwala     3.6           4009
# 19             Krishna Nagar     4.1          11841
# 20               Hitech City     4.2           6465
# 21                Karol Bagh     4.0           1048
# 22                       SDA     4.0          12499
# 23              Thippasandra     3.9          10412
# 24                    Dwarka     4.2           2389
# 25                  Kakkanad     3.8           6551
# 26                       HSR     3.4          13446
# 27                Vadapalani     4.1          10277
# 28               Neelangarai     4.3           4222
# 29     Koramangala 5th Block     4.2           6577
# ...                      ...     ...            ...
# 16891              Sector 37     3.5          13547
# 16892        Thousand Lights     4.2           9386
# 16893           Thuraipakkam     4.1          12971
# 16894              Perungudi     3.2          15219
# 16895           New BEL Road     3.8            141
# 16896         Rajendra Place     4.2           4325
# 16897             K.K. Nagar     3.4           6158
# 16898                  Worli     3.6          11799
# 16899               Kondapur     4.0           4992
# 16900         Santacruz East     3.3          11680
# 16901               Ameerpet     3.2           2943
# 16902              Kalbadevi     4.0           6204
# 16903              Manikonda     2.6          14205
# 16904               JP Nagar     3.7          10521
# 16905                  Powai     4.3           6448
# 16906               Tambaram     3.6            499
# 16907                   Juhu     4.1          14508
# 16908              Jalahalli     3.3          11667
# 16909           Malleshwaram     4.1           6412
# 16910            Mulund West     3.9           6199
# 16911          Goregaon East     3.6           3265
# 16912               JP Nagar     3.8           6973
# 16913            Lower Parel     0.0           6887
# 16914            Indiranagar     3.8            331
# 16915             Grant Road     4.0           1670
# 16916           Punjabi Bagh     3.9           9057
# 16917             HSR Layout     4.3           1247
# 16918              Sector 86     3.7           8617
# 16919                  Kochi     0.0           6485
# 16920       Perry Cross Road     3.7           2421
#
#                                                     TIME  \
# 0                 11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)
# 1                                   6pm – 11pm (Mon-Sun)
# 2                    11am – 3:30pm, 7pm – 11pm (Mon-Sun)
# 3                                11:30am – 1am (Mon-Sun)
# 4                                   11am – 1am (Mon-Sun)
# 5                             12noon – 12:30AM (Mon-Sun)
# 6      12noon – 11:30pm (Mon, Tue, Thu, Fri, Sat, Sun...
# 7                                    1pm – 1am (Mon-Sun)
# 8                                7am – 10:30pm (Mon-Sun)
# 9                    11am – 2pm, 4pm – 10:30pm (Mon-Sun)
# 10                           12:30pm – 12:30AM (Mon-Sun)
# 11      11am – 12:15AM (Mon, Tue, Wed, Thu, Fri, Sun)...
# 12                                 11am – 11pm (Mon-Sun)
# 13                              11am – 11:30pm (Mon-Sun)
# 14                    Closed (Mon),11am – 11pm (Tue-Sun)
# 15        11:30am – 11:30pm (Mon, Tue, Wed, Thu, Sun)...
# 16                         7:30am – 12midnight (Mon-Sun)
# 17                           11am – 12midnight (Mon-Sun)
# 18                              11am – 11:45pm (Mon-Sun)
# 19                     Closed (Mon),9am – 10pm (Tue-Sun)
# 20                               9:30am – 10pm (Mon-Sun)
# 21                           10:30am – 11:30pm (Mon-Sun)
# 22                                  11am – 3am (Mon-Sun)
# 23                   11am – 3:30pm, 7pm – 11pm (Mon-Sun)
# 24                                 11am – 11pm (Mon-Sun)
# 25                               12noon – 11pm (Mon-Sun)
# 26         12:30pm – 11pm (Mon-Thu),12:30pm – 11:30pm...
# 27       Closed (Mon),12noon – 3pm, 6pm – 11pm (Tue-Sun)
# 28                                 11am – 11pm (Mon-Sun)
# 29                               12:30pm – 1am (Mon-Sun)
# ...                                                  ...
# 16891                               7am – 11pm (Mon-Sun)
# 16892                              11am – 11pm (Mon-Sun)
# 16893  12noon – 3:30pm, 7:30pm – 11pm (Mon-Fri),12noo...
# 16894                              10am – 10pm (Mon-Sun)
# 16895                              11am – 11pm (Mon-Sun)
# 16896                                 24 Hours (Mon-Sun)
# 16897                               7am – 11pm (Mon-Sun)
# 16898                     11:30am – 12midnight (Mon-Sun)
# 16899                               10am – 2am (Mon-Sun)
# 16900             11am – 4pm, 7pm – 12midnight (Mon-Sun)
# 16901                                8am – 4am (Mon-Sun)
# 16902              Closed (Mon),10am – 11:45pm (Tue-Sun)
# 16903                              11am – 11pm (Mon-Sun)
# 16904                               8am – 10pm (Mon-Sun)
# 16905                           11am – 12:30AM (Mon-Sun)
# 16906                           11:30am – 11pm (Mon-Sun)
# 16907   7pm – 1:30am (Mon-Tue),12noon – 1:30am (Wed-Sun)
# 16908                        12:30pm – 10:15pm (Mon-Sun)
# 16909                        11:30am – 11:30pm (Mon-Sun)
# 16910                               7am – 10pm (Mon-Sun)
# 16911                                9am – 1am (Mon-Sun)
# 16912                 12noon – 4pm, 7pm – 11pm (Mon-Sun)
# 16913             11:30am – 4pm, 7pm – 11:30pm (Mon-Sun)
# 16914  12noon – 4pm, 7pm – 10:30pm (Mon-Sat),12noon –...
# 16915  6am – 12:30AM (Mon, Tue, Wed, Thu, Sat, Sun), ...
# 16916                        11:30am – 11:30pm (Mon-Sun)
# 16917                               11am – 1am (Mon-Sun)
# 16918                         9:30am – 10:30pm (Mon-Sun)
# 16919  11am – 11:30pm (Mon, Tue, Wed, Thu, Sat, Sun),...
# 16920                                5pm – 1am (Mon-Sun)
#
#                            TITLE  VOTES source
# 0                  CASUAL DINING     49  train
# 1              CASUAL DINING,BAR     30  train
# 2                  CASUAL DINING    221  train
# 3                    QUICK BITES     24  train
# 4                 DESSERT PARLOR    165  train
# 5                  CASUAL DINING    550  train
# 6                           CAFÉ    509  train
# 7                   MICROBREWERY   1612  train
# 8                    QUICK BITES    101  train
# 9                    QUICK BITES    219  train
# 10                 CASUAL DINING    244  train
# 11     QUICK BITES,BEVERAGE SHOP    274  train
# 12                 CASUAL DINING     15  train
# 13                 CASUAL DINING      0  train
# 14                   QUICK BITES    160  train
# 15      CASUAL DINING,IRANI CAFE   2499  train
# 16                 CASUAL DINING    319  train
# 17                 CASUAL DINING    121  train
# 18                 CASUAL DINING    535  train
# 19            BAKERY,QUICK BITES    350  train
# 20                 CASUAL DINING    400  train
# 21                   QUICK BITES   1327  train
# 22                          None   1191  train
# 23                 CASUAL DINING    533  train
# 24                          CAFÉ    493  train
# 25                   QUICK BITES    372  train
# 26                 CASUAL DINING    105  train
# 27             BAR,CASUAL DINING    178  train
# 28                           BAR    150  train
# 29                           PUB   2456  train
# ...                          ...    ...    ...
# 16891                QUICK BITES     22   test
# 16892                QUICK BITES    232   test
# 16893                QUICK BITES   1697   test
# 16894                     BAKERY     31   test
# 16895                     BAKERY     26   test
# 16896                FINE DINING    749   test
# 16897                QUICK BITES     26   test
# 16898              CASUAL DINING    251   test
# 16899              CASUAL DINING    125   test
# 16900              CASUAL DINING    312   test
# 16901         QUICK BITES,BAKERY   1246   test
# 16902              CASUAL DINING    371   test
# 16903              CASUAL DINING     62   test
# 16904                QUICK BITES    174   test
# 16905             DESSERT PARLOR   1265   test
# 16906                QUICK BITES    171   test
# 16907          BAR,CASUAL DINING   1239   test
# 16908                       None      6   test
# 16909              CASUAL DINING    226   test
# 16910              CASUAL DINING    197   test
# 16911              CASUAL DINING    441   test
# 16912                QUICK BITES    245   test
# 16913              CASUAL DINING      0   test
# 16914                QUICK BITES    410   test
# 16915                QUICK BITES    197   test
# 16916              CASUAL DINING    287   test
# 16917                       None    469   test
# 16918                QUICK BITES     53   test
# 16919                QUICK BITES      0   test
# 16920                QUICK BITES     63   test
#
# [16921 rows x 10 columns]

# %%
#Lets drop "RESTAURANT_ID" and "TIME" from the dataset
df_food.drop(columns=["RESTAURANT_ID","TIME"],inplace=True)

# %%
#Now we will divide the CUISINES column into multiple columns
#First we will find maximum number of cuisines resutarnt are serving
max_cuisines=-1
for i in range(len(df_food["CUISINES"])):
    temp=len(df_food["CUISINES"].iloc[i].split(","))
    if temp>max_cuisines:
        max_cuisines=temp
print("Max number of cuisines serverd are :{}".format(max_cuisines))
# Out:
# Max number of cuisines serverd are :8

# %%
c1=list()
c2=list()
c3=list()
c4=list()
c5=list()
c6=list()
c7=list()
c8=list()
for i in range(len(df_food["CUISINES"])):
    temp=df_food["CUISINES"].iloc[i].split(",")
    try :
        c1.append(temp[0].strip().upper())
    except :
        c1.append('NONE')
    try :
        c2.append(temp[1].strip().upper())
    except :
        c2.append('NONE')
    try :
        c3.append(temp[2].strip().upper())
    except :
        c3.append('NONE')
    try :
        c4.append(temp[3].strip().upper())
    except :
        c4.append('NONE')
    try :
        c5.append(temp[4].strip().upper())
    except :
        c5.append('NONE')
    try :
        c6.append(temp[5].strip().upper())
    except :
        c6.append('NONE')
    try :
        c7.append(temp[6].strip().upper())
    except :
        c7.append('NONE')
    try :
        c8.append(temp[7].strip().upper())
    except :
        c8.append('NONE')

# %%
df_food["c1"]=c1
df_food["c2"]=c2
df_food["c3"]=c3
df_food["c4"]=c4
df_food["c5"]=c5
df_food["c6"]=c6
df_food["c7"]=c7
df_food["c8"]=c8

# %%
#Now we will divide the "TITLE" column into multiple columns
#First we will find maximum number of TITLE resutarnt having
max_titles=-1
for i in range(len(df_food["TITLE"])):
    temp=len(df_food["TITLE"].iloc[i].split(","))
    if temp>max_titles:
        max_titles=temp
print("Max number of titles are :{}".format(max_titles))
# Out:
# Max number of titles are :2

# %%
t1=list()
t2=list()
for i in range(len(df_food["TITLE"])):
    temp=df_food["TITLE"].iloc[i].split(",")
    try :
        t1.append(temp[0].strip().upper())
    except :
        t1.append('NONE')
    try :
        t2.append(temp[1].strip().upper())
    except :
        t2.append('NONE')

# %%
df_food["t1"]=t1
df_food["t2"]=t2

# %%
#displaying the dataset
df_food
# Out:
#                       CITY    COST  \
# 0                    Thane  1200.0
# 1                  Chennai  1500.0
# 2                  Chennai   800.0
# 3                   Mumbai   800.0
# 4                   Mumbai   300.0
# 5                   Mumbai   800.0
# 6                Bangalore   600.0
# 7                  Gurgaon  1600.0
# 8                Bangalore   300.0
# 9                Hyderabad   200.0
# 10               Bangalore   900.0
# 11               Bangalore   800.0
# 12                   Kochi   600.0
# 13                   Kochi   400.0
# 14              Thane West   300.0
# 15               Hyderabad  1400.0
# 16                  Mumbai   900.0
# 17               Hyderabad   600.0
# 18     Andheri Lokhandwala   600.0
# 19               New Delhi   200.0
# 20               Hyderabad   350.0
# 21               New Delhi   500.0
# 22               New Delhi   450.0
# 23               Bangalore   600.0
# 24               New Delhi   700.0
# 25                   Kochi   400.0
# 26               Bangalore   700.0
# 27                 Chennai  1400.0
# 28                 Chennai  1000.0
# 29               Bangalore  1400.0
# ...                    ...     ...
# 16891              Gurgaon     NaN
# 16892              Chennai     NaN
# 16893              Chennai     NaN
# 16894              Chennai     NaN
# 16895            Bangalore     NaN
# 16896            New Delhi     NaN
# 16897              Chennai     NaN
# 16898               Mumbai     NaN
# 16899            Hyderabad     NaN
# 16900               Mumbai     NaN
# 16901            Hyderabad     NaN
# 16902               Mumbai     NaN
# 16903            Hyderabad     NaN
# 16904            Bangalore     NaN
# 16905               Mumbai     NaN
# 16906              Chennai     NaN
# 16907               Mumbai     NaN
# 16908            Bangalore     NaN
# 16909            Bangalore     NaN
# 16910               Mumbai     NaN
# 16911               Mumbai     NaN
# 16912            Bangalore     NaN
# 16913               Mumbai     NaN
# 16914            Bangalore     NaN
# 16915               Mumbai     NaN
# 16916            New Delhi     NaN
# 16917            Bangalore     NaN
# 16918            Faridabad     NaN
# 16919                Kochi     NaN
# 16920          Bandra West     NaN
#
#                                                 CUISINES  \
# 0                            Malwani, Goan, North Indian
# 1                         Asian, Modern Indian, Japanese
# 2             North Indian, Chinese, Biryani, Hyderabadi
# 3                                       Tibetan, Chinese
# 4                                               Desserts
# 5                North Indian, Chinese, Seafood, Biryani
# 6             Cafe, Chinese, Pizza, North Indian, Burger
# 7                                               Bar Food
# 8                             South Indian, North Indian
# 9                                           North Indian
# 10             North Indian, Chinese, Fast Food, Biryani
# 11                          Fast Food, Burger, Beverages
# 12                                      Arabian, Mughlai
# 13                                          South Indian
# 14                                         Maharashtrian
# 15                                     Parsi, Hyderabadi
# 16                               North Indian, Fast Food
# 17                     North Indian, Hyderabadi, Chinese
# 18                                         Chinese, Thai
# 19                              Bakery, Fast Food, Momos
# 20                                 Continental, European
# 21                            North Indian, Rolls, Momos
# 22               North Indian, Fast Food, Mughlai, Rolls
# 23                Andhra, Chinese, North Indian, Biryani
# 24                                Cafe, Italian, Chinese
# 25                                 Biryani, North Indian
# 26                            North Indian, Chinese, BBQ
# 27                                               Italian
# 28       Finger Food, North Indian, Continental, Italian
# 29         Finger Food, Continental, Asian, North Indian
# ...                                                  ...
# 16891                              Biryani, South Indian
# 16892                                 Biryani, Fast Food
# 16893                South Indian, Biryani, North Indian
# 16894                                             Bakery
# 16895                                   Bakery, Desserts
# 16896                European, Continental, North Indian
# 16897                South Indian, North Indian, Chinese
# 16898                              Chinese, North Indian
# 16899  Biryani, Chinese, Mughlai, North Indian, Hyder...
# 16900                     Chinese, North Indian, Mughlai
# 16901                         Fast Food, Bakery, Chinese
# 16902                                       North Indian
# 16903                North Indian, South Indian, Chinese
# 16904              Fast Food, North Indian, South Indian
# 16905                                Ice Cream, Desserts
# 16906                     Chinese, North Indian, Arabian
# 16907            European, Mediterranean, Italian, Sushi
# 16908                              North Indian, Biryani
# 16909                       Biryani, Hyderabadi, Chinese
# 16910  South Indian, North Indian, Fast Food, Chinese...
# 16911                     North Indian, Mughlai, Chinese
# 16912               North Indian, Chinese, Kebab, Juices
# 16913                                Sindhi, Street Food
# 16914                               Kerala, South Indian
# 16915                     North Indian, Mughlai, Chinese
# 16916                     North Indian, Mughlai, Chinese
# 16917      Biryani, North Indian, Sandwich, Salad, Wraps
# 16918                          Continental, North Indian
# 16919                                   Rolls, Beverages
# 16920                                            Mughlai
#
#                     LOCALITY  RATING                      TITLE  VOTES source  \
# 0             Dombivali East     3.6              CASUAL DINING     49  train
# 1                  Ramapuram     4.2          CASUAL DINING,BAR     30  train
# 2                 Saligramam     3.8              CASUAL DINING    221  train
# 3                Bandra West     4.1                QUICK BITES     24  train
# 4                Lower Parel     3.8             DESSERT PARLOR    165  train
# 5            Vile Parle West     4.0              CASUAL DINING    550  train
# 6      Koramangala 6th Block     4.1                       CAFÉ    509  train
# 7                  Sector 29     4.3               MICROBREWERY   1612  train
# 8          Bannerghatta Road     3.9                QUICK BITES    101  train
# 9               Dilsukhnagar     3.3                QUICK BITES    219  train
# 10     Koramangala 5th Block     4.1              CASUAL DINING    244  train
# 11               Indiranagar     4.0  QUICK BITES,BEVERAGE SHOP    274  train
# 12                Chullickal     3.4              CASUAL DINING     15  train
# 13                 Edappally     0.0              CASUAL DINING      0  train
# 14                  Majiwada     4.0                QUICK BITES    160  train
# 15             Jubilee Hills     4.5   CASUAL DINING,IRANI CAFE   2499  train
# 16             Borivali West     3.6              CASUAL DINING    319  train
# 17                    Nagole     3.5              CASUAL DINING    121  train
# 18       Andheri Lokhandwala     3.6              CASUAL DINING    535  train
# 19             Krishna Nagar     4.1         BAKERY,QUICK BITES    350  train
# 20               Hitech City     4.2              CASUAL DINING    400  train
# 21                Karol Bagh     4.0                QUICK BITES   1327  train
# 22                       SDA     4.0                       None   1191  train
# 23              Thippasandra     3.9              CASUAL DINING    533  train
# 24                    Dwarka     4.2                       CAFÉ    493  train
# 25                  Kakkanad     3.8                QUICK BITES    372  train
# 26                       HSR     3.4              CASUAL DINING    105  train
# 27                Vadapalani     4.1          BAR,CASUAL DINING    178  train
# 28               Neelangarai     4.3                        BAR    150  train
# 29     Koramangala 5th Block     4.2                        PUB   2456  train
# ...                      ...     ...                        ...    ...    ...
# 16891              Sector 37     3.5                QUICK BITES     22   test
# 16892        Thousand Lights     4.2                QUICK BITES    232   test
# 16893           Thuraipakkam     4.1                QUICK BITES   1697   test
# 16894              Perungudi     3.2                     BAKERY     31   test
# 16895           New BEL Road     3.8                     BAKERY     26   test
# 16896         Rajendra Place     4.2                FINE DINING    749   test
# 16897             K.K. Nagar     3.4                QUICK BITES     26   test
# 16898                  Worli     3.6              CASUAL DINING    251   test
# 16899               Kondapur     4.0              CASUAL DINING    125   test
# 16900         Santacruz East     3.3              CASUAL DINING    312   test
# 16901               Ameerpet     3.2         QUICK BITES,BAKERY   1246   test
# 16902              Kalbadevi     4.0              CASUAL DINING    371   test
# 16903              Manikonda     2.6              CASUAL DINING     62   test
# 16904               JP Nagar     3.7                QUICK BITES    174   test
# 16905                  Powai     4.3             DESSERT PARLOR   1265   test
# 16906               Tambaram     3.6                QUICK BITES    171   test
# 16907                   Juhu     4.1          BAR,CASUAL DINING   1239   test
# 16908              Jalahalli     3.3                       None      6   test
# 16909           Malleshwaram     4.1              CASUAL DINING    226   test
# 16910            Mulund West     3.9              CASUAL DINING    197   test
# 16911          Goregaon East     3.6              CASUAL DINING    441   test
# 16912               JP Nagar     3.8                QUICK BITES    245   test
# 16913            Lower Parel     0.0              CASUAL DINING      0   test
# 16914            Indiranagar     3.8                QUICK BITES    410   test
# 16915             Grant Road     4.0                QUICK BITES    197   test
# 16916           Punjabi Bagh     3.9              CASUAL DINING    287   test
# 16917             HSR Layout     4.3                       None    469   test
# 16918              Sector 86     3.7                QUICK BITES     53   test
# 16919                  Kochi     0.0                QUICK BITES      0   test
# 16920       Perry Cross Road     3.7                QUICK BITES     63   test
#
#                   c1             c2            c3            c4          c5  \
# 0            MALWANI           GOAN  NORTH INDIAN          NONE        NONE
# 1              ASIAN  MODERN INDIAN      JAPANESE          NONE        NONE
# 2       NORTH INDIAN        CHINESE       BIRYANI    HYDERABADI        NONE
# 3            TIBETAN        CHINESE          NONE          NONE        NONE
# 4           DESSERTS           NONE          NONE          NONE        NONE
# 5       NORTH INDIAN        CHINESE       SEAFOOD       BIRYANI        NONE
# 6               CAFE        CHINESE         PIZZA  NORTH INDIAN      BURGER
# 7           BAR FOOD           NONE          NONE          NONE        NONE
# 8       SOUTH INDIAN   NORTH INDIAN          NONE          NONE        NONE
# 9       NORTH INDIAN           NONE          NONE          NONE        NONE
# 10      NORTH INDIAN        CHINESE     FAST FOOD       BIRYANI        NONE
# 11         FAST FOOD         BURGER     BEVERAGES          NONE        NONE
# 12           ARABIAN        MUGHLAI          NONE          NONE        NONE
# 13      SOUTH INDIAN           NONE          NONE          NONE        NONE
# 14     MAHARASHTRIAN           NONE          NONE          NONE        NONE
# 15             PARSI     HYDERABADI          NONE          NONE        NONE
# 16      NORTH INDIAN      FAST FOOD          NONE          NONE        NONE
# 17      NORTH INDIAN     HYDERABADI       CHINESE          NONE        NONE
# 18           CHINESE           THAI          NONE          NONE        NONE
# 19            BAKERY      FAST FOOD         MOMOS          NONE        NONE
# 20       CONTINENTAL       EUROPEAN          NONE          NONE        NONE
# 21      NORTH INDIAN          ROLLS         MOMOS          NONE        NONE
# 22      NORTH INDIAN      FAST FOOD       MUGHLAI         ROLLS        NONE
# 23            ANDHRA        CHINESE  NORTH INDIAN       BIRYANI        NONE
# 24              CAFE        ITALIAN       CHINESE          NONE        NONE
# 25           BIRYANI   NORTH INDIAN          NONE          NONE        NONE
# 26      NORTH INDIAN        CHINESE           BBQ          NONE        NONE
# 27           ITALIAN           NONE          NONE          NONE        NONE
# 28       FINGER FOOD   NORTH INDIAN   CONTINENTAL       ITALIAN        NONE
# 29       FINGER FOOD    CONTINENTAL         ASIAN  NORTH INDIAN        NONE
# ...              ...            ...           ...           ...         ...
# 16891        BIRYANI   SOUTH INDIAN          NONE          NONE        NONE
# 16892        BIRYANI      FAST FOOD          NONE          NONE        NONE
# 16893   SOUTH INDIAN        BIRYANI  NORTH INDIAN          NONE        NONE
# 16894         BAKERY           NONE          NONE          NONE        NONE
# 16895         BAKERY       DESSERTS          NONE          NONE        NONE
# 16896       EUROPEAN    CONTINENTAL  NORTH INDIAN          NONE        NONE
# 16897   SOUTH INDIAN   NORTH INDIAN       CHINESE          NONE        NONE
# 16898        CHINESE   NORTH INDIAN          NONE          NONE        NONE
# 16899        BIRYANI        CHINESE       MUGHLAI  NORTH INDIAN  HYDERABADI
# 16900        CHINESE   NORTH INDIAN       MUGHLAI          NONE        NONE
# 16901      FAST FOOD         BAKERY       CHINESE          NONE        NONE
# 16902   NORTH INDIAN           NONE          NONE          NONE        NONE
# 16903   NORTH INDIAN   SOUTH INDIAN       CHINESE          NONE        NONE
# 16904      FAST FOOD   NORTH INDIAN  SOUTH INDIAN          NONE        NONE
# 16905      ICE CREAM       DESSERTS          NONE          NONE        NONE
# 16906        CHINESE   NORTH INDIAN       ARABIAN          NONE        NONE
# 16907       EUROPEAN  MEDITERRANEAN       ITALIAN         SUSHI        NONE
# 16908   NORTH INDIAN        BIRYANI          NONE          NONE        NONE
# 16909        BIRYANI     HYDERABADI       CHINESE          NONE        NONE
# 16910   SOUTH INDIAN   NORTH INDIAN     FAST FOOD       CHINESE   BEVERAGES
# 16911   NORTH INDIAN        MUGHLAI       CHINESE          NONE        NONE
# 16912   NORTH INDIAN        CHINESE         KEBAB        JUICES        NONE
# 16913         SINDHI    STREET FOOD          NONE          NONE        NONE
# 16914         KERALA   SOUTH INDIAN          NONE          NONE        NONE
# 16915   NORTH INDIAN        MUGHLAI       CHINESE          NONE        NONE
# 16916   NORTH INDIAN        MUGHLAI       CHINESE          NONE        NONE
# 16917        BIRYANI   NORTH INDIAN      SANDWICH         SALAD       WRAPS
# 16918    CONTINENTAL   NORTH INDIAN          NONE          NONE        NONE
# 16919          ROLLS      BEVERAGES          NONE          NONE        NONE
# 16920        MUGHLAI           NONE          NONE          NONE        NONE
#
#          c6    c7    c8              t1             t2
# 0      NONE  NONE  NONE   CASUAL DINING           NONE
# 1      NONE  NONE  NONE   CASUAL DINING            BAR
# 2      NONE  NONE  NONE   CASUAL DINING           NONE
# 3      NONE  NONE  NONE     QUICK BITES           NONE
# 4      NONE  NONE  NONE  DESSERT PARLOR           NONE
# 5      NONE  NONE  NONE   CASUAL DINING           NONE
# 6      NONE  NONE  NONE            CAFÉ           NONE
# 7      NONE  NONE  NONE    MICROBREWERY           NONE
# 8      NONE  NONE  NONE     QUICK BITES           NONE
# 9      NONE  NONE  NONE     QUICK BITES           NONE
# 10     NONE  NONE  NONE   CASUAL DINING           NONE
# 11     NONE  NONE  NONE     QUICK BITES  BEVERAGE SHOP
# 12     NONE  NONE  NONE   CASUAL DINING           NONE
# 13     NONE  NONE  NONE   CASUAL DINING           NONE
# 14     NONE  NONE  NONE     QUICK BITES           NONE
# 15     NONE  NONE  NONE   CASUAL DINING     IRANI CAFE
# 16     NONE  NONE  NONE   CASUAL DINING           NONE
# 17     NONE  NONE  NONE   CASUAL DINING           NONE
# 18     NONE  NONE  NONE   CASUAL DINING           NONE
# 19     NONE  NONE  NONE          BAKERY    QUICK BITES
# 20     NONE  NONE  NONE   CASUAL DINING           NONE
# 21     NONE  NONE  NONE     QUICK BITES           NONE
# 22     NONE  NONE  NONE            NONE           NONE
# 23     NONE  NONE  NONE   CASUAL DINING           NONE
# 24     NONE  NONE  NONE            CAFÉ           NONE
# 25     NONE  NONE  NONE     QUICK BITES           NONE
# 26     NONE  NONE  NONE   CASUAL DINING           NONE
# 27     NONE  NONE  NONE             BAR  CASUAL DINING
# 28     NONE  NONE  NONE             BAR           NONE
# 29     NONE  NONE  NONE             PUB           NONE
# ...     ...   ...   ...             ...            ...
# 16891  NONE  NONE  NONE     QUICK BITES           NONE
# 16892  NONE  NONE  NONE     QUICK BITES           NONE
# 16893  NONE  NONE  NONE     QUICK BITES           NONE
# 16894  NONE  NONE  NONE          BAKERY           NONE
# 16895  NONE  NONE  NONE          BAKERY           NONE
# 16896  NONE  NONE  NONE     FINE DINING           NONE
# 16897  NONE  NONE  NONE     QUICK BITES           NONE
# 16898  NONE  NONE  NONE   CASUAL DINING           NONE
# 16899  NONE  NONE  NONE   CASUAL DINING           NONE
# 16900  NONE  NONE  NONE   CASUAL DINING           NONE
# 16901  NONE  NONE  NONE     QUICK BITES         BAKERY
# 16902  NONE  NONE  NONE   CASUAL DINING           NONE
# 16903  NONE  NONE  NONE   CASUAL DINING           NONE
# 16904  NONE  NONE  NONE     QUICK BITES           NONE
# 16905  NONE  NONE  NONE  DESSERT PARLOR           NONE
# 16906  NONE  NONE  NONE     QUICK BITES           NONE
# 16907  NONE  NONE  NONE             BAR  CASUAL DINING
# 16908  NONE  NONE  NONE            NONE           NONE
# 16909  NONE  NONE  NONE   CASUAL DINING           NONE
# 16910  NONE  NONE  NONE   CASUAL DINING           NONE
# 16911  NONE  NONE  NONE   CASUAL DINING           NONE
# 16912  NONE  NONE  NONE     QUICK BITES           NONE
# 16913  NONE  NONE  NONE   CASUAL DINING           NONE
# 16914  NONE  NONE  NONE     QUICK BITES           NONE
# 16915  NONE  NONE  NONE     QUICK BITES           NONE
# 16916  NONE  NONE  NONE   CASUAL DINING           NONE
# 16917  NONE  NONE  NONE            NONE           NONE
# 16918  NONE  NONE  NONE     QUICK BITES           NONE
# 16919  NONE  NONE  NONE     QUICK BITES           NONE
# 16920  NONE  NONE  NONE     QUICK BITES           NONE
#
# [16921 rows x 18 columns]

# %%
#We can drop "CUISINE" and "TITLE"columns
df_food.drop(columns=["CUISINES","TITLE"],inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
for col in df_food.columns:
    if df_food[col].dtype=="object":
        df_food[col]=LabelEncoder().fit_transform(df_food[col])

# %%
#Displaying the dataset
df_food
# Out:
#        CITY    COST  LOCALITY  RATING  VOTES  source   c1  c2  c3  c4  c5  c6  \
# 0       400  1200.0       328     3.6     49       1   61  32  72  64  62  50
# 1        75  1500.0      1214     4.2     30       1    6  62  45  64  62  50
# 2        75   800.0      1272     3.8    221       1   74  23  14  34  62  50
# 3       277   800.0       161     4.1     24       1  102  23  70  64  62  50
# 4       277   300.0       709     3.8    165       1   30  67  70  64  62  50
# 5       277   800.0      1570     4.0    550       1   74  23  84  11  62  50
# 6        42   600.0       659     4.1    509       1   22  23  78  65  13  50
# 7       146  1600.0      1328     4.3   1612       1   10  67  70  64  62  50
# 8        42   300.0       169     3.9    101       1   92  69  70  64  62  50
# 9       160   200.0       325     3.3    219       1   74  67  70  64  62  50
# 10       42   900.0       657     4.1    244       1   74  23  30  11  62  50
# 11       42   800.0       499     4.0    274       1   35  17  12  64  62  50
# 12      216   600.0       283     3.4     15       1    4  64  70  64  62  50
# 13      216   400.0       357     0.0      0       1   92  67  70  64  62  50
# 14      403   300.0       741     4.0    160       1   59  67  70  64  62  50
# 15      160  1400.0       541     4.5   2499       1   78  38  70  64  62  50
# 16      277   900.0       218     3.6    319       1   74  28  70  64  62  50
# 17      160   600.0       852     3.5    121       1   74  38  23  64  62  50
# 18       17   600.0       107     3.6    535       1   27  96  70  64  62  50
# 19      316   200.0       673     4.1    350       1    9  28  64  64  62  50
# 20      160   350.0       477     4.2    400       1   29  27  70  64  62  50
# 21      316   500.0       598     4.0   1327       1   74  80  64  64  62  50
# 22      316   450.0      1248     4.0   1191       1   74  28  67  72  62  50
# 23       42   600.0      1494     3.9    533       1    3  23  72  11  62  50
# 24      316   700.0       338     4.2    493       1   22  43  23  64  62  50
# 25      216   400.0       563     3.8    372       1   15  69  70  64  62  50
# 26       42   700.0       460     3.4    105       1   74  23   9  64  62  50
# 27       75  1400.0      1534     4.1    178       1   49  67  70  64  62  50
# 28       75  1000.0       996     4.3    150       1   36  69  25  39  62  50
# 29       42  1400.0       657     4.2   2456       1   36  25   5  65  62  50
# ...     ...     ...       ...     ...    ...     ...  ...  ..  ..  ..  ..  ..
# 16891   146     NaN      1334     3.5     22       0   15  87  70  64  62  50
# 16892    75     NaN      1501     4.2    232       0   15  28  70  64  62  50
# 16893    75     NaN      1507     4.1   1697       0   92  14  72  64  62  50
# 16894    75     NaN      1155     3.2     31       0    9  67  70  64  62  50
# 16895    42     NaN      1006     3.8     26       0    9  26  70  64  62  50
# 16896   316     NaN      1208     4.2    749       0   34  25  72  64  62  50
# 16897    75     NaN       548     3.4     26       0   92  69  23  64  62  50
# 16898   277     NaN      1602     3.6    251       0   27  69  70  64  62  50
# 16899   160     NaN       649     4.0    125       0   15  23  67  65  34  50
# 16900   277     NaN      1279     3.3    312       0   27  69  67  64  62  50
# 16901   160     NaN       100     3.2   1246       0   35   7  23  64  62  50
# 16902   277     NaN       568     4.0    371       0   74  67  70  64  62  50
# 16903   160     NaN       764     2.6     62       0   74  87  23  64  62  50
# 16904    42     NaN       517     3.7    174       0   35  69  87  64  62  50
# 16905   277     NaN      1174     4.3   1265       0   44  26  70  64  62  50
# 16906    75     NaN      1462     3.6    171       0   27  69   4  64  62  50
# 16907   277     NaN       543     4.1   1239       0   34  57  44  82  62  50
# 16908    42     NaN       521     3.3      6       0   74  14  70  64  62  50
# 16909    42     NaN       751     4.1    226       0   15  38  23  64  62  50
# 16910   277     NaN       830     3.9    197       0   92  69  30  19  10  50
# 16911   277     NaN       425     3.6    441       0   74  64  23  64  62  50
# 16912    42     NaN       517     3.8    245       0   74  23  48  42  62  50
# 16913   277     NaN       709     0.0      0       0   89  91  70  64  62  50
# 16914    42     NaN       499     3.8    410       0   54  87  70  64  62  50
# 16915   277     NaN       429     4.0    197       0   74  64  23  64  62  50
# 16916   316     NaN      1184     3.9    287       0   74  64  23  64  62  50
# 16917    42     NaN       461     4.3    469       0   15  69  83  73  83  50
# 16918   128     NaN      1370     3.7     53       0   29  69  70  64  62  50
# 16919   216     NaN       642     0.0      0       0   84  12  70  64  62  50
# 16920    40     NaN      1148     3.7     63       0   69  67  70  64  62  50
#
#        c7  c8  t1  t2
# 0      41  18   5  16
# 1      41  18   5   1
# 2      41  18   5  16
# 3      41  18  23  16
# 4      41  18   9  16
# 5      41  18   5  16
# 6      41  18   4  16
# 7      41  18  19  16
# 8      41  18  23  16
# 9      41  18  23  16
# 10     41  18   5  16
# 11     41  18  23   2
# 12     41  18   5  16
# 13     41  18   5  16
# 14     41  18  23  16
# 15     41  18   5  11
# 16     41  18   5  16
# 17     41  18   5  16
# 18     41  18   5  16
# 19     41  18   0  19
# 20     41  18   5  16
# 21     41  18  23  16
# 22     41  18  20  16
# 23     41  18   5  16
# 24     41  18   4  16
# 25     41  18  23  16
# 26     41  18   5  16
# 27     41  18   1   4
# 28     41  18   1  16
# 29     41  18  22  16
# ...    ..  ..  ..  ..
# 16891  41  18  23  16
# 16892  41  18  23  16
# 16893  41  18  23  16
# 16894  41  18   0  16
# 16895  41  18   0  16
# 16896  41  18  11  16
# 16897  41  18  23  16
# 16898  41  18   5  16
# 16899  41  18   5  16
# 16900  41  18   5  16
# 16901  41  18  23   0
# 16902  41  18   5  16
# 16903  41  18   5  16
# 16904  41  18  23  16
# 16905  41  18   9  16
# 16906  41  18  23  16
# 16907  41  18   1   4
# 16908  41  18  20  16
# 16909  41  18   5  16
# 16910  41  18   5  16
# 16911  41  18   5  16
# 16912  41  18  23  16
# 16913  41  18   5  16
# 16914  41  18  23  16
# 16915  41  18  23  16
# 16916  41  18   5  16
# 16917  41  18  20  16
# 16918  41  18  23  16
# 16919  41  18  23  16
# 16920  41  18  23  16
#
# [16921 rows x 16 columns]

# %%
#Lets chcek the datatypes
df_food.dtypes
# Out:
# CITY          int32
# COST        float64
# LOCALITY      int32
# RATING      float64
# VOTES         int32
# source        int32
# c1            int32
# c2            int32
# c3            int32
# c4            int32
# c5            int32
# c6            int32
# c7            int32
# c8            int32
# t1            int32
# t2            int32
# dtype: object

# %%
df_train=df_food.loc[df_food["source"]==1]
df_test=df_food.loc[df_food["source"]==0]

# %%
#Resetting the index
df_test.reset_index(drop=True,inplace=True)

# %%
#Dropping the source column
df_train.drop(columns=["source"],inplace=True)
df_test.drop(columns=["source"],inplace=True)
# Out:
# F:\anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
#Lets seprate the input and output from train dataset
df_x=df_train.drop(columns=["COST"])
y=df_train[["COST"]]

# %%
#to find random stat which gives maximum r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,df_x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to ",r_state," is ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
#Lets use decision tree
from sklearn.tree import DecisionTreeRegressor
import numpy as np
dtr=DecisionTreeRegressor()
r_state=maxr2_score(dtr,df_x,y)
# Out:
# r2 score corresponding to  42  is  0.4914893469550301
# r2 score corresponding to  43  is  0.5271039714747134
# r2 score corresponding to  44  is  0.3208235581430465
# r2 score corresponding to  45  is  0.45405256829074214
# r2 score corresponding to  46  is  0.4392966617682925
# r2 score corresponding to  47  is  0.5287490245457883
# r2 score corresponding to  48  is  0.0003066420108720491
# r2 score corresponding to  49  is  0.45892013536588183
# r2 score corresponding to  50  is  0.08391614533042024
# r2 score corresponding to  51  is  0.4578986786787369
# r2 score corresponding to  52  is  0.38343351280858906
# r2 score corresponding to  53  is  0.51774420767959
# r2 score corresponding to  54  is  0.3904926929790311
# r2 score corresponding to  55  is  0.4649805520114403
# r2 score corresponding to  56  is  0.5081813497984211
# r2 score corresponding to  57  is  0.4416027185573904
# r2 score corresponding to  58  is  0.46768847181683826
# r2 score corresponding to  59  is  0.398795956649199
# r2 score corresponding to  60  is  0.5338485237724415
# r2 score corresponding to  61  is  0.39660197948780895
# r2 score corresponding to  62  is  0.3630839962661204
# r2 score corresponding to  63  is  0.32360353557068444
# r2 score corresponding to  64  is  0.45499512883908966
# r2 score corresponding to  65  is  0.16676572830208714
# r2 score corresponding to  66  is  0.368798150062017
# r2 score corresponding to  67  is  0.4173006149555849
# r2 score corresponding to  68  is  0.4943020197120829
# r2 score corresponding to  69  is  0.5018077258352812
# r2 score corresponding to  70  is  0.4881849992191083
# r2 score corresponding to  71  is  0.4583570353089581
# r2 score corresponding to  72  is  0.49312132161523936
# r2 score corresponding to  73  is  0.1911416820650409
# r2 score corresponding to  74  is  0.5040574088974623
# r2 score corresponding to  75  is  0.4385664254371159
# r2 score corresponding to  76  is  0.48686501120562475
# r2 score corresponding to  77  is  0.5286312671559784
# r2 score corresponding to  78  is  0.4781724314690188
# r2 score corresponding to  79  is  0.37230973553174873
# r2 score corresponding to  80  is  0.543675764217993
# r2 score corresponding to  81  is  0.5367284208335752
# r2 score corresponding to  82  is  0.43343455065668635
# r2 score corresponding to  83  is  0.4018412323263445
# r2 score corresponding to  84  is  0.5244029374020412
# r2 score corresponding to  85  is  0.37410725871735284
# r2 score corresponding to  86  is  0.49094264509778884
# r2 score corresponding to  87  is  0.4929456303263646
# r2 score corresponding to  88  is  0.4834042456419587
# r2 score corresponding to  89  is  0.4580293288792944
# r2 score corresponding to  90  is  0.5167290970020727
# r2 score corresponding to  91  is  0.42453014507080566
# r2 score corresponding to  92  is  0.18238993092649491
# r2 score corresponding to  93  is  0.5462452828353022
# r2 score corresponding to  94  is  0.4036312923589387
# r2 score corresponding to  95  is  0.4567847191640977
# r2 score corresponding to  96  is  0.46471875023203846
# r2 score corresponding to  97  is  0.3743334872454147
# r2 score corresponding to  98  is  0.34127551899411335
# r2 score corresponding to  99  is  0.44036800082136773
# max r2 score corresponding to  93  is  0.5462452828353022

# %%
#lets use random forest regressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore")
rfr=RandomForestRegressor()
parameters = {"n_estimators":[10,100,500]}
clf = GridSearchCV(rfr, parameters, cv=5,scoring="r2")
clf.fit(df_x,y)
clf.best_params_
# Out:
# {'n_estimators': 500}

# %%
rfr=RandomForestRegressor(n_estimators=500)
r_state=maxr2_score(rfr,df_x,y)
# Out:
# r2 score corresponding to  42  is  0.7371166550449187
# r2 score corresponding to  43  is  0.7452284323148324
# r2 score corresponding to  44  is  0.7150621513465487
# r2 score corresponding to  45  is  0.6915742281465155
# r2 score corresponding to  46  is  0.737106608272277
# r2 score corresponding to  47  is  0.712964444738686
# r2 score corresponding to  48  is  0.6153193885457728
# r2 score corresponding to  49  is  0.6385607597616225
# r2 score corresponding to  50  is  0.7112310626494572
# r2 score corresponding to  51  is  0.7248499598500692
# r2 score corresponding to  52  is  0.6233239655473681
# r2 score corresponding to  53  is  0.7253799511287846
# r2 score corresponding to  54  is  0.6938267420480694
# r2 score corresponding to  55  is  0.7476496338003574
# r2 score corresponding to  56  is  0.7217459775764119
# r2 score corresponding to  57  is  0.6872827738819725
# r2 score corresponding to  58  is  0.62999183339925
# r2 score corresponding to  59  is  0.7262988197601161
# r2 score corresponding to  60  is  0.7375470217829121
# r2 score corresponding to  61  is  0.6915254007881642
# r2 score corresponding to  62  is  0.6265281926828032
# r2 score corresponding to  63  is  0.710491155659337
# r2 score corresponding to  64  is  0.6675244428663489
# r2 score corresponding to  65  is  0.6949732562056254
# r2 score corresponding to  66  is  0.7262919625551197
# r2 score corresponding to  67  is  0.6863545691491466
# r2 score corresponding to  68  is  0.7269918176117212
# r2 score corresponding to  69  is  0.6603787264474074
# r2 score corresponding to  70  is  0.7298703465243286
# r2 score corresponding to  71  is  0.7374563174412199
# r2 score corresponding to  72  is  0.7388982918770667
# r2 score corresponding to  73  is  0.6678032543622412
# r2 score corresponding to  74  is  0.7450329485000213
# r2 score corresponding to  75  is  0.6882449308115554
# r2 score corresponding to  76  is  0.746938217848204
# r2 score corresponding to  77  is  0.7484670712610813
# r2 score corresponding to  78  is  0.6638821037463456
# r2 score corresponding to  79  is  0.7331173540933204
# r2 score corresponding to  80  is  0.7219506428637004
# r2 score corresponding to  81  is  0.7257279377193337
# r2 score corresponding to  82  is  0.7143878610606913
# r2 score corresponding to  83  is  0.6553060808628846
# r2 score corresponding to  84  is  0.7198197055432453
# r2 score corresponding to  85  is  0.7034692382263595
# r2 score corresponding to  86  is  0.7256209872262547
# r2 score corresponding to  87  is  0.7128336129390787
# r2 score corresponding to  88  is  0.725447302271496
# r2 score corresponding to  89  is  0.7099820923081934
# r2 score corresponding to  90  is  0.7280007503410186
# r2 score corresponding to  91  is  0.7254692290795755
# r2 score corresponding to  92  is  0.7167674847717889
# r2 score corresponding to  93  is  0.7321544367513575
# r2 score corresponding to  94  is  0.7317955893571129
# r2 score corresponding to  95  is  0.7136191072063907
# r2 score corresponding to  96  is  0.6442268191180187
# r2 score corresponding to  97  is  0.632384407820453
# r2 score corresponding to  98  is  0.7040002065369608
# r2 score corresponding to  99  is  0.7073080166387632
# max r2 score corresponding to  77  is  0.7484670712610813

# %%
import lightgbm as lgb
lg = lgb.LGBMRegressor(silent=False)
param_dist = {"max_depth": [25,50, 75],
              "learning_rate" : [0.01,0.05,0.1],
              "num_leaves": [300,900,1200],
              "n_estimators": [200]
             }
grid_search = GridSearchCV(lg, n_jobs=-1, param_grid=param_dist, cv = 5, scoring="r2")
grid_search.fit(df_x,y)
grid_search.best_estimator_
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#        importance_type='split', learning_rate=0.05, max_depth=25,
#        min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#        n_estimators=200, n_jobs=-1, num_leaves=900, objective=None,
#        random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=False,
#        subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
lgbr=lgb.LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
       importance_type='split', learning_rate=0.05, max_depth=25,
       min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
       n_estimators=200, n_jobs=-1, num_leaves=900, objective=None,
       random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=False,
       subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
r_state=maxr2_score(lgbr,df_x,y)
#Here we see that lightfbm was faster and better than random forest
# Out:
# r2 score corresponding to  42  is  0.7424770306203295
# r2 score corresponding to  43  is  0.7507807811895104
# r2 score corresponding to  44  is  0.7205369510709456
# r2 score corresponding to  45  is  0.6899957169025271
# r2 score corresponding to  46  is  0.7482269937551251
# r2 score corresponding to  47  is  0.7139496319087251
# r2 score corresponding to  48  is  0.7169652214140452
# r2 score corresponding to  49  is  0.655852205037972
# r2 score corresponding to  50  is  0.7525341313760034
# r2 score corresponding to  51  is  0.74361183465738
# r2 score corresponding to  52  is  0.632601376781498
# r2 score corresponding to  53  is  0.7416426867852044
# r2 score corresponding to  54  is  0.7072601484828591
# r2 score corresponding to  55  is  0.7383601813292315
# r2 score corresponding to  56  is  0.7206273042625527
# r2 score corresponding to  57  is  0.6968040466088838
# r2 score corresponding to  58  is  0.6368049457969613
# r2 score corresponding to  59  is  0.7398984646511302
# r2 score corresponding to  60  is  0.7510999558105526
# r2 score corresponding to  61  is  0.7130193813399207
# r2 score corresponding to  62  is  0.6584058021913257
# r2 score corresponding to  63  is  0.731813303719909
# r2 score corresponding to  64  is  0.6693954478617861
# r2 score corresponding to  65  is  0.6984670113100554
# r2 score corresponding to  66  is  0.7158336101773447
# r2 score corresponding to  67  is  0.7042768341471594
# r2 score corresponding to  68  is  0.73827201659868
# r2 score corresponding to  69  is  0.6648921025915092
# r2 score corresponding to  70  is  0.7201201320401598
# r2 score corresponding to  71  is  0.7412240338069451
# r2 score corresponding to  72  is  0.7415118211178402
# r2 score corresponding to  73  is  0.6950686563284233
# r2 score corresponding to  74  is  0.7530751411381014
# r2 score corresponding to  75  is  0.686579505573403
# r2 score corresponding to  76  is  0.7420550909552267
# r2 score corresponding to  77  is  0.7555842553204534
# r2 score corresponding to  78  is  0.6760215336665762
# r2 score corresponding to  79  is  0.7344693804085678
# r2 score corresponding to  80  is  0.7340220300880425
# r2 score corresponding to  81  is  0.7305831334356683
# r2 score corresponding to  82  is  0.7621309683410685
# r2 score corresponding to  83  is  0.6576529805734256
# r2 score corresponding to  84  is  0.7396921280245283
# r2 score corresponding to  85  is  0.7354699159863913
# r2 score corresponding to  86  is  0.7344533421049346
# r2 score corresponding to  87  is  0.7366824611039949
# r2 score corresponding to  88  is  0.7345250708007611
# r2 score corresponding to  89  is  0.7115972774705848
# r2 score corresponding to  90  is  0.7329062850595688
# r2 score corresponding to  91  is  0.7338123089825006
# r2 score corresponding to  92  is  0.7425648460824953
# r2 score corresponding to  93  is  0.7527817872080458
# r2 score corresponding to  94  is  0.7419943925845108
# r2 score corresponding to  95  is  0.7219272459262109
# r2 score corresponding to  96  is  0.6445102466986317
# r2 score corresponding to  97  is  0.6307525930653644
# r2 score corresponding to  98  is  0.7133051131625936
# r2 score corresponding to  99  is  0.7051622523004916
# max r2 score corresponding to  82  is  0.7621309683410685

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.05,
#  'max_depth': 25,
#  'n_estimators': 200,
#  'num_leaves': 900}

# %%
#LGBM also give provision to define which all columns should be treated as categorical
#So we will use above provision and see what is the result
params={'learning_rate': 0.05,'max_depth': 25,'n_estimators': 200,'num_leaves': 900}
cate_features_name=['CITY', 'LOCALITY', 'c1', 'c2', 'c3', 'c4', 'c5','c6', 'c7', 'c8', 't1', 't2']
max_r_score=0
for r_state in range(42,100):
    x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = r_state,test_size=0.20)
    d_train = lgb.Dataset(x_train, label=y_train)
    lgb_model = lgb.train(params, d_train, categorical_feature = cate_features_name)
    y_pred = lgb_model.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print("r2 score corresponding to ",r_state," is ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
# Out:
# r2 score corresponding to  42  is  0.7579184160139962
# r2 score corresponding to  43  is  0.7809430481295782
# r2 score corresponding to  44  is  0.7472342121877898
# r2 score corresponding to  45  is  0.7267229491462726
# r2 score corresponding to  46  is  0.7626055413785982
# r2 score corresponding to  47  is  0.7365411184827896
# r2 score corresponding to  48  is  0.742777309650922
# r2 score corresponding to  49  is  0.6627247120737827
# r2 score corresponding to  50  is  0.754914264696
# r2 score corresponding to  51  is  0.7477201078555973
# r2 score corresponding to  52  is  0.6621709258914668
# r2 score corresponding to  53  is  0.7448079207351384
# r2 score corresponding to  54  is  0.7446493823883447
# r2 score corresponding to  55  is  0.7494378470428067
# r2 score corresponding to  56  is  0.7377047921093476
# r2 score corresponding to  57  is  0.733106904395517
# r2 score corresponding to  58  is  0.6658756668537175
# r2 score corresponding to  59  is  0.7689480729958781
# r2 score corresponding to  60  is  0.7553757705879368
# r2 score corresponding to  61  is  0.7515839968275326
# r2 score corresponding to  62  is  0.6752526016192812
# r2 score corresponding to  63  is  0.7493225728698063
# r2 score corresponding to  64  is  0.6819975089952355
# r2 score corresponding to  65  is  0.733656931391361
# r2 score corresponding to  66  is  0.7402411577881074
# r2 score corresponding to  67  is  0.7463507347076828
# r2 score corresponding to  68  is  0.7511308272105326
# r2 score corresponding to  69  is  0.680000833038791
# r2 score corresponding to  70  is  0.7247816705556867
# r2 score corresponding to  71  is  0.7596517696706846
# r2 score corresponding to  72  is  0.7621501532948909
# r2 score corresponding to  73  is  0.7172754401426975
# r2 score corresponding to  74  is  0.761893535707397
# r2 score corresponding to  75  is  0.7056697965168424
# r2 score corresponding to  76  is  0.7652337802407014
# r2 score corresponding to  77  is  0.7692372588385117
# r2 score corresponding to  78  is  0.6987678173723499
# r2 score corresponding to  79  is  0.7759991218042763
# r2 score corresponding to  80  is  0.7510442383359224
# r2 score corresponding to  81  is  0.751197989411669
# r2 score corresponding to  82  is  0.7746651271092997
# r2 score corresponding to  83  is  0.6755002044394705
# r2 score corresponding to  84  is  0.7633590120858121
# r2 score corresponding to  85  is  0.7694036275963945
# r2 score corresponding to  86  is  0.7575151939212528
# r2 score corresponding to  87  is  0.7577561255251987
# r2 score corresponding to  88  is  0.7480756915647593
# r2 score corresponding to  89  is  0.756898169370943
# r2 score corresponding to  90  is  0.7411971559209358
# r2 score corresponding to  91  is  0.7767498147170335
# r2 score corresponding to  92  is  0.7554421346632689
# r2 score corresponding to  93  is  0.7792297687960802
# r2 score corresponding to  94  is  0.7784418940286127
# r2 score corresponding to  95  is  0.7611592991833125
# r2 score corresponding to  96  is  0.670398448879588
# r2 score corresponding to  97  is  0.6597932652675617
# r2 score corresponding to  98  is  0.7422153421643143
# r2 score corresponding to  99  is  0.73470693575789
# max r2 score corresponding to  43  is  0.7809430481295782

# %%
#lets make a function which evaluates the model using cross_val_score
from sklearn.model_selection import cross_val_score
def model_evaluation(model,x,y):
    c_scores=cross_val_score(model,x,y,cv=5,scoring="r2")
    print("Mean r2 score for regressor: ",c_scores.mean())
    print("standard deviation in r2 score for regressor: ",c_scores.std())
    print(c_scores)

# %%
#The above model i.e light gradient boosting works better when categorical features are defined
#So we will use this to create our final model
#Also when compared to random forest its giving better and fast results
#Lets chcek the cross_val_scores
from sklearn.model_selection import KFold
scores=[]
cate_features_name=['CITY', 'LOCALITY', 'c1', 'c2', 'c3', 'c4', 'c5','c6', 'c7', 'c8', 't1', 't2']
k_fold = KFold(n_splits=5)
for train_index,test_index in k_fold.split(df_x):
    x_train, x_test, y_train, y_test = df_x.iloc[train_index], df_x.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    d_train = lgb.Dataset(x_train, label=y_train)
    lgb_model = lgb.train(params, d_train, categorical_feature = cate_features_name)
    y_pred = lgb_model.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    scores.append(r2_scr)
print("Mean r2 score for lgbm regressor: ",np.array(scores).mean())
print("standard deviation in r2 score for lgbm regressor: ",np.array(scores).std())
print(scores)
# Out:
# Mean r2 score for lgbm regressor:  0.7428185078381448
# standard deviation in r2 score for lgbm regressor:  0.040663100711159667
# [0.6629520110002265, 0.7692618925102895, 0.7551195983056711, 0.7535636711389538, 0.773195366235583]

# %%
#lets chcek for random forset
print("RANDOM FOREST\n\n")
model_evaluation(rfr,df_x,y)
# Out:
# RANDOM FOREST
#
#
# Mean r2 score for regressor:  0.7051554902429198
# standard deviation in r2 score for regressor:  0.04389099660832986
# [0.63597276 0.74480699 0.67784051 0.71222735 0.75492984]

# %%
x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = 43,test_size=0.20)
d_train = lgb.Dataset(x_train, label=y_train)
lgb_model = lgb.train(params, d_train, categorical_feature = cate_features_name)
y_pred = lgb_model.predict(x_test)

# %%
#Lets find the rmse and r2_score using sklearn.metrics for random forest model
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2_score is: ",r2_score(y_test,y_pred))
# Out:
# RMSE is:  294.1701845492247
# r2_score is:  0.7809430481295782

# %%
#From above we see lgbm is performing better so we will use it to make our final predictions
cost_pred=lgb_model.predict(df_test)

# %%
#lets make the dataframe for cost_pred
cost_pred=pd.DataFrame(cost_pred,columns=["COST"])

# %%
#Lets save the submission to csv
cost_pred.to_csv("Item_outlet_sales_Predictions.csv",index=False)
