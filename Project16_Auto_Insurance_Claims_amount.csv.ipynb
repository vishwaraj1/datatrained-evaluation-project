# %%
import pandas as pd
df_claim=pd.read_csv("Auto_Insurance_Claims_amount.csv")
df_claim
# Out:
#      Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0     BU79786      US         KS    Kansas    276.351928       No     Basic
# 1     QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2     AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3     WW63253      US         MO  Missouri    764.586183       No     Basic
# 4     HB64268      US         KS    Kansas    281.369258       No     Basic
# 5     OC83172      US         IA      Iowa    825.629780      Yes     Basic
# 6     XZ87318      US         IA      Iowa    538.089864      Yes     Basic
# 7     CF85061      US         NE  Nebraska    721.610031       No   Premium
# 8     DY87989      US         IA      Iowa   2412.750402      Yes     Basic
# 9     BQ94931      US         IA      Iowa    738.817808       No  Extended
# 10    SX51350      US         MO  Missouri    473.899202       No     Basic
# 11    VQ65197      US         MO  Missouri    819.719708       No     Basic
# 12    DP39365      US         MO  Missouri    879.879700       No   Premium
# 13    SJ95423      US         NE  Nebraska    881.901893      Yes     Basic
# 14    IL66569      US         MO  Missouri    538.443166       No     Basic
# 15    BW63560      US         IA      Iowa    746.313938       No     Basic
# 16    FV94802      US         OK  Oklahoma    256.686782       No     Basic
# 17    OE15005      US         MO  Missouri    394.524160       No     Basic
# 18    WC83389      US         IA      Iowa    571.033311       No     Basic
# 19    FL50705      US         MO  Missouri    816.261705       No   Premium
# 20    ZK25313      US         IA      Iowa    287.205127       No     Basic
# 21    SV62436      US         KS    Kansas    304.179156       No  Extended
# 22    YH23384      US         NE  Nebraska   2412.750402      Yes     Basic
# 23    TZ98966      US         OK  Oklahoma    245.019100       No     Basic
# 24    HM55802      US         MO  Missouri    239.210789       No     Basic
# 25    FS42516      US         IA      Iowa    580.206598       No     Basic
# 26    US89481      US         MO  Missouri    394.637208       No   Premium
# 27    HO30839      US         KS    Kansas    534.691658       No  Extended
# 28    GE62437      US         NE  Nebraska   1290.256014       No   Premium
# 29    EJ77678      US         IA      Iowa    323.536047       No  Extended
# ...       ...     ...        ...       ...           ...      ...       ...
# 9104  LM97847      US         MO  Missouri    261.513922       No     Basic
# 9105  IK96366      US         MO  Missouri    555.139817       No  Extended
# 9106  SJ86522      US         MO  Missouri    682.704442       No     Basic
# 9107  UU42868      US         MO  Missouri    561.968908      Yes   Premium
# 9108  GX11087      US         MO  Missouri    390.702875       No     Basic
# 9109  JR41742      US         MO  Missouri    362.287212       No     Basic
# 9110  RA89822      US         MO  Missouri   3461.137896      Yes     Basic
# 9111  IJ25462      US         MO  Missouri    284.552093       No     Basic
# 9112  ZP86347      US         MO  Missouri    550.057741       No  Extended
# 9113  HO82823      US         MO  Missouri    335.853294       No  Extended
# 9114  EA54906      US         MO  Missouri    750.166132       No  Extended
# 9115  BC64697      US         MO  Missouri   1166.398572       No   Premium
# 9116  VV68726      US         MO  Missouri    513.339776       No     Basic
# 9117  QR91631      US         MO  Missouri    873.209053       No     Basic
# 9118  OT56964      US         MO  Missouri    942.425684       No     Basic
# 9119  YX35990      US         MO  Missouri    547.955508      Yes     Basic
# 9120  RN61682      US         MO  Missouri    211.473847       No     Basic
# 9121  BB10681      US         MO  Missouri    414.064865       No  Extended
# 9122  FH43628      US         MO  Missouri   2546.482059      Yes  Extended
# 9123  WZ45103      US         MO  Missouri    567.805017      Yes  Extended
# 9124  CB59349      US         MO  Missouri   1626.158550       No  Extended
# 9125  RX91025      US         MO  Missouri   1987.226200       No   Premium
# 9126  AC13887      US         MO  Missouri    462.899533       No     Basic
# 9127  TF56202      US         MO  Missouri    503.216550       No     Basic
# 9128  YM19146      US         MO  Missouri    410.039853       No   Premium
# 9129  LA72316      US         MO  Missouri   2340.598798       No     Basic
# 9130  PK87824      US         MO  Missouri    309.651122      Yes  Extended
# 9131  TD14365      US         MO  Missouri    816.389043       No  Extended
# 9132  UP19263      US         MO  Missouri    752.444244       No  Extended
# 9133  Y167826      US         MO  Missouri    261.183687       No  Extended
#
#                  Education Effective To Date EmploymentStatus  ...  \
# 0                 Bachelor           2/24/11         Employed  ...
# 1                 Bachelor           1/31/11       Unemployed  ...
# 2                 Bachelor           2/19/11         Employed  ...
# 3                 Bachelor           1/20/11       Unemployed  ...
# 4                 Bachelor            2/3/11         Employed  ...
# 5                 Bachelor           1/25/11         Employed  ...
# 6                  College           2/24/11         Employed  ...
# 7                   Master           1/18/11       Unemployed  ...
# 8                 Bachelor           1/26/11    Medical Leave  ...
# 9                  College           2/17/11         Employed  ...
# 10                 College           2/21/11       Unemployed  ...
# 11                 College            1/6/11       Unemployed  ...
# 12                  Master            2/6/11         Employed  ...
# 13    High School or Below           1/10/11         Employed  ...
# 14                 College           1/18/11         Employed  ...
# 15                Bachelor           1/17/11         Employed  ...
# 16    High School or Below            2/6/11    Medical Leave  ...
# 17                 College            1/5/11    Medical Leave  ...
# 18                 College           2/27/11         Employed  ...
# 19    High School or Below           1/14/11         Employed  ...
# 20    High School or Below           2/19/11         Employed  ...
# 21                Bachelor           1/21/11         Disabled  ...
# 22                Bachelor           1/26/11    Medical Leave  ...
# 23                Bachelor           2/24/11       Unemployed  ...
# 24                Bachelor            2/5/11         Disabled  ...
# 25                 College           1/29/11         Employed  ...
# 26                Bachelor           2/28/11       Unemployed  ...
# 27                  Master           2/12/11         Disabled  ...
# 28                 College            2/2/11         Employed  ...
# 29                  Master            2/7/11         Employed  ...
# ...                    ...               ...              ...  ...
# 9104               College            1/9/11         Employed  ...
# 9105               College           2/22/11         Employed  ...
# 9106  High School or Below           1/12/11       Unemployed  ...
# 9107  High School or Below           1/26/11       Unemployed  ...
# 9108  High School or Below           1/28/11       Unemployed  ...
# 9109               College           1/25/11       Unemployed  ...
# 9110  High School or Below           1/14/11         Employed  ...
# 9111              Bachelor            2/7/11         Employed  ...
# 9112               College           2/12/11         Employed  ...
# 9113              Bachelor            1/6/11         Employed  ...
# 9114  High School or Below           2/23/11         Employed  ...
# 9115               College           2/17/11       Unemployed  ...
# 9116  High School or Below           1/26/11         Disabled  ...
# 9117  High School or Below           1/20/11         Employed  ...
# 9118                Master           2/10/11         Employed  ...
# 9119                Master           1/13/11         Employed  ...
# 9120              Bachelor           2/19/11       Unemployed  ...
# 9121               College           1/17/11       Unemployed  ...
# 9122               College            2/1/11          Retired  ...
# 9123              Bachelor           1/19/11       Unemployed  ...
# 9124                Master           1/20/11         Employed  ...
# 9125  High School or Below           1/31/11       Unemployed  ...
# 9126              Bachelor            1/9/11       Unemployed  ...
# 9127               College           2/12/11         Employed  ...
# 9128               College            1/6/11         Employed  ...
# 9129              Bachelor           2/10/11         Employed  ...
# 9130               College           2/12/11         Employed  ...
# 9131              Bachelor            2/6/11       Unemployed  ...
# 9132               College            2/3/11         Employed  ...
# 9133               College           2/14/11       Unemployed  ...
#
#      Months Since Policy Inception  Number of Open Complaints  \
# 0                                5                          0
# 1                               42                          0
# 2                               38                          0
# 3                               65                          0
# 4                               44                          0
# 5                               94                          0
# 6                               13                          0
# 7                               68                          0
# 8                                3                          0
# 9                                7                          0
# 10                               5                          0
# 11                              87                          0
# 12                              82                          2
# 13                              25                          1
# 14                              10                          2
# 15                              50                          1
# 16                               7                          0
# 17                              59                          0
# 18                               1                          0
# 19                              21                          0
# 20                              21                          0
# 21                              49                          0
# 22                               3                          0
# 23                              44                          3
# 24                              91                          0
# 25                               1                          0
# 26                              47                          0
# 27                              64                          0
# 28                              54                          2
# 29                              44                          1
# ...                            ...                        ...
# 9104                            59                          0
# 9105                            77                          3
# 9106                            26                          0
# 9107                             5                          0
# 9108                             8                          0
# 9109                            52                          0
# 9110                            59                          0
# 9111                            44                          1
# 9112                            60                          0
# 9113                            48                          0
# 9114                            86                          0
# 9115                            34                          0
# 9116                            59                          0
# 9117                            52                          0
# 9118                            11                          0
# 9119                            30                          1
# 9120                            69                          5
# 9121                            35                          2
# 9122                            66                          0
# 9123                            44                          0
# 9124                            42                          0
# 9125                            35                          0
# 9126                            21                          0
# 9127                            48                          0
# 9128                            58                          0
# 9129                            89                          0
# 9130                            28                          0
# 9131                            37                          3
# 9132                             3                          0
# 9133                            90                          0
#
#      Number of Policies     Policy Type        Policy  Claim Reason  \
# 0                     1  Corporate Auto  Corporate L3     Collision
# 1                     8   Personal Auto   Personal L3  Scratch/Dent
# 2                     2   Personal Auto   Personal L3     Collision
# 3                     7  Corporate Auto  Corporate L2     Collision
# 4                     1   Personal Auto   Personal L1     Collision
# 5                     2   Personal Auto   Personal L3          Hail
# 6                     9  Corporate Auto  Corporate L3     Collision
# 7                     4  Corporate Auto  Corporate L3     Collision
# 8                     2  Corporate Auto  Corporate L3     Collision
# 9                     8    Special Auto    Special L2          Hail
# 10                    3   Personal Auto   Personal L3     Collision
# 11                    3   Personal Auto   Personal L3          Hail
# 12                    3  Corporate Auto  Corporate L1          Hail
# 13                    8  Corporate Auto  Corporate L3          Hail
# 14                    8  Corporate Auto  Corporate L3         Other
# 15                    2  Corporate Auto  Corporate L2          Hail
# 16                    1   Personal Auto   Personal L3          Hail
# 17                    1   Personal Auto   Personal L2  Scratch/Dent
# 18                    7   Personal Auto   Personal L2          Hail
# 19                    3  Corporate Auto  Corporate L2     Collision
# 20                    1   Personal Auto   Personal L2     Collision
# 21                    1   Personal Auto   Personal L3         Other
# 22                    2   Personal Auto   Personal L3     Collision
# 23                    1  Corporate Auto  Corporate L3     Collision
# 24                    1  Corporate Auto  Corporate L2          Hail
# 25                    3   Personal Auto   Personal L3          Hail
# 26                    1   Personal Auto   Personal L3     Collision
# 27                    1  Corporate Auto  Corporate L1     Collision
# 28                    2   Personal Auto   Personal L3     Collision
# 29                    1   Personal Auto   Personal L3          Hail
# ...                 ...             ...           ...           ...
# 9104                  1   Personal Auto   Personal L2          Hail
# 9105                  3   Personal Auto   Personal L1     Collision
# 9106                  9  Corporate Auto  Corporate L3          Hail
# 9107                  1  Corporate Auto  Corporate L2          Hail
# 9108                  1   Personal Auto   Personal L2     Collision
# 9109                  1  Corporate Auto  Corporate L3     Collision
# 9110                  2   Personal Auto   Personal L2          Hail
# 9111                  1   Personal Auto   Personal L2  Scratch/Dent
# 9112                  1   Personal Auto   Personal L3  Scratch/Dent
# 9113                  1   Personal Auto   Personal L3          Hail
# 9114                  3  Corporate Auto  Corporate L1          Hail
# 9115                  2   Personal Auto   Personal L3  Scratch/Dent
# 9116                  3   Personal Auto   Personal L2     Collision
# 9117                  2   Personal Auto   Personal L1          Hail
# 9118                  3  Corporate Auto  Corporate L3     Collision
# 9119                  3  Corporate Auto  Corporate L2     Collision
# 9120                  1   Personal Auto   Personal L2  Scratch/Dent
# 9121                  1  Corporate Auto  Corporate L3     Collision
# 9122                  2   Personal Auto   Personal L2     Collision
# 9123                  3   Personal Auto   Personal L2          Hail
# 9124                  2   Personal Auto   Personal L3          Hail
# 9125                  2   Personal Auto   Personal L3     Collision
# 9126                  4  Corporate Auto  Corporate L1     Collision
# 9127                  3   Personal Auto   Personal L3          Hail
# 9128                  1   Personal Auto   Personal L2     Collision
# 9129                  2   Personal Auto   Personal L1          Hail
# 9130                  1  Corporate Auto  Corporate L3     Collision
# 9131                  2  Corporate Auto  Corporate L2     Collision
# 9132                  3   Personal Auto   Personal L2  Scratch/Dent
# 9133                  1  Corporate Auto  Corporate L3         Other
#
#       Sales Channel  Total Claim Amount  Vehicle Class Vehicle Size
# 0             Agent          384.811147   Two-Door Car      Medsize
# 1             Agent         1131.464935  Four-Door Car      Medsize
# 2             Agent          566.472247   Two-Door Car      Medsize
# 3       Call Center          529.881344            SUV      Medsize
# 4             Agent          138.130879  Four-Door Car      Medsize
# 5               Web          159.383042   Two-Door Car      Medsize
# 6             Agent          321.600000  Four-Door Car      Medsize
# 7             Agent          363.029680  Four-Door Car      Medsize
# 8             Agent          511.200000  Four-Door Car      Medsize
# 9            Branch          425.527834  Four-Door Car      Medsize
# 10            Agent          482.400000  Four-Door Car        Small
# 11            Agent          528.000000            SUV      Medsize
# 12            Agent          472.029737  Four-Door Car      Medsize
# 13           Branch          528.000000            SUV      Medsize
# 14      Call Center          307.139132  Four-Door Car      Medsize
# 15           Branch           42.920271  Four-Door Car      Medsize
# 16      Call Center          454.245098   Two-Door Car      Medsize
# 17      Call Center          647.442031            SUV      Medsize
# 18           Branch          308.981664  Four-Door Car      Medsize
# 19      Call Center          484.800000  Four-Door Car        Small
# 20           Branch          355.200000   Two-Door Car      Medsize
# 21      Call Center          379.200000  Four-Door Car      Medsize
# 22            Agent          511.200000  Four-Door Car      Medsize
# 23           Branch          554.376763  Four-Door Car      Medsize
# 24           Branch          439.200000  Four-Door Car      Medsize
# 25      Call Center          389.185006  Four-Door Car        Large
# 26            Agent          799.200000  Four-Door Car        Small
# 27           Branch          516.237951            SUV      Medsize
# 28      Call Center          532.800000  Four-Door Car        Large
# 29           Branch          384.000000  Four-Door Car        Small
# ...             ...                 ...            ...          ...
# 9104          Agent          250.652309  Four-Door Car      Medsize
# 9105         Branch          364.800000   Two-Door Car      Medsize
# 9106          Agent          956.689634            SUV      Medsize
# 9107            Web         1027.000029            SUV      Medsize
# 9108          Agent          666.042098            SUV      Medsize
# 9109         Branch         1254.177129            SUV      Medsize
# 9110          Agent          523.200000     Sports Car      Medsize
# 9111          Agent          400.832857  Four-Door Car        Small
# 9112          Agent          165.478147            SUV      Medsize
# 9113          Agent            6.880385  Four-Door Car      Medsize
# 9114         Branch          331.170924  Four-Door Car      Medsize
# 9115    Call Center          513.600000  Four-Door Car        Small
# 9116          Agent          331.200000  Four-Door Car        Small
# 9117         Branch          185.530076   Two-Door Car      Medsize
# 9118          Agent          322.575677            SUV      Medsize
# 9119         Branch          326.400000  Four-Door Car        Small
# 9120            Web          518.400000  Four-Door Car      Medsize
# 9121         Branch          590.400000            SUV      Medsize
# 9122         Branch          465.600000  Four-Door Car        Small
# 9123          Agent          364.800000  Four-Door Car        Small
# 9124          Agent          643.200000            SUV      Medsize
# 9125          Agent         1950.725547            SUV        Small
# 9126         Branch          482.400000   Two-Door Car      Medsize
# 9127    Call Center          307.200000   Two-Door Car        Small
# 9128         Branch          541.282007  Four-Door Car        Large
# 9129            Web          198.234764  Four-Door Car      Medsize
# 9130         Branch          379.200000  Four-Door Car      Medsize
# 9131         Branch          790.784983  Four-Door Car      Medsize
# 9132         Branch          691.200000  Four-Door Car        Large
# 9133    Call Center          369.600000   Two-Door Car      Medsize
#
# [9134 rows x 26 columns]

# %%
#Lets check the null values in the dataset
df_claim.isnull().sum()
# Out:
# Customer                         0
# Country                          0
# State Code                       0
# State                            0
# Claim Amount                     0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Claim Reason                     0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
#Lets chcek the datatypes of the column
df_claim.dtypes
# Out:
# Customer                          object
# Country                           object
# State Code                        object
# State                             object
# Claim Amount                     float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Claim Reason                      object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# Vehicle Size                      object
# dtype: object

# %%
#Lets chcek the value counts
for col in df_claim.columns:
    if df_claim[col].dtype=="object":
        print(df_claim[col].value_counts())
        print()
#We see no customer is repeated so each customer is only availabe once in the dataset
#All instances are for one country US so we can drop this column as it is constant having no variance
#We can drop one of the column from "State Code" and "State" as both show same info
#Also we observe all the claims info are for single year
# Out:
# MN62189    1
# BB10681    1
# HN35280    1
# IA67715    1
# GY40926    1
# OY95386    1
# VE72838    1
# DU60004    1
# OX73233    1
# LD75023    1
# XY78443    1
# UO12263    1
# XO78284    1
# AQ25590    1
# AM99192    1
# GI89160    1
# XP41644    1
# CQ78705    1
# JZ61928    1
# XK20264    1
# QB24570    1
# UX92071    1
# EF13716    1
# EG97649    1
# TP10619    1
# BF45697    1
# NM77390    1
# BU72633    1
# QB14087    1
# KH44031    1
#           ..
# SC43870    1
# GT18023    1
# QM39493    1
# BE62503    1
# CQ59706    1
# YI89801    1
# OP75571    1
# BK76107    1
# GV68933    1
# ZB85648    1
# QA50777    1
# QL80621    1
# NT38409    1
# FT86104    1
# AO74776    1
# XU97999    1
# GM61951    1
# AT72574    1
# GX32768    1
# DM95829    1
# ZV55368    1
# UA50747    1
# AU98438    1
# OH23893    1
# DR84843    1
# EV95033    1
# WO83615    1
# PP64004    1
# EQ90867    1
# GD89605    1
# Name: Customer, Length: 9134, dtype: int64
#
# US    9134
# Name: Country, dtype: int64
#
# MO    3150
# IA    2601
# NE    1703
# OK     882
# KS     798
# Name: State Code, dtype: int64
#
# Missouri    3150
# Iowa        2601
# Nebraska    1703
# Oklahoma     882
# Kansas       798
# Name: State, dtype: int64
#
# No     7826
# Yes    1308
# Name: Response, dtype: int64
#
# Basic       5568
# Extended    2742
# Premium      824
# Name: Coverage, dtype: int64
#
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: Education, dtype: int64
#
# 1/10/11    195
# 1/27/11    194
# 2/14/11    186
# 1/26/11    181
# 1/17/11    180
# 1/19/11    179
# 1/3/11     178
# 1/31/11    178
# 1/20/11    173
# 1/28/11    169
# 2/26/11    169
# 2/19/11    168
# 1/5/11     167
# 2/27/11    167
# 1/11/11    166
# 2/4/11     164
# 2/10/11    161
# 2/28/11    161
# 1/29/11    160
# 1/21/11    160
# 1/2/11     160
# 2/3/11     158
# 2/22/11    158
# 2/5/11     158
# 2/7/11     157
# 2/12/11    156
# 1/23/11    155
# 2/1/11     154
# 1/18/11    154
# 1/15/11    153
# 1/14/11    152
# 1/25/11    151
# 2/11/11    151
# 1/7/11     151
# 1/8/11     149
# 2/2/11     149
# 2/18/11    149
# 2/25/11    149
# 2/21/11    148
# 1/1/11     148
# 1/24/11    147
# 1/9/11     146
# 1/13/11    145
# 1/30/11    145
# 2/6/11     144
# 2/23/11    143
# 1/6/11     143
# 1/16/11    142
# 2/16/11    139
# 2/24/11    139
# 2/13/11    139
# 2/9/11     137
# 1/22/11    136
# 2/17/11    136
# 2/8/11     134
# 2/20/11    132
# 2/15/11    130
# 1/12/11    126
# 1/4/11     115
# Name: Effective To Date, dtype: int64
#
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: EmploymentStatus, dtype: int64
#
# F    4658
# M    4476
# Name: Gender, dtype: int64
#
# Suburban    5779
# Rural       1773
# Urban       1582
# Name: Location Code, dtype: int64
#
# Married     5298
# Single      2467
# Divorced    1369
# Name: Marital Status, dtype: int64
#
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# Name: Policy Type, dtype: int64
#
# Personal L3     3426
# Personal L2     2122
# Personal L1     1240
# Corporate L3    1014
# Corporate L2     595
# Corporate L1     359
# Special L2       164
# Special L3       148
# Special L1        66
# Name: Policy, dtype: int64
#
# Collision       3752
# Hail            2926
# Scratch/Dent    1432
# Other           1024
# Name: Claim Reason, dtype: int64
#
# Agent          3477
# Branch         2567
# Call Center    1765
# Web            1325
# Name: Sales Channel, dtype: int64
#
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports Car        484
# Luxury SUV        184
# Luxury Car        163
# Name: Vehicle Class, dtype: int64
#
# Medsize    6424
# Small      1764
# Large       946
# Name: Vehicle Size, dtype: int64

# %%
df_claim.columns
# Out:
# Index(['Customer', 'Country', 'State Code', 'State', 'Claim Amount',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Claim Reason',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
#As discussed above some of the columns can be dropped
df_claim.drop(columns=["Customer","Country","State Code","Effective To Date"],inplace=True)

# %%
#Lets do the some graphical EDA
#what is the average claim amount from each states
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x="State",y="Claim Amount",data=df_claim)
plt.show()

# %%
#Lets chcek the total claim amount
sns.barplot(x="State",y="Total Claim Amount",data=df_claim)
plt.show()
#we see average total claim amount in each state is less than claim amount in each state

# %%
#Lets check the count of claim reasons
sns.countplot(x="Claim Reason",data=df_claim)
plt.show()
#Most of the claim reasons are of type "Collision"

# %%
#Through which channel claims were more
sns.countplot(x="Sales Channel",data=df_claim)
plt.show()
#people genrally prefer opting for agent

# %%
#lets check the vehicle class
sns.countplot(x="Vehicle Class",data=df_claim)
plt.show()
#insurance is mainly claimed for "four door car"

# %%
#which state is having on an averge more number of policies
sns.barplot(x="State",y="Number of Policies",data=df_claim)
plt.show()

# %%
#Which state on an averge has more open complaints
sns.barplot(x="State",y="Number of Open Complaints",data=df_claim)
plt.show()
#so each state has less than 1 complaint on an averge pending

# %%
#lets chcek the responses
sns.countplot(x="Response",data=df_claim)
plt.show()
#The amounnt of customers with no response is quite high

# %%
#lets chcek the average claim amount based on employment status
sns.barplot(x="EmploymentStatus",y="Claim Amount",data=df_claim)
plt.show()

# %%
#Lets check the correlation matrix
df_claim.corr()
# Out:
#                                Claim Amount    Income  Monthly Premium Auto  \
# Claim Amount                       1.000000  0.024366              0.396262
# Income                             0.024366  1.000000             -0.016665
# Monthly Premium Auto               0.396262 -0.016665              1.000000
# Months Since Last Claim            0.011517 -0.026715              0.005026
# Months Since Policy Inception      0.009418 -0.000875              0.020257
# Number of Open Complaints         -0.036343  0.006408             -0.013122
# Number of Policies                 0.021955 -0.008656             -0.011233
# Total Claim Amount                 0.226451 -0.355254              0.632017
#
#                                Months Since Last Claim  \
# Claim Amount                                  0.011517
# Income                                       -0.026715
# Monthly Premium Auto                          0.005026
# Months Since Last Claim                       1.000000
# Months Since Policy Inception                -0.042959
# Number of Open Complaints                     0.005354
# Number of Policies                            0.009136
# Total Claim Amount                            0.007563
#
#                                Months Since Policy Inception  \
# Claim Amount                                        0.009418
# Income                                             -0.000875
# Monthly Premium Auto                                0.020257
# Months Since Last Claim                            -0.042959
# Months Since Policy Inception                       1.000000
# Number of Open Complaints                          -0.001158
# Number of Policies                                 -0.013333
# Total Claim Amount                                  0.003335
#
#                                Number of Open Complaints  Number of Policies  \
# Claim Amount                                   -0.036343            0.021955
# Income                                          0.006408           -0.008656
# Monthly Premium Auto                           -0.013122           -0.011233
# Months Since Last Claim                         0.005354            0.009136
# Months Since Policy Inception                  -0.001158           -0.013333
# Number of Open Complaints                       1.000000            0.001498
# Number of Policies                              0.001498            1.000000
# Total Claim Amount                             -0.014241           -0.002354
#
#                                Total Claim Amount
# Claim Amount                             0.226451
# Income                                  -0.355254
# Monthly Premium Auto                     0.632017
# Months Since Last Claim                  0.007563
# Months Since Policy Inception            0.003335
# Number of Open Complaints               -0.014241
# Number of Policies                      -0.002354
# Total Claim Amount                       1.000000

# %%
#Lets get the list of categorical_features
cate_feat_list=list()
for col in df_claim.columns:
    if df_claim[col].dtype=="object":
        cate_feat_list.append(col)

# %%
#using labelencoder to convert all the object type columns to int
from sklearn.preprocessing import LabelEncoder
for col in df_claim.columns:
    if df_claim[col].dtype=="object":
        df_claim[col]=LabelEncoder().fit_transform(df_claim[col])

# %%
#Lets divide the dataset into input and output
df_x=df_claim.drop(columns=["Claim Amount"])
y=df_claim[["Claim Amount"]]

# %%
#to find random stat which gives maximum r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,df_x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to ",r_state," is ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
#Lets use light gradient boosting technique
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
lg = lgb.LGBMRegressor(silent=False)
param_dist = {"max_depth": [25,50, 75],
              "learning_rate" : [0.01,0.05,0.1],
              "num_leaves": [300,900,1200],
              "n_estimators": [200]
             }
grid_search = GridSearchCV(lg, n_jobs=-1, param_grid=param_dist, cv = 5, scoring="r2")
grid_search.fit(df_x,y)
grid_search.best_params_
# Out:
# {'learning_rate': 0.01,
#  'max_depth': 25,
#  'n_estimators': 200,
#  'num_leaves': 300}

# %%
#LGBM also give provision to define which all columns should be treated as categorical
#So we will use above provision and see what is the result
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")
params={'learning_rate': 0.01,'max_depth': 25,'n_estimators': 200,'num_leaves': 300}
max_r_score=0
for r_state in range(42,100):
    x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = r_state,test_size=0.20)
    d_train = lgb.Dataset(x_train, label=y_train)
    lgb_model = lgb.train(params, d_train,categorical_feature=cate_feat_list)
    y_pred = lgb_model.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print("r2 score corresponding to ",r_state," is ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
# Out:
# r2 score corresponding to  42  is  0.6679139743424847
# r2 score corresponding to  43  is  0.6796946891904971
# r2 score corresponding to  44  is  0.6750425971475376
# r2 score corresponding to  45  is  0.7041462167420176
# r2 score corresponding to  46  is  0.6725258535498253
# r2 score corresponding to  47  is  0.7080686817373728
# r2 score corresponding to  48  is  0.7071765515116004
# r2 score corresponding to  49  is  0.6957093097610016
# r2 score corresponding to  50  is  0.6677646711445523
# r2 score corresponding to  51  is  0.6732860283414941
# r2 score corresponding to  52  is  0.6692509319316637
# r2 score corresponding to  53  is  0.673288072904414
# r2 score corresponding to  54  is  0.6685675555094752
# r2 score corresponding to  55  is  0.6907435772640325
# r2 score corresponding to  56  is  0.6674991010751773
# r2 score corresponding to  57  is  0.6913872007719939
# r2 score corresponding to  58  is  0.6692437837332921
# r2 score corresponding to  59  is  0.6905270304465361
# r2 score corresponding to  60  is  0.671837217321429
# r2 score corresponding to  61  is  0.6897853482749945
# r2 score corresponding to  62  is  0.6860969032244186
# r2 score corresponding to  63  is  0.6854179859186564
# r2 score corresponding to  64  is  0.7007051995508902
# r2 score corresponding to  65  is  0.6776976163467716
# r2 score corresponding to  66  is  0.7007547331001386
# r2 score corresponding to  67  is  0.7011331550526341
# r2 score corresponding to  68  is  0.6992920546892811
# r2 score corresponding to  69  is  0.683723116760875
# r2 score corresponding to  70  is  0.6748422976855164
# r2 score corresponding to  71  is  0.6816211251555618
# r2 score corresponding to  72  is  0.6788932355130524
# r2 score corresponding to  73  is  0.6801293892135082
# r2 score corresponding to  74  is  0.6778911245623154
# r2 score corresponding to  75  is  0.6953138967694752
# r2 score corresponding to  76  is  0.7088953459738603
# r2 score corresponding to  77  is  0.6861189865451817
# r2 score corresponding to  78  is  0.6909854221338732
# r2 score corresponding to  79  is  0.6753158677183724
# r2 score corresponding to  80  is  0.69273122455513
# r2 score corresponding to  81  is  0.6937475684689178
# r2 score corresponding to  82  is  0.6916955801106903
# r2 score corresponding to  83  is  0.6887754700970332
# r2 score corresponding to  84  is  0.6562303441824494
# r2 score corresponding to  85  is  0.6858411698102773
# r2 score corresponding to  86  is  0.6813438234793757
# r2 score corresponding to  87  is  0.7313681265305425
# r2 score corresponding to  88  is  0.6877101028199168
# r2 score corresponding to  89  is  0.6849106117757717
# r2 score corresponding to  90  is  0.6722185039162158
# r2 score corresponding to  91  is  0.6622365673227114
# r2 score corresponding to  92  is  0.6767961009188143
# r2 score corresponding to  93  is  0.7213545484695365
# r2 score corresponding to  94  is  0.6777117194258547
# r2 score corresponding to  95  is  0.684544112857952
# r2 score corresponding to  96  is  0.7101135012055317
# r2 score corresponding to  97  is  0.7120893613490644
# r2 score corresponding to  98  is  0.6881776868977292
# r2 score corresponding to  99  is  0.6888473627006304
# max r2 score corresponding to  87  is  0.7313681265305425

# %%
#Lets chcek the cross_val_scores
from sklearn.model_selection import KFold
import numpy as np
scores=[]
k_fold = KFold(n_splits=5)
for train_index,test_index in k_fold.split(df_x):
    x_train, x_test, y_train, y_test = df_x.iloc[train_index], df_x.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    d_train = lgb.Dataset(x_train, label=y_train)
    lgb_model = lgb.train(params, d_train, categorical_feature = cate_feat_list)
    y_pred = lgb_model.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    scores.append(r2_scr)
print("Mean r2 score for lgbm regressor: ",np.array(scores).mean())
print("standard deviation in r2 score for lgbm regressor: ",np.array(scores).std())
print(scores)
# Out:
# Mean r2 score for lgbm regressor:  0.6909282385020374
# standard deviation in r2 score for lgbm regressor:  0.009359123689616687
# [0.6937459395395909, 0.7023530373177671, 0.6929156944250588, 0.6737621612117561, 0.6918643600160139]

# %%
#lets make a function which evaluates the model using cross_val_score for models accept lgbm
from sklearn.model_selection import cross_val_score
def model_evaluation(model,x,y):
    c_scores=cross_val_score(model,x,y,cv=5,scoring="r2")
    print("Mean r2 score for regressor: ",c_scores.mean())
    print("standard deviation in r2 score for regressor: ",c_scores.std())
    print(c_scores)

# %%
#Lets use decision tree
from sklearn.tree import DecisionTreeRegressor
import numpy as np
dtr=DecisionTreeRegressor()
r_state=maxr2_score(dtr,df_x,y)
# Out:
# r2 score corresponding to  42  is  0.4255551405268626
# r2 score corresponding to  43  is  0.5996428041246997
# r2 score corresponding to  44  is  0.43984693378922257
# r2 score corresponding to  45  is  0.38741788004115096
# r2 score corresponding to  46  is  0.5486577174620558
# r2 score corresponding to  47  is  0.4019937815198771
# r2 score corresponding to  48  is  0.3799812342857154
# r2 score corresponding to  49  is  0.5167459002470254
# r2 score corresponding to  50  is  0.5351868139344935
# r2 score corresponding to  51  is  0.4050422613797192
# r2 score corresponding to  52  is  0.45104167121721106
# r2 score corresponding to  53  is  0.43914274984507506
# r2 score corresponding to  54  is  0.3414392166225909
# r2 score corresponding to  55  is  0.43500724264599877
# r2 score corresponding to  56  is  0.48799554851465743
# r2 score corresponding to  57  is  0.4683151425626919
# r2 score corresponding to  58  is  0.44272346116858474
# r2 score corresponding to  59  is  0.4026444093734015
# r2 score corresponding to  60  is  0.4339584549855018
# r2 score corresponding to  61  is  0.5030519807492344
# r2 score corresponding to  62  is  0.44479957235860645
# r2 score corresponding to  63  is  0.47862853173781406
# r2 score corresponding to  64  is  0.4646309111719159
# r2 score corresponding to  65  is  0.38037327342651506
# r2 score corresponding to  66  is  0.366196716826216
# r2 score corresponding to  67  is  0.4542774639044108
# r2 score corresponding to  68  is  0.5297481734242215
# r2 score corresponding to  69  is  0.4593965992459971
# r2 score corresponding to  70  is  0.45950984055202726
# r2 score corresponding to  71  is  0.4495822968648454
# r2 score corresponding to  72  is  0.40495828533482603
# r2 score corresponding to  73  is  0.36726745122527815
# r2 score corresponding to  74  is  0.251215753504372
# r2 score corresponding to  75  is  0.4300553512034604
# r2 score corresponding to  76  is  0.45319365339753515
# r2 score corresponding to  77  is  0.45657315555060607
# r2 score corresponding to  78  is  0.3619818634990677
# r2 score corresponding to  79  is  0.5040748493457771
# r2 score corresponding to  80  is  0.4020776543515294
# r2 score corresponding to  81  is  0.4259531289519388
# r2 score corresponding to  82  is  0.4591531714635383
# r2 score corresponding to  83  is  0.4757590405156227
# r2 score corresponding to  84  is  0.4856777160530191
# r2 score corresponding to  85  is  0.4063332590378691
# r2 score corresponding to  86  is  0.4626756716590865
# r2 score corresponding to  87  is  0.4189739228843101
# r2 score corresponding to  88  is  0.4059351409379357
# r2 score corresponding to  89  is  0.4824335542912376
# r2 score corresponding to  90  is  0.4999192960211378
# r2 score corresponding to  91  is  0.3419343014378048
# r2 score corresponding to  92  is  0.37216969009928824
# r2 score corresponding to  93  is  0.3547616461513474
# r2 score corresponding to  94  is  0.3536160777878946
# r2 score corresponding to  95  is  0.38882945217883313
# r2 score corresponding to  96  is  0.4256750000641978
# r2 score corresponding to  97  is  0.4212136159589289
# r2 score corresponding to  98  is  0.3644232904252088
# r2 score corresponding to  99  is  0.5158164360081039
# max r2 score corresponding to  43  is  0.5996428041246997

# %%
#lets chcek cross val score for decision tree
print("DECISION TREE\n\n")
model_evaluation(dtr,df_x,y)
# Out:
# DECISION TREE
#
#
# Mean r2 score for regressor:  0.4174921271142965
# standard deviation in r2 score for regressor:  0.020683103356426497
# [0.39752541 0.42248354 0.39273188 0.44986676 0.42485304]

# %%
#lets use random forest regressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore")
rfr=RandomForestRegressor()
parameters = {"n_estimators":[10,100,500]}
clf = GridSearchCV(rfr, parameters, cv=5,scoring="r2")
clf.fit(df_x,y)
clf.best_params_
# Out:
# {'n_estimators': 500}

# %%
rfr=RandomForestRegressor(n_estimators=500)
r_state=maxr2_score(rfr,df_x,y)
# Out:
# r2 score corresponding to  42  is  0.6896483825375879
# r2 score corresponding to  43  is  0.7140129560298172
# r2 score corresponding to  44  is  0.672448431903893
# r2 score corresponding to  45  is  0.7175321358439375
# r2 score corresponding to  46  is  0.6990976513089341
# r2 score corresponding to  47  is  0.7268739472560075
# r2 score corresponding to  48  is  0.7140165379679602
# r2 score corresponding to  49  is  0.7144997293179817
# r2 score corresponding to  50  is  0.7001353564511603
# r2 score corresponding to  51  is  0.693235002416493
# r2 score corresponding to  52  is  0.6735019393157591
# r2 score corresponding to  53  is  0.6718562381133537
# r2 score corresponding to  54  is  0.6851502453599208
# r2 score corresponding to  55  is  0.6896226734538661
# r2 score corresponding to  56  is  0.6938161773652305
# r2 score corresponding to  57  is  0.7003399162434549
# r2 score corresponding to  58  is  0.6954471732362397
# r2 score corresponding to  59  is  0.7025019694473171
# r2 score corresponding to  60  is  0.6757832755385521
# r2 score corresponding to  61  is  0.7194776958936024
# r2 score corresponding to  62  is  0.6928054188746341
# r2 score corresponding to  63  is  0.7054144851546056
# r2 score corresponding to  64  is  0.7047079263106766
# r2 score corresponding to  65  is  0.7026052942756621
# r2 score corresponding to  66  is  0.7123372046462566
# r2 score corresponding to  67  is  0.6875982125330757
# r2 score corresponding to  68  is  0.7213403267739669
# r2 score corresponding to  69  is  0.6955428843467661
# r2 score corresponding to  70  is  0.7020302144333748
# r2 score corresponding to  71  is  0.6973337834637712
# r2 score corresponding to  72  is  0.6896489662733618
# r2 score corresponding to  73  is  0.6833593253081702
# r2 score corresponding to  74  is  0.6528805184518924
# r2 score corresponding to  75  is  0.6961423161698734
# r2 score corresponding to  76  is  0.7149516527649673
# r2 score corresponding to  77  is  0.690680810814445
# r2 score corresponding to  78  is  0.6801235511513569
# r2 score corresponding to  79  is  0.6920373625078367
# r2 score corresponding to  80  is  0.704261815796513
# r2 score corresponding to  81  is  0.6978875760944125
# r2 score corresponding to  82  is  0.6814424186312191
# r2 score corresponding to  83  is  0.7124375669791663
# r2 score corresponding to  84  is  0.6850060133120437
# r2 score corresponding to  85  is  0.7029980150908925
# r2 score corresponding to  86  is  0.6897090117965101
# r2 score corresponding to  87  is  0.7145300635591212
# r2 score corresponding to  88  is  0.7013489179607432
# r2 score corresponding to  89  is  0.689986267808521
# r2 score corresponding to  90  is  0.6801030722147957
# r2 score corresponding to  91  is  0.6525362424384915
# r2 score corresponding to  92  is  0.6821624557399695
# r2 score corresponding to  93  is  0.7076597458281444
# r2 score corresponding to  94  is  0.6896018919634497
# r2 score corresponding to  95  is  0.6983611493026822
# r2 score corresponding to  96  is  0.6953135432673052
# r2 score corresponding to  97  is  0.7262604436698117
# r2 score corresponding to  98  is  0.7044146471763988
# r2 score corresponding to  99  is  0.7110573530196375
# max r2 score corresponding to  47  is  0.7268739472560075

# %%
#lets chcek cross val score for decision tree
print("RANDOM FORSET\n\n")
model_evaluation(rfr,df_x,y)
# Out:
# RANDOM FORSET
#
#
# Mean r2 score for regressor:  0.7036454624000903
# standard deviation in r2 score for regressor:  0.007880218625914533
# [0.70052586 0.7176075  0.69939079 0.70609689 0.69460627]
