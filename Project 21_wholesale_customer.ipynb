# %%
#importing the dataset
import pandas as pd
df_spend=pd.read_csv("C:/Users/vishwaraj/Desktop/Wholesale customers data.csv")
df_spend
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185
# ..          ...
# 435        2204
# 436        2346
# 437        1867
# 438        2125
# 439          52
#
# [440 rows x 8 columns]

# %%
#Lets chcek wheher there are null values or not
df_spend.isnull().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
#as mentioned that we can drop features "channel" and "region"
df_spend.drop(columns=["Channel","Region"],inplace=True)

# %%
#displaying the data
df_spend
# Out:
#      Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0    12669   9656     7561     214              2674        1338
# 1     7057   9810     9568    1762              3293        1776
# 2     6353   8808     7684    2405              3516        7844
# 3    13265   1196     4221    6404               507        1788
# 4    22615   5410     7198    3915              1777        5185
# ..     ...    ...      ...     ...               ...         ...
# 435  29703  12051    16027   13135               182        2204
# 436  39228   1431      764    4510                93        2346
# 437  14531  15488    30243     437             14841        1867
# 438  10290   1981     2232    1038               168        2125
# 439   2787   1698     2510      65               477          52
#
# [440 rows x 6 columns]

# %%
#Lets chcek the correlation matrix
df_spend.corr()
#We cans see some high correlations between grocerry and milk,milk and detergents_paper,Grocerry and detergents_paper
# Out:
#                      Fresh      Milk   Grocery    Frozen  Detergents_Paper  \
# Fresh             1.000000  0.100510 -0.011854  0.345881         -0.101953
# Milk              0.100510  1.000000  0.728335  0.123994          0.661816
# Grocery          -0.011854  0.728335  1.000000 -0.040193          0.924641
# Frozen            0.345881  0.123994 -0.040193  1.000000         -0.131525
# Detergents_Paper -0.101953  0.661816  0.924641 -0.131525          1.000000
# Delicassen        0.244690  0.406368  0.205497  0.390947          0.069291
#
#                   Delicassen
# Fresh               0.244690
# Milk                0.406368
# Grocery             0.205497
# Frozen              0.390947
# Detergents_Paper    0.069291
# Delicassen          1.000000

# %%
#lets describe the above Dataset
df_spend.describe()
#there seems to be sigificant difference between mean and median ,so there are outliers
#Also outliers can be wrong value or really high spending
#If we remove outliers we may remove customer group which are making spending most
# Out:
#                Fresh          Milk       Grocery        Frozen  \
# count     440.000000    440.000000    440.000000    440.000000
# mean    12000.297727   5796.265909   7951.277273   3071.931818
# std     12647.328865   7380.377175   9503.162829   4854.673333
# min         3.000000     55.000000      3.000000     25.000000
# 25%      3127.750000   1533.000000   2153.000000    742.250000
# 50%      8504.000000   3627.000000   4755.500000   1526.000000
# 75%     16933.750000   7190.250000  10655.750000   3554.250000
# max    112151.000000  73498.000000  92780.000000  60869.000000
#
#        Detergents_Paper    Delicassen
# count        440.000000    440.000000
# mean        2881.493182   1524.870455
# std         4767.854448   2820.105937
# min            3.000000      3.000000
# 25%          256.750000    408.250000
# 50%          816.500000    965.500000
# 75%         3922.000000   1820.250000
# max        40827.000000  47943.000000

# %%
#Let's make columns for each type of product which categorize spending as very low,low,medium,high
#for this we will use percentile obtained from above matrix
df_spend["Fresh_spend"]=pd.cut(df_spend["Fresh"],bins=[3.0,3127.750,8504.0,16933.750,112151.0],labels=["very_low","low","medium","high"])
df_spend["Milk_spend"]=pd.cut(df_spend["Milk"],bins=[55.0,1533.0,3627.0,7190.25,73498.0],labels=["very_low","low","medium","high"])
df_spend["Grocerry_spend"]=pd.cut(df_spend["Grocery"],bins=[3.0,2153.0,4755.5,10655.75,92780.0],labels=["very_low","low","medium","high"])
df_spend["Frozen_spend"]=pd.cut(df_spend["Frozen"],bins=[25.0,742.25,1526.0,3554.25,60869.0],labels=["very_low","low","medium","high"])
df_spend["Detergent_spend"]=pd.cut(df_spend["Detergents_Paper"],bins=[3.0,256.75,816.5,3922.0,40827.0],labels=["very_low","low","medium","high"])
df_spend["Delicassen_spend"]=pd.cut(df_spend["Delicassen"],bins=[3.0,408.25,965.5,1820.25,47943.0],labels=["very_low","low","medium","high"])

# %%
#displaying the data wth new columns
df_spend
# Out:
#      Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicassen Fresh_spend  \
# 0    12669   9656     7561     214              2674        1338      medium
# 1     7057   9810     9568    1762              3293        1776         low
# 2     6353   8808     7684    2405              3516        7844         low
# 3    13265   1196     4221    6404               507        1788      medium
# 4    22615   5410     7198    3915              1777        5185        high
# 5     9413   8259     5126     666              1795        1451      medium
# 6    12126   3199     6975     480              3140         545      medium
# 7     7579   4956     9426    1669              3321        2566         low
# 8     5963   3648     6192     425              1716         750         low
# 9     6006  11093    18881    1159              7425        2098         low
# 10    3366   5403    12974    4400              5977        1744         low
# 11   13146   1124     4523    1420               549         497      medium
# 12   31714  12319    11757     287              3881        2931        high
# 13   21217   6208    14982    3095              6707         602        high
# 14   24653   9465    12091     294              5058        2168        high
# 15   10253   1114     3821     397               964         412      medium
# 16    1020   8816    12121     134              4508        1080    very_low
# 17    5876   6157     2933     839               370        4478         low
# 18   18601   6327    10099    2205              2767        3181        high
# 19    7780   2495     9464     669              2518         501         low
# 20   17546   4519     4602    1066              2259        2124        high
# 21    5567    871     2010    3383               375         569         low
# 22   31276   1917     4469    9408              2381        4334        high
# 23   26373  36423    22019    5154              4337       16523        high
# 24   22647   9776    13792    2915              4482        5778        high
# 25   16165   4230     7595     201              4003          57      medium
# 26    9898    961     2861    3151               242         833      medium
# 27   14276    803     3045     485               100         518      medium
# 28    4113  20484    25957    1158              8604        5206         low
# 29   43088   2100     2609    1200              1107         823        high
# ..     ...    ...      ...     ...               ...         ...         ...
# 410   6633   2096     4563    1389              1860        1892         low
# 411   2126   3289     3281    1535               235        4365    very_low
# 412     97   3605    12400      98              2970          62    very_low
# 413   4983   4859     6633   17866               912        2435         low
# 414   5969   1990     3417    5679              1135         290         low
# 415   7842   6046     8552    1691              3540        1874         low
# 416   4389  10940    10908     848              6728         993         low
# 417   5065   5499    11055     364              3485        1063         low
# 418    660   8494    18622     133              6740         776    very_low
# 419   8861   3783     2223     633              1580        1521      medium
# 420   4456   5266    13227      25              6818        1393         low
# 421  17063   4847     9053    1031              3415        1784        high
# 422  26400   1377     4172     830               948        1218        high
# 423  17565   3686     4657    1059              1803         668        high
# 424  16980   2884    12232     874              3213         249        high
# 425  11243   2408     2593   15348               108        1886      medium
# 426  13134   9347    14316    3141              5079        1894      medium
# 427  31012  16687     5429   15082               439        1163        high
# 428   3047   5970     4910    2198               850         317    very_low
# 429   8607   1750     3580      47                84        2501      medium
# 430   3097   4230    16483     575               241        2080    very_low
# 431   8533   5506     5160   13486              1377        1498      medium
# 432  21117   1162     4754     269              1328         395        high
# 433   1982   3218     1493    1541               356        1449    very_low
# 434  16731   3922     7994     688              2371         838      medium
# 435  29703  12051    16027   13135               182        2204        high
# 436  39228   1431      764    4510                93        2346        high
# 437  14531  15488    30243     437             14841        1867      medium
# 438  10290   1981     2232    1038               168        2125      medium
# 439   2787   1698     2510      65               477          52    very_low
#
#     Milk_spend Grocerry_spend Frozen_spend Detergent_spend Delicassen_spend
# 0         high         medium     very_low          medium           medium
# 1         high         medium       medium          medium           medium
# 2         high         medium       medium          medium             high
# 3     very_low            low         high             low           medium
# 4       medium         medium         high          medium             high
# 5         high         medium     very_low          medium           medium
# 6          low         medium     very_low          medium              low
# 7       medium         medium       medium          medium             high
# 8       medium         medium     very_low          medium              low
# 9         high           high          low            high             high
# 10      medium           high         high            high           medium
# 11    very_low            low          low             low              low
# 12        high           high     very_low          medium             high
# 13      medium           high       medium            high              low
# 14        high           high     very_low            high             high
# 15    very_low            low     very_low          medium              low
# 16        high           high     very_low            high           medium
# 17      medium            low          low             low             high
# 18      medium         medium       medium          medium             high
# 19         low         medium     very_low          medium              low
# 20      medium            low          low          medium             high
# 21    very_low       very_low       medium             low              low
# 22         low            low         high          medium             high
# 23        high           high         high            high             high
# 24        high           high       medium            high             high
# 25      medium         medium     very_low            high         very_low
# 26    very_low            low       medium        very_low              low
# 27    very_low            low     very_low        very_low              low
# 28        high           high          low            high             high
# 29         low            low          low          medium              low
# ..         ...            ...          ...             ...              ...
# 410        low            low          low          medium             high
# 411        low            low       medium        very_low             high
# 412        low           high     very_low          medium         very_low
# 413     medium         medium         high          medium             high
# 414        low            low         high          medium         very_low
# 415     medium         medium       medium          medium             high
# 416       high           high          low            high           medium
# 417     medium           high     very_low          medium           medium
# 418       high           high     very_low            high              low
# 419     medium            low     very_low          medium           medium
# 420     medium           high          NaN            high           medium
# 421     medium         medium          low          medium           medium
# 422   very_low            low          low          medium           medium
# 423     medium            low          low          medium              low
# 424        low           high          low          medium         very_low
# 425        low            low         high        very_low             high
# 426       high           high       medium            high             high
# 427       high         medium         high             low           medium
# 428     medium         medium       medium          medium         very_low
# 429        low            low     very_low        very_low             high
# 430     medium           high     very_low        very_low             high
# 431     medium         medium         high          medium           medium
# 432   very_low            low     very_low          medium         very_low
# 433        low       very_low       medium             low           medium
# 434     medium         medium     very_low          medium              low
# 435       high           high         high        very_low             high
# 436   very_low       very_low         high        very_low             high
# 437       high           high     very_low            high             high
# 438        low            low          low        very_low             high
# 439        low            low     very_low             low         very_low
#
# [440 rows x 12 columns]

# %%
#The new columns created will help us in segmenting  the dataset based on spendings
#lets display the data with high spendings on each of the product categories
df_spend.loc[(df_spend["Fresh_spend"]=="high")&(df_spend["Milk_spend"]=="high")&(df_spend["Grocerry_spend"]=="high")&(df_spend["Frozen_spend"]=="high")&(df_spend["Detergent_spend"]=="high")&(df_spend["Delicassen_spend"]=="high"),["Fresh","Milk","Grocery","Frozen","Detergents_Paper","Delicassen"]]
# Out:
#       Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 23    26373  36423    22019    5154              4337       16523
# 47    44466  54259    55571    7782             24171        6465
# 181  112151  29627    18148   16745              4948        8550

# %%
#lets display the data with medium spendings on each of the product categories
df_spend.loc[(df_spend["Fresh_spend"]=="medium")&(df_spend["Milk_spend"]=="medium")&(df_spend["Grocerry_spend"]=="medium")&(df_spend["Frozen_spend"]=="medium")&(df_spend["Detergent_spend"]=="medium")&(df_spend["Delicassen_spend"]=="medium"),["Fresh","Milk","Grocery","Frozen","Detergents_Paper","Delicassen"]]
#There are no customer group who does medium spending on all products simultaneously
# Out:
# Empty DataFrame
# Columns: [Fresh, Milk, Grocery, Frozen, Detergents_Paper, Delicassen]
# Index: []

# %%
#lets display the data with low spendings on each of the product categories
df_spend.loc[(df_spend["Fresh_spend"]=="low")&(df_spend["Milk_spend"]=="low")&(df_spend["Grocerry_spend"]=="low")&(df_spend["Frozen_spend"]=="low")&(df_spend["Detergent_spend"]=="low")&(df_spend["Delicassen_spend"]=="low"),["Fresh","Milk","Grocery","Frozen","Detergents_Paper","Delicassen"]]
# Out:
# Empty DataFrame
# Columns: [Fresh, Milk, Grocery, Frozen, Detergents_Paper, Delicassen]
# Index: []

# %%
#lets display the data with very_low spendings on each of the product categories
df_spend.loc[(df_spend["Fresh_spend"]=="very_low")&(df_spend["Milk_spend"]=="very_low")&(df_spend["Grocerry_spend"]=="very_low")&(df_spend["Frozen_spend"]=="very_low")&(df_spend["Detergent_spend"]=="very_low")&(df_spend["Delicassen_spend"]=="very_low"),["Fresh","Milk","Grocery","Frozen","Detergents_Paper","Delicassen"]]
# Out:
#      Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 131   2101   589      314     346                70         310
# 355    190   727     2012     245               184         127

# %% [markdown]
# From above segmentation we were not able to get data  in each groups,Therefore lets try to chcek with 2 groups above medium and below 50 percentile of respective columns

# %%
df_spend.describe()
# Out:
#                Fresh          Milk       Grocery        Frozen  \
# count     440.000000    440.000000    440.000000    440.000000
# mean    12000.297727   5796.265909   7951.277273   3071.931818
# std     12647.328865   7380.377175   9503.162829   4854.673333
# min         3.000000     55.000000      3.000000     25.000000
# 25%      3127.750000   1533.000000   2153.000000    742.250000
# 50%      8504.000000   3627.000000   4755.500000   1526.000000
# 75%     16933.750000   7190.250000  10655.750000   3554.250000
# max    112151.000000  73498.000000  92780.000000  60869.000000
#
#        Detergents_Paper    Delicassen
# count        440.000000    440.000000
# mean        2881.493182   1524.870455
# std         4767.854448   2820.105937
# min            3.000000      3.000000
# 25%          256.750000    408.250000
# 50%          816.500000    965.500000
# 75%         3922.000000   1820.250000
# max        40827.000000  47943.000000

# %%
#Less than equal to 50 percentile
df_spend.loc[(df_spend["Fresh"]<=8504.0)&(df_spend["Milk"]<=3627.0)&(df_spend["Grocery"]<=4755.5)&(df_spend["Frozen"]<=1526.0)&(df_spend["Detergents_Paper"]<=816.5)&(df_spend["Delicassen"]<=965.5),["Fresh","Milk","Grocery","Frozen","Detergents_Paper","Delicassen"]]
# Out:
#      Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 34    1502  1979     2262     425               483         395
# 69    8352  2820     1293     779               656         144
# 80    7005   829     3009     430               610         529
# 97     403   254      610     774                54          63
# 98     503   112      778     895                56         132
# 131   2101   589      314     346                70         310
# 134   7388  1882     2174     720                47         537
# 135   6300  1289     2591    1170               199         326
# 146   7769  1936     2177     926                73         520
# 154    622    55      137      75                 7           8
# 168   5809   735      803    1393                79         429
# 184    327   918     4710      74               334          11
# 192   5509  1461     2251     547               187         409
# 206   6373   780      950     878               288         285
# 224   7274   659     1499     784                70         659
# 238   7363   475      585    1112                72         216
# 275    680  1610      223     862                96         379
# 299    444   879     2060     264               290         259
# 308   6987  1020     3007     416               257         656
# 327    542   899     1664     414                88         522
# 352    608  1106     1533     830                90         195
# 355    190   727     2012     245               184         127
# 361   4734   607      864    1206               159         405
# 362   2121  1601     2453     560               179         712
# 364   2615   873     1524    1103               514         468
# 367   3477   894      534    1457               252         342
# 369   6211   337      683    1089                41         296
# 374   6338  2256     1668    1492               311         686
# 375   5841  1450     1162     597               476          70
# 439   2787  1698     2510      65               477          52

# %%
#greater than 50 percentile
df_spend.loc[(df_spend["Fresh"]>8504.0)&(df_spend["Milk"]>3627.0)&(df_spend["Grocery"]>4755.5)&(df_spend["Frozen"]>1526.0)&(df_spend["Detergents_Paper"]>816.5)&(df_spend["Delicassen"]>965.5),["Fresh","Milk","Grocery","Frozen","Detergents_Paper","Delicassen"]]
# Out:
#       Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 4     22615   5410     7198    3915              1777        5185
# 18    18601   6327    10099    2205              2767        3181
# 23    26373  36423    22019    5154              4337       16523
# 24    22647   9776    13792    2915              4482        5778
# 36    29955   4362     5428    1729               862        4626
# 40    24025   4332     4757    9510              1145        5864
# 47    44466  54259    55571    7782             24171        6465
# 61    35942  38369    59598    3254             26701        2017
# 63     9396  11601    15775    2896              7677        1295
# 87    43265   5025     8117    6312              1579       14351
# 92     9198  27472    32034    3232             18906        5130
# 100   11594   7779    12144    3252              8035        3029
# 107    8797  10646    14886    2471              8969        1438
# 140   17623   4280     7305    2279               960        2616
# 165   15615  12653    19858    4425              7108        2379
# 181  112151  29627    18148   16745              4948        8550
# 211   12119  28326    39694    4736             19410        2870
# 226   20782   5921     9212    1759              2568        1553
# 230   11072   5989     5615    8321               955        2137
# 325   32717  16784    13626   60869              1272        5609
# 347   27380   7184    12311    2809              4621        1022
# 382   34454   7435     8469    2540              1711        2893
# 409    8708   3634     6100    2349              2123        5137
# 426   13134   9347    14316    3141              5079        1894
# 431    8533   5506     5160   13486              1377        1498

# %%
#Lets chcek the average spendings in milk each quantile graphically
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x="Milk_spend",y="Milk",data=df_spend)
plt.show()

# %%
#lets chcek this for "Fresh" product
sns.barplot(x="Fresh_spend",y="Fresh",data=df_spend)
plt.show()

# %% [markdown]
# All the above graphs of average spending based on low to high wil be of same trend,important here is to analyze the increase.

# %%
#lets chcek the people who are sepnding very low on first three products
df_spend.loc[(df_spend["Fresh_spend"]=="very_low")&(df_spend["Milk_spend"]=="very_low")&(df_spend["Grocerry_spend"]=="very_low"),["Fresh","Milk","Grocery","Frozen","Detergents_Paper","Delicassen"]]
# Out:
#      Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 97     403   254      610     774                54          63
# 98     503   112      778     895                56         132
# 131   2101   589      314     346                70         310
# 186   3009   521      854    3470               949         727
# 228   1869   577      572     950              4762         203
# 299    444   879     2060     264               290         259
# 327    542   899     1664     414                88         522
# 344   3043  1172     1763    2234               217         379
# 352    608  1106     1533     830                90         195
# 355    190   727     2012     245               184         127
# 364   2615   873     1524    1103               514         468

# %%
#lets chcek the people who are sepnding very low on first three products
df_spend.loc[(df_spend["Fresh_spend"]=="low")&(df_spend["Milk_spend"]=="low")&(df_spend["Grocerry_spend"]=="low"),["Fresh","Milk","Grocery","Frozen","Detergents_Paper","Delicassen"]]
# Out:
#      Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 134   7388  1882     2174     720                47         537
# 146   7769  1936     2177     926                73         520
# 252   6623  1860     4740    7683               205        1693
# 280   3366  2884     2431     977               167        1104
# 291   6022  3354     3261    2507               212         686
# 410   6633  2096     4563    1389              1860        1892
# 414   5969  1990     3417    5679              1135         290

# %%
#Lets graphically chcek the count  of people who are spending very_low,low_medium and high on each actegory of product
sns.countplot(x="Fresh_spend",data=df_spend)
plt.show()

# %%
#lets chcek for milk
sns.countplot(x="Milk_spend",data=df_spend)
plt.show()

# %%
#Lets plot the graph of countplot using for loop
df_spend.columns
cols=['Fresh_spend', 'Milk_spend', 'Grocerry_spend', 'Frozen_spend',"Detergent_spend","Delicassen_spend"]
for col in cols:
    sns.countplot(x=col,data=df_spend)
    plt.show()
    print()
    print()
#From below we come to know there are equal instances of each type of spendings per caegory of product

# %% [markdown]
# Above method of making new columns is called binning ,now using that one column or combination of columns we can identify customer groups and provide them with the plans such that those kind of customer increase their spendings

# %%
#input
df_x=df_spend[["Fresh","Milk","Grocery","Frozen","Detergents_Paper","Delicassen"]]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(df_x)
x=sc.transform(df_x)

# %%
#Now we will use unsupervised K means clustering algorithm to find the clusters
from sklearn.cluster import KMeans
inertia_list=list()
for cluster in range(2,11):
    km=KMeans(n_clusters=cluster)
    km.fit(x)
    inertia_list.append(km.inertia_)
sns.lineplot(x=range(2,11),y=inertia_list,marker='o')
plt.show()
#We can see below change is consant between 6 to 9 ,so lets choose number of clusters as 8

# %%
#so making the final model
km=KMeans(n_clusters=8)
km.fit(x)
y_pred=km.predict(x)

# %%
y_pred=pd.DataFrame(y_pred,columns=["target"])
df_final=pd.concat([df_x,y_pred],axis=1)
df_final
# Out:
#      Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicassen  target
# 0    12669   9656     7561     214              2674        1338       7
# 1     7057   9810     9568    1762              3293        1776       0
# 2     6353   8808     7684    2405              3516        7844       0
# 3    13265   1196     4221    6404               507        1788       5
# 4    22615   5410     7198    3915              1777        5185       1
# 5     9413   8259     5126     666              1795        1451       7
# 6    12126   3199     6975     480              3140         545       7
# 7     7579   4956     9426    1669              3321        2566       7
# 8     5963   3648     6192     425              1716         750       7
# 9     6006  11093    18881    1159              7425        2098       0
# 10    3366   5403    12974    4400              5977        1744       0
# 11   13146   1124     4523    1420               549         497       7
# 12   31714  12319    11757     287              3881        2931       1
# 13   21217   6208    14982    3095              6707         602       0
# 14   24653   9465    12091     294              5058        2168       1
# 15   10253   1114     3821     397               964         412       7
# 16    1020   8816    12121     134              4508        1080       0
# 17    5876   6157     2933     839               370        4478       7
# 18   18601   6327    10099    2205              2767        3181       1
# 19    7780   2495     9464     669              2518         501       7
# 20   17546   4519     4602    1066              2259        2124       1
# 21    5567    871     2010    3383               375         569       7
# 22   31276   1917     4469    9408              2381        4334       5
# 23   26373  36423    22019    5154              4337       16523       0
# 24   22647   9776    13792    2915              4482        5778       0
# 25   16165   4230     7595     201              4003          57       1
# 26    9898    961     2861    3151               242         833       7
# 27   14276    803     3045     485               100         518       7
# 28    4113  20484    25957    1158              8604        5206       0
# 29   43088   2100     2609    1200              1107         823       1
# ..     ...    ...      ...     ...               ...         ...     ...
# 410   6633   2096     4563    1389              1860        1892       7
# 411   2126   3289     3281    1535               235        4365       7
# 412     97   3605    12400      98              2970          62       7
# 413   4983   4859     6633   17866               912        2435       5
# 414   5969   1990     3417    5679              1135         290       7
# 415   7842   6046     8552    1691              3540        1874       7
# 416   4389  10940    10908     848              6728         993       0
# 417   5065   5499    11055     364              3485        1063       7
# 418    660   8494    18622     133              6740         776       0
# 419   8861   3783     2223     633              1580        1521       7
# 420   4456   5266    13227      25              6818        1393       0
# 421  17063   4847     9053    1031              3415        1784       1
# 422  26400   1377     4172     830               948        1218       1
# 423  17565   3686     4657    1059              1803         668       1
# 424  16980   2884    12232     874              3213         249       1
# 425  11243   2408     2593   15348               108        1886       5
# 426  13134   9347    14316    3141              5079        1894       0
# 427  31012  16687     5429   15082               439        1163       5
# 428   3047   5970     4910    2198               850         317       7
# 429   8607   1750     3580      47                84        2501       7
# 430   3097   4230    16483     575               241        2080       7
# 431   8533   5506     5160   13486              1377        1498       5
# 432  21117   1162     4754     269              1328         395       1
# 433   1982   3218     1493    1541               356        1449       7
# 434  16731   3922     7994     688              2371         838       1
# 435  29703  12051    16027   13135               182        2204       5
# 436  39228   1431      764    4510                93        2346       1
# 437  14531  15488    30243     437             14841        1867       0
# 438  10290   1981     2232    1038               168        2125       7
# 439   2787   1698     2510      65               477          52       7
#
# [440 rows x 7 columns]

# %%
#Lets check the value counts
df_final["target"].value_counts()
# Out:
# 7    203
# 0     91
# 1     77
# 5     45
# 6     11
# 2     10
# 4      2
# 3      1
# Name: target, dtype: int64

# %%
#Lets chcek silhouette_score
from sklearn.metrics import silhouette_score
for cluster in range(2,11):
    km=KMeans(n_clusters=cluster)
    km.fit(x)
    y_pred=km.predict(x)
    print("Average silhouette_score for cluster: {} is: {}".format(cluster,silhouette_score(x,y_pred)))
# Out:
# Average silhouette_score for cluster: 2 is: 0.5626329567380032
# Average silhouette_score for cluster: 3 is: 0.5482872649700601
# Average silhouette_score for cluster: 4 is: 0.34847138657014315
# Average silhouette_score for cluster: 5 is: 0.3690403826812808
# Average silhouette_score for cluster: 6 is: 0.3782288965882046
# Average silhouette_score for cluster: 7 is: 0.35046540473802296
# Average silhouette_score for cluster: 8 is: 0.3271438986591137
# Average silhouette_score for cluster: 9 is: 0.3026370741182072
# Average silhouette_score for cluster: 10 is: 0.3142526034297306
